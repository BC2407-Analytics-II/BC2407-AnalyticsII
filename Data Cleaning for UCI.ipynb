# %%
import pandas as pd

# %% [markdown]
# ## DATA CLEANING

# %%
df = pd.read_excel('Data/Raw Data/uci_online_retail.xlsx')

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# ## ==== InvoiceNo ====
#
# - InvoiceNo: Invoice number. Nominal, a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation.

# %%
colName = 'InvoiceNo'

# View the rows that are not valid digits.

temp = pd.DataFrame(df.loc[~df[colName].astype(str).str.isdigit(), colName].unique())
#1.take colName column
#2.change to string datatype
#3.use isdigit() function
#4.filter df on the inverse of this condition using loc
#5.get unique values using unique()
#5.convert this array data structure into DataFrame data structure

temp.columns = [colName]
#6.rename column

temp.sort_values(by=colName)
#7.sort values by ascending
# Out:
#      InvoiceNo
# 2388   A563185
# 2389   A563186
# 2390   A563187
# 0      C536379
# 1      C536383
# ...        ...
# 3834   C581484
# 3835   C581490
# 3836   C581499
# 3837   C581568
# 3838   C581569
#
# [3839 rows x 1 columns]

# %%
temp = df[~df[colName].astype('str').str.contains('C') & ~df[colName].astype('str').str.isdigit()]
temp
#1.convert column to string
#2.search for strings that contain C
#3.filter dataframe on the inverse of this condition
#4.AND with the previous condition we wrote
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299982   A563185         B  Adjust bad debt         1 2011-08-12 14:50:00
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299982   11062.06         NaN  United Kingdom
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
# there's our culprit - the adjustment of bad debt. 
# Hypothesis: the corresponding bad debt source is the listed 6 digit invoice number less the A
# Let's test this out

temp2 = df.iloc[0:0].copy()
#1.create empty dataframe with same column names as original

for invoice in temp[colName].str[1:]:
    temp2.append(df[df[colName] == invoice])
    #append to this empty dataframe any rows that match the stripped invoice number
    
temp2
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
# no match....
# since these are not customer transactions, nor are they tagged to any existing transaction,
# let's just remove them

if colName == 'InvoiceNo':
    df = df.drop(temp.index)
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [541906 rows x 8 columns]

# %%
# Hypothesis: The 7 digit StockCodes that are Cancelled have a a 6 digit equivalent,
# indicating the invoice the cancellation corresponds to

# Do a left join of the 7 digit-ers with the 6 digit-ers, 
# on a new column that extracts the last 6 digits of the 7 digit-ers

tempL = df[df[colName].astype('str').str.len() == 7]
#1.get 7 digit-ers
tempL[colName+'Trunc'] = tempL[colName].astype('str').str[1:].astype('int')
#2.extract last 6 digits, this will be the join column. 
#Important: must be same datatype as the other column we are joining on

tempR = df[df[colName].astype('str').str.len() == 6]
tempR[colName+'Trunc'] = tempR[colName].astype('int')
#3.create right table

pd.merge(tempL, tempR, left_on=(colName+'Trunc'), right_on=colName, how='left')
# Out:
# C:\Users\bryan\AppData\Local\Temp/ipykernel_19292/1951423686.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tempL[colName+'Trunc'] = tempL[colName].astype('str').str[1:].astype('int')
# C:\Users\bryan\AppData\Local\Temp/ipykernel_19292/1951423686.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tempR[colName+'Trunc'] = tempR[colName].astype('int')
#      InvoiceNo_x StockCode_x                     Description_x  Quantity_x  \
# 0        C536379           D                          Discount          -1
# 1        C536383      35004C   SET OF 3 COLOURED  FLYING DUCKS          -1
# 2        C536391       22556    PLASTERS IN TIN CIRCUS PARADE          -12
# 3        C536391       21984  PACK OF 12 PINK PAISLEY TISSUES          -24
# 4        C536391       21983  PACK OF 12 BLUE PAISLEY TISSUES          -24
# ...          ...         ...                               ...         ...
# 9283     C581490       23144   ZINC T-LIGHT HOLDER STARS SMALL         -11
# 9284     C581499           M                            Manual          -1
# 9285     C581568       21258        VICTORIAN SEWING BOX LARGE          -5
# 9286     C581569       84978  HANGING HEART JAR T-LIGHT HOLDER          -1
# 9287     C581569       20979     36 PENCILS TUBE RED RETROSPOT          -5
#
#            InvoiceDate_x  UnitPrice_x  CustomerID_x       Country_x  \
# 0    2010-12-01 09:41:00        27.50       14527.0  United Kingdom
# 1    2010-12-01 09:49:00         4.65       15311.0  United Kingdom
# 2    2010-12-01 10:24:00         1.65       17548.0  United Kingdom
# 3    2010-12-01 10:24:00         0.29       17548.0  United Kingdom
# 4    2010-12-01 10:24:00         0.29       17548.0  United Kingdom
# ...                  ...          ...           ...             ...
# 9283 2011-12-09 09:57:00         0.83       14397.0  United Kingdom
# 9284 2011-12-09 10:28:00       224.69       15498.0  United Kingdom
# 9285 2011-12-09 11:57:00        10.95       15311.0  United Kingdom
# 9286 2011-12-09 11:58:00         1.25       17315.0  United Kingdom
# 9287 2011-12-09 11:58:00         1.25       17315.0  United Kingdom
#
#      InvoiceNoTrunc_x InvoiceNo_y StockCode_y Description_y  Quantity_y  \
# 0              536379         NaN         NaN           NaN         NaN
# 1              536383         NaN         NaN           NaN         NaN
# 2              536391         NaN         NaN           NaN         NaN
# 3              536391         NaN         NaN           NaN         NaN
# 4              536391         NaN         NaN           NaN         NaN
# ...               ...         ...         ...           ...         ...
# 9283           581490         NaN         NaN           NaN         NaN
# 9284           581499         NaN         NaN           NaN         NaN
# 9285           581568         NaN         NaN           NaN         NaN
# 9286           581569         NaN         NaN           NaN         NaN
# 9287           581569         NaN         NaN           NaN         NaN
#
#      InvoiceDate_y  UnitPrice_y  CustomerID_y Country_y InvoiceNoTrunc_y
# 0              NaT          NaN           NaN       NaN              NaN
# 1              NaT          NaN           NaN       NaN              NaN
# 2              NaT          NaN           NaN       NaN              NaN
# 3              NaT          NaN           NaN       NaN              NaN
# 4              NaT          NaN           NaN       NaN              NaN
# ...            ...          ...           ...       ...              ...
# 9283           NaT          NaN           NaN       NaN              NaN
# 9284           NaT          NaN           NaN       NaN              NaN
# 9285           NaT          NaN           NaN       NaN              NaN
# 9286           NaT          NaN           NaN       NaN              NaN
# 9287           NaT          NaN           NaN       NaN              NaN
#
# [9288 rows x 18 columns]

# %%
# our hypothesis is false. 
# we will circle back to this after cleaning the other columns

# %% [markdown]
# ## // InvoiceNo is done. //

# %% [markdown]
# ## ==== Quantity ====
#
# - Quantity: The quantities of each product (item) per transaction. Numeric.

# %%
colName = 'Quantity'

df[[colName]].describe()
# Out:
#             Quantity
# count  541906.000000
# mean        9.552297
# std       218.081761
# min    -80995.000000
# 25%         1.000000
# 50%         3.000000
# 75%        10.000000
# max     80995.000000

# %%
# min should not be negative; in fact all quantities should be positive in theory
df[df[colName]<=0]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 141    2010-12-01 09:41:00      27.50     14527.0  United Kingdom
# 154    2010-12-01 09:49:00       4.65     15311.0  United Kingdom
# 235    2010-12-01 10:24:00       1.65     17548.0  United Kingdom
# 236    2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# 237    2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# ...                    ...        ...         ...             ...
# 540449 2011-12-09 09:57:00       0.83     14397.0  United Kingdom
# 541541 2011-12-09 10:28:00     224.69     15498.0  United Kingdom
# 541715 2011-12-09 11:57:00      10.95     15311.0  United Kingdom
# 541716 2011-12-09 11:58:00       1.25     17315.0  United Kingdom
# 541717 2011-12-09 11:58:00       1.25     17315.0  United Kingdom
#
# [10624 rows x 8 columns]

# %%
# some of these are the cancellations. we ignore them and circle back to them later
temp = df[(~df['InvoiceNo'].astype('str').str.contains('C')) & (df[colName]<=0)]
temp
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 2406      536589     21777         NaN       -10 2010-12-01 16:50:00
# 4347      536764    84952C         NaN       -38 2010-12-02 14:42:00
# 7188      536996     22712         NaN       -20 2010-12-03 15:30:00
# 7189      536997     22028         NaN       -20 2010-12-03 15:30:00
# 7190      536998     85067         NaN        -6 2010-12-03 15:30:00
# ...          ...       ...         ...       ...                 ...
# 535333    581210     23395       check       -26 2011-12-07 18:36:00
# 535335    581212     22578        lost     -1050 2011-12-07 18:38:00
# 535336    581213     22576       check       -30 2011-12-07 18:38:00
# 536908    581226     23090     missing      -338 2011-12-08 09:56:00
# 538919    581422     23169     smashed      -235 2011-12-08 15:24:00
#
#         UnitPrice  CustomerID         Country
# 2406          0.0         NaN  United Kingdom
# 4347          0.0         NaN  United Kingdom
# 7188          0.0         NaN  United Kingdom
# 7189          0.0         NaN  United Kingdom
# 7190          0.0         NaN  United Kingdom
# ...           ...         ...             ...
# 535333        0.0         NaN  United Kingdom
# 535335        0.0         NaN  United Kingdom
# 535336        0.0         NaN  United Kingdom
# 536908        0.0         NaN  United Kingdom
# 538919        0.0         NaN  United Kingdom
#
# [1336 rows x 8 columns]

# %%
temp['CustomerID'].describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: CustomerID, dtype: float64

# %%
temp['Description'].unique()
# Out:
# array([nan, '?', 'check', 'damages', 'faulty', 'Dotcom sales',
#        'reverse 21/5/10 adjustment', 'mouldy, thrown away.', 'counted',
#        'Given away', 'Dotcom', 'label mix up', 'samples/damages',
#        'thrown away', 'incorrectly made-thrown away.', 'showroom', 'MIA',
#        'Dotcom set', 'wrongly sold as sets', 'Amazon sold sets',
#        'dotcom sold sets', 'wrongly sold sets', '? sold as sets?',
#        '?sold as sets?', 'Thrown away.', 'damages/display',
#        'damaged stock', 'broken', 'throw away', 'wrong barcode (22467)',
#        'wrong barcode', 'barcode problem', '?lost',
#        "thrown away-can't sell.", "thrown away-can't sell", 'damages?',
#        're dotcom quick fix.', "Dotcom sold in 6's", 'sold in set?',
#        'cracked', 'sold as 22467', 'Damaged',
#        'mystery! Only ever imported 1800',
#        'MERCHANT CHANDLER CREDIT ERROR, STO', 'POSSIBLE DAMAGES OR LOST?',
#        'damaged', 'DAMAGED', 'Display', 'Missing', 'wrong code?',
#        'wrong code', 'adjust', 'crushed', 'damages/showroom etc',
#        'samples', 'damages/credits from ASOS.',
#        'Not rcvd in 10/11/2010 delivery', 'Thrown away-rusty',
#        'sold as set/6 by dotcom', 'wet/rusty', 'damages/dotcom?',
#        'smashed', 'reverse previous adjustment',
#        'incorrectly credited C550456 see 47', 'wet damaged',
#        'Water damaged', 'missing', 'sold as set on dotcom',
#        'sold as set on dotcom and amazon', 'water damage',
#        'sold as set by dotcom', 'Printing smudges/thrown away',
#        'printing smudges/thrown away', 'found some more on shelf',
#        'Show Samples', 'mix up with c', 'mouldy, unsaleable.',
#        'wrongly marked. 23343 in box', 'stock creditted wrongly', 'ebay',
#        'incorrectly put back into stock', 'Damages/samples',
#        'Sold as 1 on dotcom', 'taig adjust no stock',
#        'code mix up? 84930', '?display?', 'sold as 1', '?missing',
#        'crushed ctn', 'Crushed', 'temp adjustment', '??', 'test',
#        'OOPS ! adjustment', 'Dagamed',
#        'historic computer difference?....se', 'Incorrect stock entry.',
#        'incorrect stock entry.', 'wrongly coded-23343', 'stock check',
#        'crushed boxes', 'WET/MOULDY', "can't find", 'mouldy',
#        'Wet pallet-thrown away', 'adjustment', '20713 wrongly marked',
#        're-adjustment', 'Breakages', 20713, 'wrongly coded 20713',
#        'Damages', 'CHECK', 'Unsaleable, destroyed.', 'dotcom sales',
#        'damages wax', 'water damaged', 'Wrongly mrked had 85123a in box',
#        'wrongly marked carton 22804', 'missing?', 'wet rusty', '???lost',
#        'sold with wrong barcode', 'rusty thrown away', 'rusty throw away',
#        'dotcom', '?? missing', 'wet pallet', '????missing', '???missing',
#        'lost in space', 'wet?', 'lost??', '???', 'wet', 'wet boxes',
#        '????damages????', 'mixed up', 'lost'], dtype=object)

# %%
# these rows mostly consist of inventory upkeep. 
# a rare few are related to sales, but for simplicity we shall just remove them

if colName == 'Quantity':
    df = df.drop(temp.index)
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [540570 rows x 8 columns]

# %%
df[[colName]].describe()
# Out:
#             Quantity
# count  540570.000000
# mean        9.958755
# std       216.230153
# min    -80995.000000
# 25%         1.000000
# 50%         3.000000
# 75%        10.000000
# max     80995.000000

# %% [markdown]
# ## // Quantity is done. //

# %% [markdown]
# ## ==== InvoiceDate ====
#
# - InvoiceDate: Invice Date and time. Numeric, the day and time when each transaction was generated.

# %%
# seems good
df['InvoiceDate'].describe(datetime_is_numeric=True)
# Out:
# count                           540570
# mean     2011-07-04 14:42:30.409234432
# min                2010-12-01 08:26:00
# 25%                2011-03-28 11:34:00
# 50%                2011-07-20 11:07:00
# 75%                2011-10-19 11:41:00
# max                2011-12-09 12:50:00
# Name: InvoiceDate, dtype: object

# %% [markdown]
# ## // InvoiceDate is done. //

# %% [markdown]
# ## ==== UnitPrice ====
#
# - UnitPrice: Unit price. Numeric, Product price per unit in sterling.

# %%
colName = 'UnitPrice'

df[colName].describe()
# Out:
# count    540570.000000
# mean          4.642999
# std          93.307581
# min           0.000000
# 25%           1.250000
# 50%           2.080000
# 75%           4.130000
# max       38970.000000
# Name: UnitPrice, dtype: float64

# %%
# prie shouldn't be zero
df.loc[df[colName] == 0]
# Out:
#        InvoiceNo StockCode                   Description  Quantity  \
# 622       536414     22139                           NaN        56
# 1970      536545     21134                           NaN         1
# 1971      536546     22145                           NaN         1
# 1972      536547     37509                           NaN         1
# 1987      536549    85226A                           NaN         1
# ...          ...       ...                           ...       ...
# 535334    581211     22142                         check        14
# 536981    581234     72817                           NaN        27
# 538504    581406    46000M  POLYESTER FILLER PAD 45x45cm       240
# 538505    581406    46000S  POLYESTER FILLER PAD 40x40cm       300
# 538554    581408     85175                           NaN        20
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 622    2010-12-01 11:52:00        0.0         NaN  United Kingdom
# 1970   2010-12-01 14:32:00        0.0         NaN  United Kingdom
# 1971   2010-12-01 14:33:00        0.0         NaN  United Kingdom
# 1972   2010-12-01 14:33:00        0.0         NaN  United Kingdom
# 1987   2010-12-01 14:34:00        0.0         NaN  United Kingdom
# ...                    ...        ...         ...             ...
# 535334 2011-12-07 18:36:00        0.0         NaN  United Kingdom
# 536981 2011-12-08 10:33:00        0.0         NaN  United Kingdom
# 538504 2011-12-08 13:58:00        0.0         NaN  United Kingdom
# 538505 2011-12-08 13:58:00        0.0         NaN  United Kingdom
# 538554 2011-12-08 14:06:00        0.0         NaN  United Kingdom
#
# [1179 rows x 8 columns]

# %%
# drop those with no price and customerID, because those are untrackable already
temp = df.loc[(df[colName] == 0) & (df['CustomerID'].isna())]

if colName == 'UnitPrice':
    df = df.drop(temp.index)
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [539431 rows x 8 columns]

# %%
# these have a product and customer, but no price.
# let's try to fill in the missing prices

missingPrices = df.loc[(df[colName] == 0)]
missingPricesIndexes = missingPrices.index
missingPrices
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 9302      537197     22841         ROUND CAKE TIN VINTAGE GREEN         1
# 33576     539263     22580         ADVENT CALENDAR GINGHAM SACK         4
# 40089     539722     22423             REGENCY CAKESTAND 3 TIER        10
# 47068     540372     22090              PAPER BUNTING RETROSPOT        24
# 47070     540372     22553               PLASTERS IN TIN SKULLS        24
# 56674     541109     22168        ORGANISER WOOD ANTIQUE WHITE          1
# 86789     543599    84535B         FAIRY CAKES NOTEBOOK A6 SIZE        16
# 130188    547417     22062  CERAMIC BOWL WITH LOVE HEART DESIGN        36
# 139453    548318     22055   MINI CAKE STAND  HANGING STRAWBERY         5
# 145208    548871     22162          HEART GARLAND RUSTIC PADDED         2
# 157042    550188     22636   CHILDS BREAKFAST SET CIRCUS PARADE         1
# 187613    553000     47566                        PARTY BUNTING         4
# 198383    554037     22619            SET OF 6 SOLDIER SKITTLES        80
# 279324    561284     22167           OVAL WALL MIRROR DIAMANTE          1
# 282912    561669     22960             JAM MAKING SET WITH JARS        11
# 285657    561916         M                               Manual         1
# 298054    562973     23157           SET OF 6 NATIVITY MAGNETS        240
# 314745    564651     23270     SET OF 2 CERAMIC PAINTED HEARTS         96
# 314746    564651     23268  SET OF 2 CERAMIC CHRISTMAS REINDEER       192
# 314747    564651     22955             36 FOIL STAR CAKE CASES        144
# 314748    564651     21786                   POLKADOT RAIN HAT        144
# 358655    568158      PADS           PADS TO MATCH ALL CUSHIONS         1
# 361825    568384         M                               Manual         1
# 379913    569716     22778                   GLASS CLOCHE SMALL         2
# 395529    571035         M                               Manual         1
# 420404    572893     21208          PASTEL COLOUR HONEYCOMB FAN         5
# 436428    574138     23234        BISCUIT TIN VINTAGE CHRISTMAS       216
# 436597    574175     22065       CHRISTMAS PUDDING TRINKET POT         12
# 436961    574252         M                               Manual         1
# 439361    574469     22385            JUMBO BAG SPACEBOY DESIGN        12
# 446125    574879     22625                   RED KITCHEN SCALES         2
# 446793    574920     22899         CHILDREN'S APRON DOLLY GIRL          1
# 446794    574920     23480       MINI LIGHTS WOODLAND MUSHROOMS         1
# 454463    575579     22437        SET OF 9 BLACK SKULL BALLOONS        20
# 454464    575579     22089        PAPER BUNTING VINTAGE PAISLEY        24
# 479079    577129     22464          HANGING METAL HEART LANTERN         4
# 479546    577168         M                               Manual         1
# 480649    577314     23407       SET OF 2 TRAYS HOME SWEET HOME         2
# 485985    577696         M                               Manual         1
# 502122    578841     84826       ASSTD DESIGN 3D PAPER STICKERS     12540
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 9302   2010-12-05 14:02:00        0.0     12647.0         Germany
# 33576  2010-12-16 14:36:00        0.0     16560.0  United Kingdom
# 40089  2010-12-21 13:45:00        0.0     14911.0            EIRE
# 47068  2011-01-06 16:41:00        0.0     13081.0  United Kingdom
# 47070  2011-01-06 16:41:00        0.0     13081.0  United Kingdom
# 56674  2011-01-13 15:10:00        0.0     15107.0  United Kingdom
# 86789  2011-02-10 13:08:00        0.0     17560.0  United Kingdom
# 130188 2011-03-23 10:25:00        0.0     13239.0  United Kingdom
# 139453 2011-03-30 12:45:00        0.0     13113.0  United Kingdom
# 145208 2011-04-04 14:42:00        0.0     14410.0  United Kingdom
# 157042 2011-04-14 18:57:00        0.0     12457.0     Switzerland
# 187613 2011-05-12 15:21:00        0.0     17667.0  United Kingdom
# 198383 2011-05-20 14:13:00        0.0     12415.0       Australia
# 279324 2011-07-26 12:24:00        0.0     16818.0  United Kingdom
# 282912 2011-07-28 17:09:00        0.0     12507.0           Spain
# 285657 2011-08-01 11:44:00        0.0     15581.0  United Kingdom
# 298054 2011-08-11 11:42:00        0.0     14911.0            EIRE
# 314745 2011-08-26 14:19:00        0.0     14646.0     Netherlands
# 314746 2011-08-26 14:19:00        0.0     14646.0     Netherlands
# 314747 2011-08-26 14:19:00        0.0     14646.0     Netherlands
# 314748 2011-08-26 14:19:00        0.0     14646.0     Netherlands
# 358655 2011-09-25 12:22:00        0.0     16133.0  United Kingdom
# 361825 2011-09-27 09:46:00        0.0     12748.0  United Kingdom
# 379913 2011-10-06 08:17:00        0.0     15804.0  United Kingdom
# 395529 2011-10-13 12:50:00        0.0     12446.0             RSA
# 420404 2011-10-26 14:36:00        0.0     18059.0  United Kingdom
# 436428 2011-11-03 11:26:00        0.0     12415.0       Australia
# 436597 2011-11-03 11:47:00        0.0     14110.0  United Kingdom
# 436961 2011-11-03 13:24:00        0.0     12437.0          France
# 439361 2011-11-04 11:55:00        0.0     12431.0       Australia
# 446125 2011-11-07 13:22:00        0.0     13014.0  United Kingdom
# 446793 2011-11-07 16:34:00        0.0     13985.0  United Kingdom
# 446794 2011-11-07 16:34:00        0.0     13985.0  United Kingdom
# 454463 2011-11-10 11:49:00        0.0     13081.0  United Kingdom
# 454464 2011-11-10 11:49:00        0.0     13081.0  United Kingdom
# 479079 2011-11-17 19:52:00        0.0     15602.0  United Kingdom
# 479546 2011-11-18 10:42:00        0.0     12603.0         Germany
# 480649 2011-11-18 13:23:00        0.0     12444.0          Norway
# 485985 2011-11-21 11:57:00        0.0     16406.0  United Kingdom
# 502122 2011-11-25 15:57:00        0.0     13256.0  United Kingdom

# %%
# Obtain the average price of each product

tempR = df[['Description', 'Quantity', 'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country', ]]
tempR = tempR[tempR['UnitPrice'] != 0]
#1.unit price should not be zero
tempR = tempR.groupby(by=['Description'], as_index=False).sum()
#2.group by product (as_index=False is important!!)
tempR['AvgPrice'] = tempR['UnitPrice'] / tempR['Quantity']
#3.calculate average price
tempR = tempR[['Description', 'AvgPrice']]
#4.drop all other columns
tempR
# Out:
#                            Description   AvgPrice
# 0        4 PURPLE FLOCK DINNER CANDLES   0.699097
# 1        50'S CHRISTMAS GIFT BAG LARGE   0.096853
# 2                    DOLLY GIRL BEAKER   0.110858
# 3          I LOVE LONDON MINI BACKPACK   1.043188
# 4          I LOVE LONDON MINI RUCKSACK   4.150000
# ...                                ...        ...
# 4036   ZINC T-LIGHT HOLDER STARS SMALL   0.051933
# 4037    ZINC TOP  2 DOOR WOODEN SHELF   35.628750
# 4038  ZINC WILLIE WINKIE  CANDLE STICK   0.101752
# 4039       ZINC WIRE KITCHEN ORGANISER   5.295667
# 4040  ZINC WIRE SWEETHEART LETTER TRAY   1.101928
#
# [4041 rows x 2 columns]

# %%
# Merge the average prices with missingPrices dataframe

missingPrices = pd.merge(missingPrices, tempR, left_on='Description', right_on='Description', how='left')
#1.left join
missingPrices[colName] = missingPrices['AvgPrice']
#2.update 0 values with joined value
missingPrices = missingPrices.drop(labels='AvgPrice',axis=1)
#3.drop that column from the join
missingPrices
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     537197     22841         ROUND CAKE TIN VINTAGE GREEN         1
# 1     539263     22580         ADVENT CALENDAR GINGHAM SACK         4
# 2     539722     22423             REGENCY CAKESTAND 3 TIER        10
# 3     540372     22090              PAPER BUNTING RETROSPOT        24
# 4     540372     22553               PLASTERS IN TIN SKULLS        24
# 5     541109     22168        ORGANISER WOOD ANTIQUE WHITE          1
# 6     543599    84535B         FAIRY CAKES NOTEBOOK A6 SIZE        16
# 7     547417     22062  CERAMIC BOWL WITH LOVE HEART DESIGN        36
# 8     548318     22055   MINI CAKE STAND  HANGING STRAWBERY         5
# 9     548871     22162          HEART GARLAND RUSTIC PADDED         2
# 10    550188     22636   CHILDS BREAKFAST SET CIRCUS PARADE         1
# 11    553000     47566                        PARTY BUNTING         4
# 12    554037     22619            SET OF 6 SOLDIER SKITTLES        80
# 13    561284     22167           OVAL WALL MIRROR DIAMANTE          1
# 14    561669     22960             JAM MAKING SET WITH JARS        11
# 15    561916         M                               Manual         1
# 16    562973     23157           SET OF 6 NATIVITY MAGNETS        240
# 17    564651     23270     SET OF 2 CERAMIC PAINTED HEARTS         96
# 18    564651     23268  SET OF 2 CERAMIC CHRISTMAS REINDEER       192
# 19    564651     22955             36 FOIL STAR CAKE CASES        144
# 20    564651     21786                   POLKADOT RAIN HAT        144
# 21    568158      PADS           PADS TO MATCH ALL CUSHIONS         1
# 22    568384         M                               Manual         1
# 23    569716     22778                   GLASS CLOCHE SMALL         2
# 24    571035         M                               Manual         1
# 25    572893     21208          PASTEL COLOUR HONEYCOMB FAN         5
# 26    574138     23234        BISCUIT TIN VINTAGE CHRISTMAS       216
# 27    574175     22065       CHRISTMAS PUDDING TRINKET POT         12
# 28    574252         M                               Manual         1
# 29    574469     22385            JUMBO BAG SPACEBOY DESIGN        12
# 30    574879     22625                   RED KITCHEN SCALES         2
# 31    574920     22899         CHILDREN'S APRON DOLLY GIRL          1
# 32    574920     23480       MINI LIGHTS WOODLAND MUSHROOMS         1
# 33    575579     22437        SET OF 9 BLACK SKULL BALLOONS        20
# 34    575579     22089        PAPER BUNTING VINTAGE PAISLEY        24
# 35    577129     22464          HANGING METAL HEART LANTERN         4
# 36    577168         M                               Manual         1
# 37    577314     23407       SET OF 2 TRAYS HOME SWEET HOME         2
# 38    577696         M                               Manual         1
# 39    578841     84826       ASSTD DESIGN 3D PAPER STICKERS     12540
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-05 14:02:00   3.631625     12647.0         Germany
# 1  2010-12-16 14:36:00   1.153291     16560.0  United Kingdom
# 2  2010-12-21 13:45:00   2.331486     14911.0            EIRE
# 3  2011-01-06 16:41:00   0.408109     13081.0  United Kingdom
# 4  2011-01-06 16:41:00   0.277685     13081.0  United Kingdom
# 5  2011-01-13 15:10:00   5.551154     15107.0  United Kingdom
# 6  2011-02-10 13:08:00   0.114907     17560.0  United Kingdom
# 7  2011-03-23 10:25:00   0.221615     13239.0  United Kingdom
# 8  2011-03-30 12:45:00   0.355945     13113.0  United Kingdom
# 9  2011-04-04 14:42:00   1.199644     14410.0  United Kingdom
# 10 2011-04-14 18:57:00   3.330318     12457.0     Switzerland
# 11 2011-05-12 15:21:00   0.553869     17667.0  United Kingdom
# 12 2011-05-20 14:13:00   0.845328     12415.0       Australia
# 13 2011-07-26 12:24:00   7.459655     16818.0  United Kingdom
# 14 2011-07-28 17:09:00   0.727366     12507.0           Spain
# 15 2011-08-01 11:44:00  67.885711     15581.0  United Kingdom
# 16 2011-08-11 11:42:00   0.173871     14911.0            EIRE
# 17 2011-08-26 14:19:00   0.169414     14646.0     Netherlands
# 18 2011-08-26 14:19:00   0.106825     14646.0     Netherlands
# 19 2011-08-26 14:19:00   0.306221     14646.0     Netherlands
# 20 2011-08-26 14:19:00   0.081543     14646.0     Netherlands
# 21 2011-09-25 12:22:00   0.001000     16133.0  United Kingdom
# 22 2011-09-27 09:46:00  67.885711     12748.0  United Kingdom
# 23 2011-10-06 08:17:00   1.063419     15804.0  United Kingdom
# 24 2011-10-13 12:50:00  67.885711     12446.0             RSA
# 25 2011-10-26 14:36:00   0.120189     18059.0  United Kingdom
# 26 2011-11-03 11:26:00   0.561527     12415.0       Australia
# 27 2011-11-03 11:47:00   0.041226     14110.0  United Kingdom
# 28 2011-11-03 13:24:00  67.885711     12437.0          France
# 29 2011-11-04 11:55:00   0.216708     12431.0       Australia
# 30 2011-11-07 13:22:00   3.465627     13014.0  United Kingdom
# 31 2011-11-07 16:34:00   0.376702     13985.0  United Kingdom
# 32 2011-11-07 16:34:00   0.550567     13985.0  United Kingdom
# 33 2011-11-10 11:49:00   0.082794     13081.0  United Kingdom
# 34 2011-11-10 11:49:00   0.676032     13081.0  United Kingdom
# 35 2011-11-17 19:52:00   0.215980     15602.0  United Kingdom
# 36 2011-11-18 10:42:00  67.885711     12603.0         Germany
# 37 2011-11-18 13:23:00   5.633640     12444.0          Norway
# 38 2011-11-21 11:57:00  67.885711     16406.0  United Kingdom
# 39 2011-11-25 15:57:00   0.019738     13256.0  United Kingdom

# %%
if colName == 'UnitPrice':
    df = df.drop(missingPricesIndexes)
    df = pd.concat([df, missingPrices])
df
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ..       ...       ...                                  ...       ...
# 35    577129     22464          HANGING METAL HEART LANTERN         4
# 36    577168         M                               Manual         1
# 37    577314     23407       SET OF 2 TRAYS HOME SWEET HOME         2
# 38    577696         M                               Manual         1
# 39    578841     84826       ASSTD DESIGN 3D PAPER STICKERS     12540
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00   2.550000     17850.0  United Kingdom
# 1  2010-12-01 08:26:00   3.390000     17850.0  United Kingdom
# 2  2010-12-01 08:26:00   2.750000     17850.0  United Kingdom
# 3  2010-12-01 08:26:00   3.390000     17850.0  United Kingdom
# 4  2010-12-01 08:26:00   3.390000     17850.0  United Kingdom
# ..                 ...        ...         ...             ...
# 35 2011-11-17 19:52:00   0.215980     15602.0  United Kingdom
# 36 2011-11-18 10:42:00  67.885711     12603.0         Germany
# 37 2011-11-18 13:23:00   5.633640     12444.0          Norway
# 38 2011-11-21 11:57:00  67.885711     16406.0  United Kingdom
# 39 2011-11-25 15:57:00   0.019738     13256.0  United Kingdom
#
# [539431 rows x 8 columns]

# %% [markdown]
# ## // UnitPrice is done. //

# %% [markdown]
# ## ==== Country ====
#
# - Country: Country name. Nominal, the name of the country where each customer resides.

# %%
colName = 'Country'

df[colName].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %% [markdown]
# ## // Country is done. //

# %% [markdown]
# ## ==== CustomerID ====
#
# - CustomerID: Customer number. Nominal, a 5-digit integral number uniquely assigned to each customer.

# %%
colName = 'CustomerID'

df[colName].describe()
# Out:
# count    406829.000000
# mean      15287.690570
# std        1713.600303
# min       12346.000000
# 25%       13953.000000
# 50%       15152.000000
# 75%       16791.000000
# max       18287.000000
# Name: CustomerID, dtype: float64

# %%
temp = df[df[colName].isna()]
temp
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 1443      536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444      536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445      536544     21786               POLKADOT RAIN HAT          4
# 1446      536544     21787            RAIN PONCHO RETROSPOT         2
# 1447      536544     21790               VINTAGE SNAP CARDS         9
# ...          ...       ...                              ...       ...
# 541536    581498    85099B          JUMBO BAG RED RETROSPOT         5
# 541537    581498    85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538    581498     85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539    581498     85174                S/4 CACTI CANDLES         1
# 541540    581498       DOT                   DOTCOM POSTAGE         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 1443   2010-12-01 14:32:00       2.51         NaN  United Kingdom
# 1444   2010-12-01 14:32:00       2.51         NaN  United Kingdom
# 1445   2010-12-01 14:32:00       0.85         NaN  United Kingdom
# 1446   2010-12-01 14:32:00       1.66         NaN  United Kingdom
# 1447   2010-12-01 14:32:00       1.66         NaN  United Kingdom
# ...                    ...        ...         ...             ...
# 541536 2011-12-09 10:26:00       4.13         NaN  United Kingdom
# 541537 2011-12-09 10:26:00       4.13         NaN  United Kingdom
# 541538 2011-12-09 10:26:00       4.96         NaN  United Kingdom
# 541539 2011-12-09 10:26:00      10.79         NaN  United Kingdom
# 541540 2011-12-09 10:26:00    1714.17         NaN  United Kingdom
#
# [132602 rows x 8 columns]

# %%
# because our purpose is to obtain CLV, we NEED the customerID column to be valid so that we can group by customer.
# hence, we have to remove these columns

if colName == 'CustomerID':
    df = df.drop(temp.index)
df
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ..       ...       ...                                  ...       ...
# 35    577129     22464          HANGING METAL HEART LANTERN         4
# 36    577168         M                               Manual         1
# 37    577314     23407       SET OF 2 TRAYS HOME SWEET HOME         2
# 38    577696         M                               Manual         1
# 39    578841     84826       ASSTD DESIGN 3D PAPER STICKERS     12540
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00   2.550000     17850.0  United Kingdom
# 1  2010-12-01 08:26:00   3.390000     17850.0  United Kingdom
# 2  2010-12-01 08:26:00   2.750000     17850.0  United Kingdom
# 3  2010-12-01 08:26:00   3.390000     17850.0  United Kingdom
# 4  2010-12-01 08:26:00   3.390000     17850.0  United Kingdom
# ..                 ...        ...         ...             ...
# 35 2011-11-17 19:52:00   0.215980     15602.0  United Kingdom
# 36 2011-11-18 10:42:00  67.885711     12603.0         Germany
# 37 2011-11-18 13:23:00   5.633640     12444.0          Norway
# 38 2011-11-21 11:57:00  67.885711     16406.0  United Kingdom
# 39 2011-11-25 15:57:00   0.019738     13256.0  United Kingdom
#
# [406829 rows x 8 columns]

# %% [markdown]
# ## // CustomerID is done. //

# %% [markdown]
# ## ==== StockCode ====
#
# - StockCode: Product (item) code. Nominal, a 5-digit integral number uniquely assigned to each distinct product.

# %%
colName = 'StockCode'

# Let's first view StockCodes that don't have 5 digits
df[df[colName].astype('str').str.len() != 5].sort_values(by='StockCode', ascending=True)
# Out:
#        InvoiceNo StockCode                  Description  Quantity  \
# 140929    548491    10123C        HEARTS WRAPPING TAPE          1
# 109611    545655    10123C        HEARTS WRAPPING TAPE          3
# 5451      536863    10123C        HEARTS WRAPPING TAPE          1
# 12492     537382    10124A  SPOTS ON RED BOOKCOVER TAPE         4
# 84458     543397    10124A  SPOTS ON RED BOOKCOVER TAPE         3
# ...          ...       ...                          ...       ...
# 313193    564471      POST                      POSTAGE         1
# 313215    564475      POST                      POSTAGE         1
# 313233    564476      POST                      POSTAGE         1
# 312087    564337      POST                      POSTAGE         1
# 246297    558687      POST                      POSTAGE         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 140929 2011-03-31 13:14:00       0.65     14064.0  United Kingdom
# 109611 2011-03-04 13:58:00       0.65     14670.0  United Kingdom
# 5451   2010-12-03 11:19:00       0.65     17967.0  United Kingdom
# 12492  2010-12-06 13:13:00       0.42     16710.0  United Kingdom
# 84458  2011-02-08 10:32:00       0.42     17859.0  United Kingdom
# ...                    ...        ...         ...             ...
# 313193 2011-08-25 12:26:00      18.00     12583.0          France
# 313215 2011-08-25 12:50:00      18.00     12500.0         Germany
# 313233 2011-08-25 12:57:00      40.00     12610.0           Italy
# 312087 2011-08-24 14:40:00      18.00     12649.0         Germany
# 246297 2011-07-01 11:43:00      18.00     12598.0          France
#
# [35809 rows x 8 columns]

# %%
# Hypothesis: Those 6 digit StockCodes are to indicate variants of a base product. 
# Let's see if these 6 digit-ers have a 5 digit equivalent

# Do a left join of the 6 digit-ers with the 5 digit-ers, 
# on a new column that extracts the first 5 digits of the 6 digit-ers

tempL = df[df[colName].astype('str').str.len() == 6][['StockCode', 'Description', 'Quantity']]
#1.get 6 digit-ers
#2.get the 3 relevant columns
tempL[colName+'Trunc'] = tempL[colName].str[:5].astype('int')
#3.extract first 5 digits, this will be the join column. 
#Important: must be same datatype as the other column we are joining on

tempR = df[df[colName].astype('str').str.len() == 5][['StockCode', 'Description', 'Quantity']]
tempR[colName] = tempR[colName].astype('int')
#4.create right table

pd.merge(tempL, tempR, left_on=(colName+'Trunc'), right_on=colName, how='left')
# Out:
#        StockCode_x                        Description_x  Quantity_x  \
# 0           85123A   WHITE HANGING HEART T-LIGHT HOLDER           6
# 1           84406B       CREAM CUPID HEARTS COAT HANGER           8
# 2           84029G  KNITTED UNION FLAG HOT WATER BOTTLE           6
# 3           84029E       RED WOOLLY HOTTIE WHITE HEART.           6
# 4           85123A   WHITE HANGING HEART T-LIGHT HOLDER           6
# ...            ...                                  ...         ...
# 492048      85099C       JUMBO  BAG BAROQUE BLACK WHITE          10
# 492049      84993A            75 GREEN PETIT FOUR CASES           2
# 492050      85049A        TRADITIONAL CHRISTMAS RIBBONS           1
# 492051      85049E            SCANDINAVIAN REDS RIBBONS           2
# 492052      84535B         FAIRY CAKES NOTEBOOK A6 SIZE          16
#
#         StockCodeTrunc  StockCode_y Description_y  Quantity_y
# 0                85123          NaN           NaN         NaN
# 1                84406          NaN           NaN         NaN
# 2                84029          NaN           NaN         NaN
# 3                84029          NaN           NaN         NaN
# 4                85123          NaN           NaN         NaN
# ...                ...          ...           ...         ...
# 492048           85099          NaN           NaN         NaN
# 492049           84993          NaN           NaN         NaN
# 492050           85049          NaN           NaN         NaN
# 492051           85049          NaN           NaN         NaN
# 492052           84535          NaN           NaN         NaN
#
# [492053 rows x 7 columns]

# %%
# No match...hence, we cannot merge these products directly.
# Let's observe what different products belong to each base StockCode

from collections import defaultdict
d1 = defaultdict(set)
#1.dictionary of sets

for i in range(len(tempL)):
    d1[tempL['StockCodeTrunc'].iloc[i]].add(tempL['Description'].iloc[i])
    #for every row in dataframe, add the item description to the set (value).
    #the corresponding key is the base StockCode

d = dict((k, tuple(v)) for k, v in d1.items())
d
# Out:
# {85123: ('CREAM HANGING HEART T-LIGHT HOLDER',
#   'WHITE HANGING HEART T-LIGHT HOLDER'),
#  84406: ('CREAM CUPID HEARTS COAT HANGER',),
#  84029: ('RED WOOLLY HOTTIE WHITE HEART.',
#   'KNITTED UNION FLAG HOT WATER BOTTLE'),
#  82494: ('WOODEN FRAME ANTIQUE WHITE ',),
#  85099: ('JUMBO BAG RED RETROSPOT',
#   'JUMBO BAG STRAWBERRY',
#   'JUMBO  BAG BAROQUE BLACK WHITE'),
#  84997: ('PINK 3 PIECE POLKADOT CUTLERY SET',
#   'BLUE 3 PIECE POLKADOT CUTLERY SET',
#   'RED 3 PIECE RETROSPOT CUTLERY SET',
#   'CHILDRENS CUTLERY RETROSPOT RED ',
#   'CHILDRENS CUTLERY POLKADOT GREEN ',
#   'CHILDRENS CUTLERY POLKADOT BLUE',
#   'CHILDRENS CUTLERY POLKADOT PINK',
#   'GREEN 3 PIECE POLKADOT CUTLERY SET'),
#  84519: ('CARROT CHARLIE+LOLA COASTER SET', 'TOMATO CHARLIE+LOLA COASTER SET'),
#  85183: ('CHARLIE & LOLA WASTEPAPER BIN BLUE',
#   'CHARLIE & LOLA WASTEPAPER BIN FLORA'),
#  85071: ('CHARLIE+LOLA"EXTREMELY BUSY" SIGN',
#   'BLUE CHARLIE+LOLA PERSONAL DOORSIGN',
#   'CHARLIE+LOLA MY ROOM DOOR SIGN',
#   'RED CHARLIE+LOLA PERSONAL DOORSIGN'),
#  37444: ('PINK BREAKFAST CUP AND SAUCER ',
#   'YELLOW BREAKFAST CUP AND SAUCER',
#   'BLUE BREAKFAST CUP AND SAUCER '),
#  84971: ('SMALL HEART FLOWERS HOOK ',),
#  15056: ('EDWARDIAN PARASOL PINK', 'EDWARDIAN PARASOL NATURAL'),
#  35004: ('SET OF 3 GOLD FLYING DUCKS',
#   'SET OF 3 COLOURED  FLYING DUCKS',
#   'SET OF 3 PINK FLYING DUCKS',
#   'SET OF 3 BLACK FLYING DUCKS'),
#  85049: ('URBAN BLACK RIBBONS ',
#   'TRADITIONAL CHRISTMAS RIBBONS',
#   'ROMANTIC PINKS RIBBONS ',
#   'BABY BOOM RIBBONS ',
#   'LUSH GREENS RIBBONS',
#   'BRIGHT BLUES RIBBONS ',
#   'SCANDINAVIAN REDS RIBBONS',
#   'CHOCOLATE BOX RIBBONS '),
#  85014: ('RED RETROSPOT UMBRELLA', 'BLACK/BLUE POLKADOT UMBRELLA'),
#  84970: ('HANGING HEART ZINC T-LIGHT HOLDER',
#   'SINGLE HEART ZINC T-LIGHT HOLDER'),
#  84030: ('ENGLISH ROSE HOT WATER BOTTLE',),
#  17091: ('LAVENDER INCENSE IN TIN', 'VANILLA INCENSE IN TIN'),
#  84509: ('SET OF 4 FAIRY CAKE PLACEMATS',
#   'SET OF 4 ENGLISH ROSE PLACEMATS',
#   'SET OF 4 POLKADOT PLACEMATS ',
#   'SET OF 4 FAIRY CAKE PLACEMATS ',
#   'SET OF 4 CAROUSEL PLACEMATS '),
#  84510: ('SET OF 4 ENGLISH ROSE COASTERS',
#   'SET OF 4 GREEN CAROUSEL COASTERS',
#   'SET OF 4 POLKADOT COASTERS'),
#  84709: ('PINK OVAL JEWELLED MIRROR',),
#  84625: ('PINK NEW BAROQUECANDLESTICK CANDLE',
#   'BLUE NEW BAROQUE CANDLESTICK CANDLE'),
#  47570: ('TEA TIME TABLE CLOTH',),
#  90199: ('5 STRAND GLASS NECKLACE BLACK',
#   '5 STRAND GLASS NECKLACE CRYSTAL',
#   '5 STRAND GLASS NECKLACE AMETHYST',
#   '5 STRAND GLASS NECKLACE AMBER'),
#  90129: ('PINK GLASS TASSLE BAG CHARM ',
#   'PURPLE GLASS TASSLE BAG CHARM',
#   'TURQUOISE GLASS TASSLE BAG CHARM ',
#   'AMBER GLASS TASSLE BAG CHARM',
#   'RED GLASS TASSLE BAG CHARM',
#   'GREEN GLASS TASSLE BAG CHARM'),
#  90210: ('RED   ACRYLIC FACETED BANGLE',
#   'PURPLE ACRYLIC FACETED BANGLE',
#   'GREY ACRYLIC FACETED BANGLE',
#   'CLEAR ACRYLIC FACETED BANGLE'),
#  72802: ('ROSE SCENT CANDLE IN JEWELLED BOX',
#   'OCEAN SCENT CANDLE IN JEWELLED BOX',
#   'VANILLA SCENT CANDLE JEWELLED BOX'),
#  85169: ('BLACK LOVE BIRD CANDLE',
#   'IVORY LOVE BIRD CANDLE',
#   'EAU DE NIL LOVE BIRD CANDLE',
#   'PINK LOVE BIRD CANDLE'),
#  85184: ('S/4 VALENTINE DECOUPAGE HEART BOX',
#   'SET 4 VALENTINE DECOUPAGE HEART BOX'),
#  35591: ('TURQUOISE CHRISTMAS TREE ',),
#  84032: ('CHARLIE+LOLA PINK HOT WATER BOTTLE',
#   'CHARLIE + LOLA RED HOT WATER BOTTLE'),
#  72800: ('4 BLUE DINNER CANDLES SILVER FLOCK',
#   '4 PINK DINNER CANDLE SILVER FLOCK',
#   '4 IVORY DINNER CANDLES SILVER FLOCK',
#   ' 4 PURPLE FLOCK DINNER CANDLES'),
#  84849: ('FAIRY SOAP SOAP HOLDER',
#   'HELLO SAILOR BLUE SOAP HOLDER',
#   'HOT BATHS SOAP HOLDER'),
#  90200: ('PINK SWEETHEART BRACELET',
#   'BLUE SWEETHEART BRACELET',
#   'PURPLE SWEETHEART BRACELET',
#   'GREEN SWEETHEART BRACELET',
#   'BLACK SWEETHEART BRACELET'),
#  90059: ('DIAMANTE HAIR GRIP PACK/2 MONTANA',
#   'DIAMANTE HAIR GRIP PACK/2 PERIDOT',
#   'DIAMANTE HAIR GRIP PACK/2 CRYSTAL',
#   'DIAMANTE HAIR GRIP PACK/2 BLACK DIA',
#   'DIAMANTE HAIR GRIP PACK/2 RUBY',
#   'DIAMANTE HAIR GRIP PACK/2 LT ROSE'),
#  90185: ('AMETHYST DIAMANTE EXPANDABLE RING',
#   'CRYSTAL DIAMANTE EXPANDABLE RING',
#   'AMBER DIAMANTE EXPANDABLE RING',
#   'BLACK DIAMANTE EXPANDABLE RING'),
#  16258: ('SWIRLY CIRCULAR RUBBERS IN BAG',),
#  85231: ('ORANGE SCENTED SET/9 T-LIGHTS', 'CINAMMON SET OF 9 T-LIGHTS'),
#  48173: ('DOORMAT BLACK FLOCK ',),
#  47563: ('RETRO LONGBOARD IRONING BOARD COVER',),
#  84558: ('3D DOG PICTURE PLAYING CARDS',),
#  46000: ('POLYESTER FILLER PAD 45x30cm',
#   'POLYESTER FILLER PAD 40x40cm',
#   'POLYESTER FILLER PAD 30CMx30CM',
#   'POLYESTER FILLER PAD 45x45cm',
#   'POLYESTER FILLER PAD 65CMx65CM'),
#  71406: ('BLACK ORANGE SQUEEZER',),
#  84985: ('SET OF 72 GREEN PAPER DOILIES',),
#  84596: ('SMALL CHOCOLATES PINK BOWL',
#   'BISCUITS SMALL BOWL LIGHT BLUE',
#   'SMALL LICORICE DES PINK BOWL',
#   'SMALL DOLLY MIX DESIGN ORANGE BOWL',
#   'MIXED NUTS LIGHT GREEN BOWL',
#   'SMALL MARSHMALLOWS PINK BOWL'),
#  47599: ('PINK PARTY BAGS', 'BLUE PARTY BAGS '),
#  85035: ('GARDENIA 3 WICK MORRIS BOXED CANDLE',
#   'ROSE 3 WICK MORRIS BOX CANDLE',
#   'CHOCOLATE 3 WICK MORRIS BOX CANDLE'),
#  84968: ('SET OF 16 VINTAGE PISTACHIO CUTLERY',
#   'SET OF 16 VINTAGE ROSE CUTLERY',
#   'SET OF 16 VINTAGE BLACK CUTLERY',
#   'SET OF 16 VINTAGE SKY BLUE CUTLERY',
#   'SET OF 16 VINTAGE IVORY CUTLERY',
#   'SET OF 16 VINTAGE RED CUTLERY'),
#  84563: ('PINK & WHITE BREAKFAST TRAY', 'BLUE & WHITE BREAKFAST TRAY'),
#  47504: ('ENGLISH ROSE GARDEN SECATEURS', 'ENGLISH ROSE SPIRIT LEVEL '),
#  17164: ("ASS COL SMALL SAND GECKO P'WEIGHT",),
#  15044: ('RED PAPER PARASOL',
#   'PURPLE PAPER PARASOL',
#   'BLUE PAPER PARASOL ',
#   'PINK PAPER PARASOL '),
#  84569: ('PACK 6 HEART/ICE-CREAM PATCHES',
#   'PACK 3 IRON ON DOG PATCHES',
#   'PACK 4 FLOWER/BUTTERFLY PATCHES',
#   'PACK 3 FIRE ENGINE/CAR PATCHES'),
#  85114: ('RED ENCHANTED FOREST PLACEMAT',
#   'IVORY ENCHANTED FOREST PLACEMAT',
#   'BLACK ENCHANTED FOREST PLACEMAT'),
#  85199: ('SMALL HANGING IVORY/RED WOOD BIRD',
#   'LARGE HANGING IVORY & RED WOOD BIRD'),
#  85019: ('CURIOUS  IMAGES NOTEBOOK SET',
#   'ROMANTIC IMAGES NOTEBOOK SET',
#   'BLOSSOM  IMAGES NOTEBOOK SET'),
#  85135: ('BLUE DRAGONFLY HELICOPTER',
#   'YELLOW DRAGONFLY HELICOPTER',
#   'RED DRAGONFLY HELICOPTER'),
#  85136: ('RED SHARK HELICOPTER',
#   'YELLOW SHARK HELICOPTER',
#   'BLUE SHARK HELICOPTER'),
#  79144: ('PAINTED LIGHTBULB STAR+ MOON', 'PAINTED LIGHTBULB RAINBOW DESIGN'),
#  84508: ('CAMOUFLAGE DESIGN TEDDY',
#   'STRIPES DESIGN TEDDY',
#   'BLUE CIRCLES DESIGN TEDDY'),
#  85232: ('SET/3 DECOUPAGE STACKING TINS',
#   'SET OF 3 BABUSHKA STACKING TINS',
#   'SET/3 POLKADOT STACKING TINS'),
#  79066: ('RETRO MOD TRAY',),
#  84884: ('ANT WHITE WIRE HEART SPIRAL',),
#  51014: ('FEATHER PEN,HOT PINK',
#   'FEATHER PEN,COAL BLACK',
#   'FEATHER PEN,LIGHT PINK'),
#  79302: ('ART LIGHTS,FUNK MONKEY',),
#  84870: ('GREEN GEISHA GIRL ', 'BLUE GEISHA GIRL '),
#  85032: ('BLOSSOM IMAGES GIFT WRAP SET',
#   'CURIOUS IMAGES GIFT WRAP SET',
#   'ROMANTIC IMAGES GIFT WRAP SET',
#   'YULETIDE IMAGES GIFT WRAP SET'),
#  84760: ('SMALL HANGING GLASS+ZINC LANTERN',),
#  35598: ('BLACK CHRISTMAS TREE 60CM',
#   'DUSTY PINK CHRISTMAS TREE 60CM',
#   'PINK/WHITE CHRISTMAS TREE 60CM',
#   'WHITE CHRISTMAS TREE 60CM'),
#  84031: ('CHARLIE LOLA BLUE HOT WATER BOTTLE ',
#   'CHARLIE+LOLA RED HOT WATER BOTTLE '),
#  90214: ('LETTER "F" BLING KEY RING',
#   'LETTER "A" BLING KEY RING',
#   'LETTER "T" BLING KEY RING',
#   'LETTER "U" BLING KEY RING',
#   'LETTER "P" BLING KEY RING',
#   'LETTER "W" BLING KEY RING',
#   'LETTER "D" BLING KEY RING',
#   'LETTER "Y" BLING KEY RING',
#   'LETTER "C" BLING KEY RING',
#   'LETTER "R" BLING KEY RING',
#   'LETTER "J" BLING KEY RING',
#   'LETTER "Z" BLING KEY RING',
#   'LETTER "I" BLING KEY RING',
#   'LETTER "O" BLING KEY RING',
#   'LETTER "E" BLING KEY RING',
#   'LETTER "N" BLING KEY RING',
#   'LETTER "L" BLING KEY RING',
#   'LETTER "K" BLING KEY RING',
#   'LETTER "V" BLING KEY RING',
#   'LETTER "M" BLING KEY RING',
#   'LETTER "H" BLING KEY RING',
#   'LETTER "S" BLING KEY RING',
#   'LETTER "B" BLING KEY RING',
#   'LETTER "G" BLING KEY RING'),
#  72807: ('SET/3 VANILLA SCENTED CANDLE IN BOX',
#   'SET/3 ROSE CANDLE IN JEWELLED BOX',
#   'SET/3 OCEAN SCENT CANDLE JEWEL BOX'),
#  47591: ('SCOTTIES CHILDRENS APRON', 'PINK FAIRY CAKE CHILDRENS APRON'),
#  72803: ('ROSE SCENT CANDLE JEWELLED DRAWER',),
#  85034: ('3 GARDENIA MORRIS BOXED CANDLES',
#   '3 ROSE MORRIS BOXED CANDLES',
#   '3 WHITE CHOC MORRIS BOXED CANDLES'),
#  72798: ('SET/4 GARDEN ROSE DINNER CANDLE',),
#  35271: ('GOLD PRINT PAPER BAG',),
#  47567: ('TEA TIME KITCHEN APRON',),
#  72760: ('VINTAGE CREAM 3 BASKET CAKE STAND',),
#  62096: ('PINK/YELLOW FLOWERS HANDBAG', 'PURPLE/TURQ FLOWERS HANDBAG'),
#  79191: ('RETRO PLASTIC DAISY TRAY',
#   'RETRO PLASTIC ELEPHANT TRAY',
#   'RETRO PLASTIC POLKA TRAY'),
#  47566: ('TEA TIME PARTY BUNTING',),
#  47590: ('BLUE HAPPY BIRTHDAY BUNTING', 'PINK HAPPY BIRTHDAY BUNTING'),
#  85061: ('WHITE JEWELLED HEART DECORATION',),
#  84341: ('SMALL PINK MAGIC CHRISTMAS TREE',),
#  84846: ('SCENTED CANDLE IN DIGITALIS TIN',),
#  85132: ('CHARLIE AND LOLA TABLE TINS',
#   'CHARLIE AND LOLA FIGURES TINS',
#   'CHARLIE + LOLA BISCUITS TINS'),
#  85159: ('WHITE TEA,COFFEE,SUGAR JARS', 'BLACK TEA,COFFEE,SUGAR JARS'),
#  17090: ('VANILLA INCENSE 40 CONES IN TIN',
#   'LAVENDER INCENSE 40 CONES IN TIN'),
#  10124: ('SPOTS ON RED BOOKCOVER TAPE', 'ARMY CAMO BOOKCOVER TAPE'),
#  90175: ('WHITE GLASS CHUNKY CHARM BRACELET',
#   'TIGRIS EYE CHUNKY CHARM BRACELET',
#   'BLUE GLASS CHUNKY CHARM BRACELET'),
#  90180: ('BLACK+WHITE NECKLACE W TASSEL', 'PURPLE AMETHYST NECKLACE W TASSEL'),
#  90178: ('PURPLE CHUNKY GLASS+BEAD NECKLACE',
#   'AMBER CHUNKY GLASS+BEAD NECKLACE'),
#  85025: ('EAU DE NILE HEART SHAPE PHOTO FRAME',
#   'PINK HEART SHAPE PHOTO FRAME'),
#  85124: ('BLUE JUICY FRUIT PHOTO FRAME', 'GREEN JUICY FRUIT PHOTO FRAME'),
#  16156: ('WRAP, CAROUSEL', 'WRAP CAROUSEL', 'WRAP PINK FAIRY CAKES '),
#  90082: ('DIAMANTE BOW BROOCH GREEN COLOUR',
#   'DIAMANTE BOW BROOCH BLACK COLOUR',
#   'DIAMANTE BOW BROOCH RED COLOUR'),
#  90081: ('LILY BROOCH OLIVE COLOUR', 'LILY BROOCH AMETHYST COLOUR'),
#  90195: ('PURPLE GEMSTONE BRACELET', 'BLACK GEMSTONE BRACELET'),
#  90196: ('BLACK GEMSTONE NECKLACE 45CM', 'PURPLE GEMSTONE NECKLACE 45CM'),
#  90177: ('DROP DIAMANTE EARRINGS CRYSTAL',
#   'DROP DIAMANTE EARRINGS PURPLE',
#   'DROP DIAMANTE EARRINGS GREEN',
#   'DROP DIAMANTE EARRINGS BLACK DIAMON',
#   'CLASSIC DIAMANTE EARRINGS JET'),
#  90186: ('CRYSTAL HOOP EARRING FLORAL LEAF',
#   'AMETHYST HOOP EARRING FLORAL LEAF'),
#  18097: ('WHITE TALL PORCELAIN T-LIGHT HOLDER',
#   'PINK TALL PORCELAIN T-LIGHT HOLDER '),
#  85185: ('PINK HORSE SOCK PUPPET',
#   'PINK HORSE SOCK PUPPET KIT',
#   'FROG SOCK PUPPET'),
#  15060: ('FAIRY CAKE DESIGN UMBRELLA',),
#  72801: ('4 ROSE PINK DINNER CANDLES',
#   '4 BURGUNDY WINE DINNER CANDLES',
#   '4 SKY BLUE DINNER CANDLES'),
#  84952: ('BLACK LOVE BIRD T-LIGHT HOLDER',
#   'CLEAR LOVE BIRD T-LIGHT HOLDER',
#   'MIRROR LOVE BIRD T-LIGHT HOLDER'),
#  35001: ('HAND OPEN SHAPE DECO.WHITE', 'HAND OPEN SHAPE GOLD'),
#  90002: ('FLOWER BURST SILVER RING CRYSTAL',),
#  72799: ('IVORY PILLAR CANDLE SILVER FLOCK',
#   'PINK PILLAR CANDLE SILVER FLOCK',
#   'IVORY PILLAR CANDLE GOLD FLOCK'),
#  47559: ('TEA TIME OVEN GLOVE',),
#  16161: ('WRAP BAD HAIR DAY',
#   'WRAP  PINK FLOCK',
#   'WRAP SUKI AND FRIENDS',
#   'WRAP ENGLISH ROSE '),
#  84247: ('FOLK ART GREETING CARD,pack/12',
#   'FAWN AND MUSHROOM GREETING CARD',
#   'DECOUPAGE,GREETING CARD,',
#   'PACK OF 12 CHRISTMAS FUN CARDS',
#   'PACK/12 XMAS FUN CARD',
#   'PACK/12 BLUE FOLKART CARDS'),
#  47021: ('SET/6 BEAD COASTERS GAUZE BAG GOLD',),
#  85131: ('BEADED CRYSTAL HEART GREEN ON STICK',
#   'BEADED PEARL HEART WHITE ON STICK',
#   'BEADED CRYSTAL HEART PINK ON STICK',
#   'BEADED CRYSTAL HEART BLUE ON STICK'),
#  10123: ('HEARTS WRAPPING TAPE ',),
#  84993: ('75 GREEN PETIT FOUR CASES', '75 BLACK PETIT FOUR CASES'),
#  84925: ('PSYCHEDELIC WALL THERMOMETER', 'LA PALMIERA WALL THERMOMETER'),
#  84520: ('PACK 20 ENGLISH ROSE PAPER NAPKINS',),
#  17084: ('DRAGONS BLOOD INCENSE',
#   'FAIRY DREAMS INCENSE ',
#   'TRANQUILITY MASALA INCENSE',
#   'ASSORTED INCENSE PACK',
#   'LOVE POTION MASALA INCENSE'),
#  85018: ('YULETIDE IMAGES S/6 PAPER BOXES',),
#  47503: ('ASS FLORAL PRINT SPIRIT LEVEL ',
#   'SET/3 FLORAL GARDEN TOOLS IN BAG',
#   'ASS FLORAL PRINT MULTI SCREWDRIVER'),
#  37489: ('YELLOW/PINK FLOWER DESIGN BIG MUG',
#   'GREEN/BLUE FLOWER DESIGN BIG MUG',
#   'BLUE/YELLOW FLOWER DESIGN BIG MUG',
#   'PINK/GREEN FLOWER DESIGN BIG MUG'),
#  17107: ('FLOWER FAIRY 5 SUMMER DRAW LINERS',
#   "FLOWER FAIRY,5 SUMMER B'DRAW LINERS",
#   'FLOWER FAIRY 5 DRAWER LINERS'),
#  84534: ('FAIRY CAKE NOTEBOOK A5 SIZE',),
#  84536: ('FAIRY CAKES NOTEBOOK A7 SIZE', 'ENGLISH ROSE NOTEBOOK A7 SIZE'),
#  85130: ('BEADED PEARL HEART WHITE LARGE',
#   'BEADED CRYSTAL HEART BLUE  LARGE',
#   'BEADED CRYSTAL HEART GREEN LARGE',
#   'BEADED CRYSTAL HEART PINK LARGE'),
#  85129: ('BEADED CRYSTAL HEART PINK SMALL',
#   'BEADED CRYSTAL HEART BLUE SMALL',
#   'BEADED CRYSTAL HEART GREEN SMALL'),
#  84559: ('3D SHEET OF CAT STICKERS', '3D SHEET OF DOG STICKERS'),
#  85230: ('STRAWBRY SCENTED VOTIVE CANDLE',
#   'CINNAMON SCENTED VOTIVE CANDLE',
#   'ORANGE VOTIVE CANDLE',
#   'OPIUM SCENTED VOTIVE CANDLE',
#   'JASMINE VOTIVE CANDLE'),
#  84507: ('BLUE CIRCLES DESIGN MONKEY DOLL', 'STRIPES DESIGN MONKEY DOLL'),
#  82616: ('FRAPPUCINO SCARF KNITTING KIT',
#   'MIDNIGHT GLAMOUR SCARF KNITTING KIT'),
#  90128: ('BLUE LEAVES AND BEADS PHONE CHARM',),
#  90198: ('VINTAGE ROSE BEAD BRACELET BLACK',
#   'VINTAGE ROSE BEAD BRACELET RASPBERR'),
#  90152: ('BLUE/GREEN SHELL NECKLACE W PENDANT',
#   'SILVER/NAT SHELL NECKLACE W PENDANT',
#   'BLUE/NAT SHELL NECKLACE W PENDANT'),
#  84877: ('BLUE ROUND COMPACT MIRROR',
#   'GREEN ROUND COMPACT MIRROR',
#   'PINK ROUND COMPACT MIRROR'),
#  47343: ('FUSCHIA FLOWER PURSE WITH BEADS',),
#  84562: ('PINK/WHITE RIBBED MELAMINE JUG',),
#  82011: ('BATHROOM SCALES FOOTPRINTS IN SAND',
#   'BATHROOM SCALES RUBBER DUCKS',
#   'BATHROOM SCALES, TROPICAL BEACH'),
#  85036: ('ROSE 1 WICK MORRIS BOXED CANDLE',
#   'GARDENIA 1 WICK MORRIS BOXED CANDLE',
#   'CHOCOLATE 1 WICK MORRIS BOX CANDLE'),
#  84614: ('PINK BAROQUE FLOCK CANDLE HOLDER',),
#  84924: ('PSYCHEDELIC METAL SIGN CALENDAR', 'WAKE UP COCKEREL CALENDAR SIGN '),
#  35810: ('ENAMEL PINK COFFEE CONTAINER', 'ENAMEL BLUE RIM COFFEE CONTAINER'),
#  17109: ('FLOWER FAIRY INCENSE BOUQUET',),
#  90162: ('ANT SILVER FUSCHIA BOUDICCA RING',
#   'ANT SILVER TURQUOISE BOUDICCA RING',
#   'ANT SILVER LIME GREEN BOUDICCA RING',
#   'ANT SILVER PURPLE BOUDICCA RING'),
#  84898: ('YELLOW FLOWERS FELT HANDBAG KIT',),
#  47310: ('SMALL POP BOX FUNKY MONKEY', 'SMALL POP BOX,FUNKY MONKEY'),
#  84279: ('CHERRY BLOSSOM DECORATIVE FLASK',
#   'CHERRY BLOSSOM  DECORATIVE FLASK'),
#  84963: ('BLUE PAINTED KASHMIRI CHAIR', 'PINK PAINTED KASHMIRI CHAIR'),
#  72349: ('SET/6 PURPLE BUTTERFLY T-LIGHTS',),
#  85206: ('PINK FELT EASTER EGG BASKET', 'CREAM FELT EASTER EGG BASKET'),
#  77101: ('UNION FLAG WINDSOCK',),
#  79149: ('SILICON STAR BULB  BLUE',),
#  78034: ('BLUE NETTING STORAGE HANGER',),
#  79151: ('SILICON CUBE 25W, BLUE',),
#  35471: ('SET OF 3 BIRD LIGHT PINK FEATHER ',),
#  72351: ('SET/6 TURQUOISE BUTTERFLY T-LIGHTS',
#   'SET/6 PINK  BUTTERFLY T-LIGHTS'),
#  85179: ('GREEN BITTY LIGHT CHAIN', 'PINK BITTY LIGHT CHAIN'),
#  84874: ('BLUE TRAVEL FIRST AID KIT',),
#  85167: ('BLACK GRAND BAROQUE PHOTO FRAME',),
#  72051: ('BAG OF SILVER STONES',),
#  84535: ('FAIRY CAKES NOTEBOOK A6 SIZE', 'ENGLISH ROSE NOTEBOOK A6 SIZE'),
#  75013: ('STRING OF 8 BUTTERFLIES,PINK',),
#  82613: ('METAL SIGN CUPCAKE SINGLE HOOK', 'METAL SIGN,CUPCAKE SINGLE HOOK'),
#  79190: ("RETRO PLASTIC 70'S TRAY",
#   'RETRO PLASTIC DAISY TRAY',
#   'RETRO PLASTIC POLKA TRAY'),
#  47593: ('CAROUSEL PONIES BABY BIB', 'SCOTTIE DOGS BABY BIB'),
#  47369: ('BLUE GREEN EMBROIDERY COSMETIC BAG',
#   'PINK GREEN EMBROIDERY COSMETIC BAG'),
#  47367: ('PAIR PADDED HANGERS PINK CHECK',),
#  84597: ('RETRO PINK BALL ASHTRAY ', 'RETRO BROWN BALL ASHTRAY '),
#  51020: ('SUMMER FUN DESIGN SHOWER CAP', 'STRIPY DESIGN SHOWER CAP'),
#  18098: ('PORCELAIN BUTTERFLY OIL BURNER',),
#  85170: ('SET/6 BLACK BIRD T-LIGHT CANDLES',
#   'SET/6 EAU DE NIL BIRD T-LIGHTS',
#   'SET/6 PINK BIRD T-LIGHT CANDLES',
#   'SET/6 IVORY BIRD T-LIGHT CANDLES'),
#  84531: ('BLUE KNITTED EGG COSY', 'PINK KNITTED EGG COSY'),
#  84809: ('WHITE CHRYSANTHEMUMS ART FLOWER', 'PINK CHRYSANTHEMUMS ART FLOWER'),
#  84795: ('SUNSET CHECK HAMMOCK', 'OCEAN STRIPE HAMMOCK '),
#  85027: ('FRENCH CHATEAU LARGE PLATTER ',),
#  85017: ('ENVELOPE 50 BLOSSOM IMAGES',
#   'ENVELOPE 50 ROMANTIC IMAGES',
#   'ENVELOPE 50 CURIOUS IMAGES'),
#  84707: ('SILVER JEWELLED MIRROR TRINKET TRAY',
#   'PINK JEWELLED MIRROR TRINKET TRAY'),
#  79030: ('TUMBLER, BAROQUE',
#   'TUMBLER NEW ENGLAND',
#   'TUMBLER BAROQUE',
#   'TUMBLER, NEW ENGLAND'),
#  37479: ('CUBIC MUG FLOCK PINK ON BROWN', 'CUBIC MUG FLOCK BLUE ON BROWN'),
#  37482: ('CUBIC MUG PINK POLKADOT',),
#  47594: ('SCOTTIES DESIGN WASHBAG', 'CAROUSEL DESIGN WASHBAG'),
#  84926: ('PSYCHEDELIC TILE COASTER',
#   'WAKE UP COCKEREL TILE COASTER',
#   'FLOWERS TILE COASTER',
#   'LA PALMIERA TILE COASTER'),
#  84711: ('PINK OVAL SHAPE TRINKET BOX', 'SILVER OVAL SHAPE TRINKET BOX'),
#  16169: ('WRAP BLUE RUSSIAN FOLKART',
#   'WRAP FOLK ART',
#   'WRAP GREEN RUSSIAN FOLKART ',
#   'WRAP DAISY CARPET ',
#   "WRAP 50'S  CHRISTMAS"),
#  35597: ('PINK/WHITE CHRISTMAS TREE 30CM',
#   'DUSTY PINK CHRISTMAS TREE 30CM',
#   'BLACKCHRISTMAS TREE 30CM'),
#  84912: ('GREEN ROSE WASHBAG', 'PINK ROSE WASHBAG'),
#  90179: ('AMBER FINE BEAD NECKLACE W TASSEL',
#   'BLACK FINE BEAD NECKLACE W TASSEL'),
#  90060: ('FIRE POLISHED GLASS NECKL GOLD', 'FIRE POLISHED GLASS NECKL BRONZE'),
#  79051: ('SMOKEY GREY COLOUR D.O.F. GLASS', 'SMOKEY GREY COLOUR GLASS'),
#  17007: ('S/3 POT POURI CUSHIONS BLUE COLOURS',),
#  40005: ('BLUE ORGANDY ROUND LAMPSHADE W BEA',),
#  18094: ('WHITE AND BLUE CERAMIC OIL BURNER',),
#  47586: ('PINK FAIRY CAKE CUSHION COVER',),
#  46115: ('GREEN POP ART MAO CUSHION COVER ',),
#  47574: ('ENGLISH ROSE SCENTED HANGING FLOWER',
#   'ENGLISH ROSE SCENTED HANGING HEART'),
#  85026: ('EAU DE NILE JEWELLED T-LIGHT HOLDER',),
#  82001: ('SILVER RECORD COVER FRAME', 'VINYL RECORD FRAME SILVER'),
#  90212: ('JET BLACK LAS VEGAS BRACELET ROUND',
#   'PURPLE LAS VEGAS BRACELET ROUND'),
#  47348: ('FUSCHIA VOILE POINTY SHOE DEC',),
#  85039: ('S/4 BLACK MINI ROSE CANDLE IN BOWL',
#   'S/4 IVORY MINI ROSE CANDLE IN BOWL',
#   'SET/4 RED MINI ROSE CANDLE IN BOWL'),
#  85024: ('EAU DE NILE JEWELLED PHOTOFRAME', 'PINK SMALL JEWELLED PHOTOFRAME'),
#  84613: ('BLUE NEW BAROQUE FLOCK CANDLESTICK',
#   'PINK NEW BAROQUE FLOCK CANDLESTICK'),
#  84910: ('PINK PAISLEY CUSHION COVER ',),
#  16202: ('PASTEL BLUE PHOTO ALBUM ',
#   'PASTEL PINK PHOTO ALBUM ',
#   'BLACK PHOTO ALBUM '),
#  90184: ('BLACK CHUNKY BEAD BRACELET W STRAP',
#   'AMETHYST CHUNKY BEAD BRACELET W STR',
#   'AMBER CHUNKY BEAD BRACELET W STRAP'),
#  84415: ('BLUE FLOCK CUSHION COVER ', 'PINK FLOCK SUEDE CUSHION COVER '),
#  71496: ('A4 WALL TIDY RED FLOWERS', 'A4 WALL TIDY BLUE OFFICE'),
#  71495: ('CD WALL TIDY RED FLOWERS', 'CD WALL TIDY BLUE OFFICE'),
#  35833: ('4 PINK FLOCK CHRISTMAS BALLS',),
#  16168: ('FUNKY MONKEY GIFT BAG MEDIUM',),
#  84706: ('RED PEONY TABLE CLOCK', 'CHERRY BLOSSOM TABLE CLOCK '),
#  84875: ('BLUE SQUARE COMPACT MIRROR', 'GREEN SQUARE COMPACT MIRROR'),
#  84876: ('BLUE HEART COMPACT MIRROR', 'GREEN HEART COMPACT MIRROR'),
#  90211: ('DIAMOND LAS VEGAS NECKLACE 45CM',
#   'JET BLACK LAS VEGAS NECKLACE 45CM'),
#  90036: ('FLOWER GLASS GARLAND NECKL.36"BLUE',
#   'FLOWER GLASS GARLD NECKL36"AMETHYST',
#   'FLOWER GLASS GARLAND NECKL.36"BLACK',
#   'FLOWER GARLAND NECKLACE RED',
#   'FLOWER GLASS GARLAND NECKL.36"GREEN',
#   'FLOWER GLASS GARLD NECKL36"TURQUOIS'),
#  85040: ('SET/4 BLUE FLOWER CANDLES IN BOWL',
#   'S/4 PINK FLOWER CANDLES IN BOWL'),
#  84798: ('PURPLE FOXGLOVE ARTIIFCIAL FLOWER',
#   'PINK FOXGLOVE ARTIIFCIAL FLOWER'),
#  84913: ('MINT GREEN ROSE TOWEL', 'SOFT PINK ROSE TOWEL '),
#  47578: ('ENGLISH ROSE SMALL SCENTED FLOWER',),
#  84951: ('SET OF 4 PISTACHIO LOVEBIRD COASTER',
#   'SET OF 4 BLACK LOVEBIRD COASTERS'),
#  17165: ("ASS COL LARGE SAND FROG P'WEIGHT",),
#  15058: ('BLUE POLKADOT GARDEN PARASOL',
#   'ICE CREAM DESIGN GARDEN PARASOL',
#   'PINK POLKADOT GARDEN PARASOL'),
#  84595: ('LARGE TORTILLA DESIGN RED BOWL',),
#  84459: ('PINK METAL CHICKEN HEART ', 'YELLOW METAL CHICKEN HEART '),
#  35915: ('BLUE KNITTED HEN ', 'PEACH KNITTED HEN '),
#  85086: ('CANDY SPOT HEART DECORATION',),
#  81950: ('FLOWER BLUE CLOCK WITH SUCKER',
#   'FLOWER PURPLE CLOCK WITH SUCKER',
#   'FLOWER PURPLE CLOCK W/SUCKER'),
#  17012: ('ORIGAMI OPIUM INCENSE/CANDLE SET ',
#   'ORIGAMI SANDLEWOOD INCENSE/CAND SET',
#   'ORIGAMI VANILLA INCENSE/CANDLE SET ',
#   'ORIGAMI ROSE INCENSE/CANDLE SET ',
#   'ORIGAMI JASMINE INCENSE/CANDLE SET',
#   'ORIGAMI LAVENDER INCENSE/CANDL SET '),
#  90190: ('GOLD/AMBER DROP EARRINGS W LEAF',
#   'SILVER/CRYSTAL DROP EARRINGS W LEAF',
#   'SILVER/AMETHYST DROP EARRINGS LEAF'),
#  90003: ('GREEN PAIR HEART HAIR SLIDES',
#   'CRYSTAL PAIR HEART HAIR SLIDES',
#   'ROSE COLOUR PAIR HEART HAIR SLIDES',
#   'MIDNIGHT BLUE PAIR HEART HAIR SLIDE'),
#  90067: ('PINK VINTAGE VICTORIAN EARRINGS',),
#  85031: ('BLOSSOM IMAGES SCRAP BOOK SET',
#   'ROMANTIC IMAGES SCRAP BOOK SET',
#   'CURIOUS IMAGES SCRAP BOOK SET'),
#  84660: ('WHITE STITCHED WALL CLOCK',
#   'PINK STITCHED WALL CLOCK',
#   'BLACK STITCHED WALL CLOCK'),
#  90160: ('PURPLE BOUDICCA LARGE BRACELET',
#   'PINK BOUDICCA LARGE BRACELET',
#   'RED BOUDICCA LARGE BRACELET',
#   'TURQ+RED BOUDICCA LARGE BRACELET'),
#  90161: ('ANT COPPER LIME BOUDICCA BRACELET',
#   'ANT COPPER TURQ BOUDICCA BRACELET',
#   'ANT COPPER PINK BOUDICCA BRACELET',
#   'ANT COPPER RED BOUDICCA BRACELET'),
#  35610: ('PINK CHRISTMAS FLOCK DROPLET ',
#   'WHITE CHRISTMAS FLOCK DROPLET ',
#   'BLACK CHRISTMAS FLOCK DROPLET '),
#  84927: ('WAKE UP COCKEREL TILE HOOK',
#   'PSYCHEDELIC TILE HOOK',
#   'FLOWERS TILE HOOK',
#   'LA PALMIERA TILE HOOK'),
#  90120: ('WHITE MURANO TWIST BRACELET',
#   'GREEN MURANO TWIST BRACELET',
#   'BLUE MURANO TWIST BRACELET'),
#  90014: ('SILVER/MOP ORBIT NECKLACE',
#   'SILVER M.O.P. ORBIT NECKLACE',
#   'GOLD M.O.P. ORBIT NECKLACE',
#   'GOLD M PEARL  ORBIT NECKLACE',
#   'SILVER AND BLACK ORBIT NECKLACE',
#   'SILVER/BLACK ORBIT NECKLACE'),
#  84575: ('PINK DOG CANNISTER',),
#  84313: ('BLUE TV TRAY TABLE ', 'ORANGE TV TRAY TABLE '),
#  90125: ('AMBER BERTIE GLASS BEAD BAG CHARM',
#   'PINK BERTIE GLASS BEAD BAG CHARM',
#   'TURQUOISE BERTIE GLASS BEAD CHARM',
#   'AQUA BERTIE GLASS BEAD BAG CHARM',
#   'PURPLE BERTIE GLASS BEAD BAG CHARM'),
#  35095: ('BLUE VICTORIAN FABRIC OVAL BOX', 'RED VICTORIAN FABRIC OVAL BOX'),
#  85194: ('HANGING SPRING FLOWER EGG LARGE', 'HANGING SPRING FLOWER EGG SMALL'),
#  85180: ('PINK HEARTS LIGHT CHAIN ', 'RED HEARTS LIGHT CHAIN '),
#  90058: ('CRYSTAL STUD EARRINGS CLEAR DISPLAY',
#   'CRYSTAL STUD EARRINGS ASSORTED COL '),
#  62094: ('TURQ ICE CREAM BUM BAG ',),
#  84673: ('BLUE FLY SWAT', 'PINK FLY SWAT'),
#  17013: ('ORIGAMI ROSE INCENSE IN TUBE',),
#  35817: ('ACRYLIC JEWEL SNOWFLAKE,PINK', 'PINK ACRYLIC JEWEL SNOWFLAKE'),
#  35599: ('PINK AND WHITE CHRISTMAS TREE 120CM', 'BLACK CHRISTMAS TREE 120CM'),
#  90042: ('FRESHWATER PEARL BRACELET GOLD',),
#  90035: ('PEARL & SHELL 42"NECKL. IVORY', 'PEARL & SHELL 42"NECKL. GREEN'),
#  84751: ('BLACK MEDIUM GLASS CAKE STAND',),
#  17014: ('ORIGAMI VANILLA INCENSE CONES',),
#  90209: ('PURPLE ENAMEL+GLASS HAIR COMB',
#   'GREEN ENAMEL+GLASS HAIR COMB',
#   'PINK ENAMEL+GLASS HAIR COMB'),
#  84078: ('SET/4 WHITE RETRO STORAGE CUBES ',),
#  35911: ('PINK/FLOWER RABBIT EGG WARMER ', 'MULTICOLOUR RABBIT EGG WARMER'),
#  84750: ('PINK SMALL GLASS CAKE STAND', 'BLACK SMALL GLASS CAKE STAND'),
#  17011: ('ORIGAMI SANDLEWOOD INCENSE+FLOWER',),
#  35809: ('ENAMEL BLUE RIM TEA CONTAINER', 'ENAMEL PINK TEA CONTAINER'),
#  35607: ('PINK FLUFFY CHRISTMAS DECORATION',
#   'BLACK FEATHER CHRISTMAS DECORATION'),
#  84859: ('PINK DISCO HANDBAG', 'BLUE DISCO HANDBAG', 'SILVER DISCO HANDBAG'),
#  85205: ('PINK FELT EASTER RABBIT GARLAND',),
#  85163: ('WHITE BAROQUE WALL CLOCK ', 'BLACK BAROQUE WALL CLOCK '),
#  85023: ('EAU DE NILE JEWELLED PHOTOFRAME', 'PINK LARGE JEWELED PHOTOFRAME'),
#  84804: ('BLUE DELPHINIUM ARTIFICIAL FLOWER',
#   'CREAM DELPHINIUM ARTIFICIAL FLOWER'),
#  84800: ('SMALL WHITE/PINK ROSE ART FLOWER',
#   'LARGE WHITE/PINK ROSE ART FLOWER',
#   'MEDIUM WHITE/PINK ROSE ART FLOWER'),
#  84802: ('PURPLE ANEMONE ARTIFICIAL FLOWER',
#   'WHITE ANEMONE ARTIFICIAL FLOWER'),
#  84806: ('PINK CANDYSTUFT ARTIFICIAL FLOWER',
#   'WHITE CANDYSTUFT ARTIFICIAL FLOWER'),
#  16207: ('PINK STRAWBERRY HANDBAG ', 'PINK HEART RED HANDBAG'),
#  84249: ('GREETING CARD,SQUARE, DOUGHNUTS',),
#  90027: ('GLASS BEAD HOOP EARRINGS BLACK',
#   'GLASS BEAD HOOP EARRINGS AMETHYST'),
#  90019: ('SILVER BLACK ORBIT BRACELET',
#   'GOLD M.O.P ORBIT BRACELET',
#   'SILVER M.O.P ORBIT BRACELET'),
#  90040: ('MURANO STYLE GLASS BRACELET RED',
#   'MURANO STYLE GLASS BRACELET GOLD',
#   'MURANO STYLE GLASS BRACELET BLACK'),
#  72225: ('LAVENDER SCENT CAKE CANDLE',),
#  90165: ('WHITE ROSEBUD  PEARL EARRINGS',),
#  16206: ('RED PURSE WITH PINK HEART',),
#  46138: ('BLUE CHENILLE SHAGGY CUSHION COVER ',),
#  47585: ('PINK FAIRY CAKE CUSHION COVER',),
#  84989: ('75 GREEN FAIRY CAKE CASES',),
#  79071: ('ENGLISH ROSE METAL WASTE BIN',),
#  84931: ('PINK SCOTTIE DOG W FLOWER PATTERN',
#   'BLUE SCOTTIE DOG W FLOWER PATTERN'),
#  35909: ('PINK FLOWERS RABBIT EASTER', 'RABBIT EASTER DECORATION'),
#  35910: ('PINK FLOWERS RABBIT EASTER', 'MULTICOLOUR EASTER RABBIT '),
#  79323: ('BLACK CHERRY LIGHTS', 'WHITE CHERRY LIGHTS', 'PINK CHERRY LIGHTS'),
#  47518: ('ICON PLACEMAT POP ART ELVIS',),
#  47351: ('BLUE  VOILE LAMPSHADE',),
#  84251: ('GREETING CARD, STICKY GORDON',
#   'GREETING CARD, TWO SISTERS.',
#   'GREETING CARD, OVERCROWDED POOL.'),
#  84741: ('CITRUS GARLAND FELT FLOWERS ',),
#  90123: ('TURQUOISE HEART OF GLASS BRACELET',
#   'GREEN HEART OF GLASS BRACELET',
#   'WHITE HEART OF GLASS BRACELET',
#   'PINK HEART OF GLASS BRACELET'),
#  90122: ('TURQUOISE CRYSTAL+GLASS BRACELET',
#   'PINK CRYSTAL+GLASS BRACELET',
#   'JADE CRYSTAL+GLASS BRACELET'),
#  75049: ('LARGE CIRCULAR MIRROR MOBILE',),
#  44091: ('BLUE CRUSOE CHECK LAMPSHADE',),
#  47556: ('TEA TIME TEA TOWELS ',),
#  62086: ('PINK RETRO BIG FLOWER BAG',),
#  35912: ('WHITE/PINK CHICK DECORATION',),
#  84745: ('PINK HANGING GINGHAM EASTER HEN', 'BLUE HANGING GINGHAM EASTER HEN'),
#  85186: ('EASTER BUNNY GARLAND OF FLOWERS', 'BUNNY EGG GARLAND'),
#  90010: ('MIDNIGHT BLUE GLASS/SILVER BRACELET',
#   'BLACK/WHITE GLASS/SILVER BRACELET',
#   'AMBER GLASS/SILVER BRACELET'),
#  85188: ('PINK METAL SWINGING BUNNY', 'GREEN METAL SWINGING BUNNY'),
#  84796: ('PINK HAWAIIAN PICNIC HAMPER FOR 2',
#   'BLUE SAVANNAH PICNIC HAMPER FOR 2'),
#  37379: ('PINK CHERRY BLOSSOM CUP & SAUCER',),
#  84801: ('WHITE HYDRANGEA ART FLOWER', 'PINK HYDRANGEA ART FLOWER'),
#  79192: ("RETRO PLASTIC 70'S TRAY",),
#  40046: ('RED DAISY PAPER LAMPSHADE',),
#  71101: ('STANDING FAIRY POLE SUPPORT ',),
#  46775: ('SUNSET COLOUR CHUNKY KNITTED THROW',),
#  90197: ('BLACK GLASS BRACELET W HEART CHARMS',),
#  35913: ('WHITE/PINK CHICK EASTER DECORATION',),
#  90016: ('SILVER/M.O.P PENDANT ORBIT NECKLACE',
#   'GOLD/M.O.P PENDANT ORBIT NECKLACE'),
#  85160: ('BLACK BIRD GARDEN DESIGN MUG',),
#  17028: ('INCENSE BAZAAR PEACH',),
#  62074: ('ELEPHANT CLIP W SUCTION CUP',),
#  84805: ('BLUE CLIMBING HYDRANGA ART FLOWER',
#   'CREAM CLIMBING HYDRANGA ART FLOWER'),
#  17136: ('BLUE STONES ON WIRE FOR CANDLE',),
#  84712: ('PINK JEWELLED PHOTO FRAME',),
#  84708: ('PINK JEWELLED PHOTO FRAME ',),
#  44089: ('LILAC GAUZE BUTTERFLY LAMPSHADE', 'PINK GAUZE BUTTERFLY LAMPSHADE'),
#  84086: ('PINK/PURPLE RETRO RADIO', 'YELLOW/BLUE RETRO RADIO'),
#  84429: ('MEDIUM PINK BUDDHA HEAD ',),
#  37462: ('PET MUG, GOLDFISH',),
#  90037: ('TINY CRYSTAL BRACELET GREEN',),
#  84659: ('WHITE TRAVEL ALARM CLOCK',),
#  35815: ('ACRYLIC JEWEL SNOWFLAKE, PINK',),
#  90202: ('PINK ENAMEL FLOWER HAIR TIE',
#   'WHITE ENAMEL FLOWER HAIR TIE',
#   'GREEN ENAMEL FLOWER HAIR TIE',
#   'PURPLE ENAMEL FLOWER HAIR TIE'),
#  90039: ('FIRE POLISHED GLASS BRACELET BLACK',
#   'FIRE POLISHED GLASS BRACELET GREEN',
#   'FIRE POLISHED GLASS BRACELET MONTAN',
#   'FIRE POLISHED GLASS BRACELET RED'),
#  90064: ('WHITE VINTAGE CRYSTAL EARRINGS', 'BLACK VINTAGE  CRYSTAL EARRINGS'),
#  90011: ('MIDNIGHT BLUE CRYSTAL DROP EARRINGS', 'BLACK CRYSTAL DROP EARRINGS'),
#  90063: ('WHITE VINT ART DECO CRYSTAL NECKLAC',
#   'BLACK VINT ART DEC CRYSTAL NECKLACE'),
#  90018: ('GOLD M.O.P ORBIT DROP EARRINGS',
#   'SILVER M.O.P ORBIT DROP EARRINGS',
#   'SILVER BLACK ORBIT DROP EARRINGS'),
#  84663: ('GRASS HOPPER WOODEN WALL CLOCK ',),
#  35637: ('PINK STRING CURTAIN WITH POLE', 'IVORY STRING CURTAIN WITH POLE '),
#  84661: ('BLACK SQUARE TABLE CLOCK',
#   'PINK SQUARE TABLE CLOCK',
#   'WHITE SQUARE TABLE CLOCK'),
#  84857: ('BLUE MONTE CARLO HANDBAG', 'PINK MONTE CARLO HANDBAG'),
#  79063: ('RETRO PILL BOX , REVOLUTIONARY',
#   'RETRO PILL BOX KEY CHAIN,THE KING'),
#  79062: ('RETRO TIN ASHTRAY,REVOLUTIONARY',),
#  47341: ('FUSCHIA TABLE RUN FLOWER ', 'BLUE TABLE RUN FLOWER'),
#  44092: ('PURPLE/COPPER HANGING LAMPSHADE',
#   'BLUE WHITE PLASTIC RINGS LAMPSHADE'),
#  90065: ('BLACK VINT ART DEC CRYSTAL BRACELET',
#   'WHITE VINTAGE CRYSTAL BRACELET'),
#  90024: ("NEW BAROQUE B'FLY NECKLACE PINK",
#   "NEW BAROQUE B'FLY NECKLACE GREEN",
#   "NEW BAROQUE B'FLY NECKLACE RED",
#   "NEW BAROQUE B'FLY NECKLACE CRYSTAL"),
#  90026: ('GLASS BEAD HOOP NECKLACE AMETHYST',
#   'GLASS BEAD HOOP NECKLACE MONTANA',
#   'GLASS BEAD HOOP NECKLACE GREEN',
#   'GLASS BEAD HOOP NECKLACE BLACK'),
#  90000: ('COPPER/OLIVE GREEN FLOWER NECKLACE',
#   'MIDNIGHT BLUE COPPER FLOWER NECKLAC',
#   'RASPBERRY ANT COPPER FLOWER NECKLAC'),
#  35638: ('PINK/BLUE STRING CURTAIN ', 'PINK AND BLACK STRING CURTAIN'),
#  46776: ('WOVEN ROSE GARDEN CUSHION COVER ',
#   'WOVEN BERRIES CUSHION COVER ',
#   'WOVEN CANDY CUSHION COVER ',
#   'WOVEN FROST CUSHION COVER',
#   'WOVEN BUBBLE GUM CUSHION COVER',
#   'WOVEN SUNSET CUSHION COVER '),
#  84858: ('PINK RIVIERA HANDBAG',),
#  72140: ('BEST DAD CANDLE LETTERS',),
#  35916: ('PINK FELT HANGING HEART W FLOWER',
#   'YELLOW FELT HANGING HEART W FLOWER',
#   'BLUE FELT HANGING HEART WITH FLOWER'),
#  84803: ('WHITE ALLIUM  ARTIFICIAL FLOWER',),
#  16020: ('CLEAR STATIONERY BOX SET ',),
#  90141: ('ORANGE PENDANT TRIPLE SHELL NECKLAC',
#   'IVORY PENDANT TRIPLE SHELL NECKLACE',
#   'ROSE PENDANT TRIPLE SHELL NECKLACE',
#   'TURQ PENDANT TRIPLE SHELL NECKLACE',
#   'GREEN PENDANT TRIPLE SHELL NECKLACE'),
#  90183: ('BLACK DROP EARRINGS W LONG BEADS',
#   'AMBER DROP EARRINGS W LONG BEADS'),
#  90124: ('PINK MURANO TWIST NECKLACE',
#   'BLUE MURANO TWIST NECKLACE',
#   'GREEN MURANO TWIST NECKLACE'),
#  79026: ('S/4 ICON COASTER,ELVIS LIVES',),
#  90038: ('GLASS AND PAINTED BEADS BRACELET OL',
#   'GLASS AND PAINTED BEADS BRACELET TO',
#   'GLASS AND BEADS BRACELET IVORY'),
#  16248: ('BLUE HOLE PUNCH',),
#  85098: ('BLUE FLYING SINGING CANARY',),
#  17129: ('BLUE GLASS GEMS IN BAG',),
#  90201: ('PURPLE ENAMEL FLOWER RING',
#   'GREEN ENAMEL FLOWER RING',
#   'RED ENAMEL FLOWER RING',
#   'BLACK ENAMEL FLOWER RING'),
#  47013: ('WINE BOTTLE DRESSING LT.BLUE', 'WINE BOTTLE DRESSING DARK BLUE'),
#  37488: ('YELLOW PINK FLOWER DESIGN BIG BOWL',),
#  47344: ('BLUE FLOWER DES PURSE',),
#  46126: ('ELVIS WALLHANGING / CURTAIN',),
#  90030: ('BROWN KUKUI COCONUT SEED NECKLACE',
#   'RED KUKUI COCONUT SEED NECKLACE',
#   'SPOTTED WHITE NATURAL SEED NECKLACE'),
#  85028: ('FRENCH CHATEAU SMALL FRUITBOWL', 'FRENCH CHATEAU LARGE FRUIT BOWL '),
#  90164: ('WHITE  ROSEBUD PEARL BRACELET', 'PINK ROSEBUD PEARL BRACELET'),
#  84743: ('ORANGE FELT VASE + FLOWERS',),
#  84872: ('TEATIME FUNKY FLOWER BACKPACK FOR 2',),
#  90001: ('ANTIQUE RASPBERRY FLOWER EARRINGS',
#   'ANTIQUE OLIVE GREEN FLOWER EARRINGS',
#   'ANTIQUE OPAL WHITE FLOWER EARRINGS',
#   'ANTIQUE MID BLUE FLOWER EARRINGS'),
#  90025: ('BAROQUE BUTTERFLY EARRINGS CRYSTAL',
#   'BAROQUE BUTTERFLY EARRINGS BLACK'),
#  90142: ('MOP PENDANT SHELL NECKLACE',),
#  37487: ('YELLOW/ORANGE FLOWER DESIGN PLATE',),
#  84856: ('SMALL TAHITI BEACH BAG',),
#  44242: ('PINK FEATHERS CURTAIN', 'LILAC FEATHERS CURTAIN'),
#  72024: ('LILAC VOTIVE CANDLE',),
#  90163: ('WHITE ROSEBUD & PEARL NECKLACE', 'PINK ROSEBUD & PEARL NECKLACE'),
#  16244: ('MAXWELL 2 TONE BLUE 60 PAGE PHOTO A',),
#  62097: ('BLUE STRIPES SHOULDER BAG',),
#  62043: ('BLUE CHECK BAG W HANDLE 34X20CM',),
#  84705: ('PINK FLOCK PHOTO FRAME ',),
#  90130: ('WHITE STONE/CRYSTAL EARRINGS', 'TURQ STONE/CRYSTAL EARRINGS'),
#  16151: ('FLOWERS HANDBAG blue and orange',),
#  84873: ('FUNKY FLOWER PICNIC BAG FOR 4',),
#  84984: ('GREEN PEONY CUSHION COVER',
#   'RED PEONY CUSHION COVER ',
#   'ORIENTAL RED CUSHION COVER '),
#  90013: ('MIDNIGHT BLUE VINTAGE EARRINGS', 'GREEN VINTAGE EARRINGS '),
#  84206: ('3 BLACK CATS W HEARTS BLANK CARD',
#   'CAT WITH SUNGLASSES BLANK CARD',
#   'CHAMPAGNE TRAY BLANK CARD'),
#  90206: ('GOLD DIAMANTE STAR BROOCH', 'CRYSTAL DIAMANTE STAR BROOCH'),
#  35818: ('ACRYLIC JEWEL ICICLE, PINK', 'ACRYLIC JEWEL ICICLE, BLUE'),
#  16162: ('THE KING GIFT BAG 25x24x12cm', 'THE KING GIFT BAG'),
#  90187: ('GREEN DROP EARRINGS W BEAD CLUSTER',),
#  85168: ('BLACK BAROQUE CARRIAGE CLOCK',),
#  72369: ('PINK CLEAR GLASS CANDLE PLATE',),
#  90176: ('DIAMANTE NECKLACE PURPLE',
#   'DIAMANTE NECKLACE GREEN',
#   'CLASSIC DIAMANTE NECKLACE JET',
#   'DIAMANTE NECKLACE',
#   'DIAMANTE NECKLACE BLACK '),
#  81952: ('ROUND BLUE CLOCK WITH SUCKER', 'ROUND PURPLE CLOCK WITH SUCKER'),
#  90205: ('LARGE CRYSTAL DIAMANTE HAIRSLIDE', 'LARGE MINT DIAMANTE HAIRSLIDE'),
#  81953: ('ROUND ARTICULATED PINK CLOCK W/SUCK',
#   'ROUND BLUE CLOCK WITH SUCKER'),
#  37491: ('BLUE/YELLOW CERAMIC CANDLE HOLDER',
#   'GREEN/BLUE CERAMIC CANDLE HOLDER',
#   'PURPLE/BLUE CERAMIC CANDLE HOLDER'),
#  84402: ('PURPLE DRESS JEWELLERY STAND',),
#  84732: ('CUTE BIRD CEATURE SCREEN', 'CUTE RABBIT CEATURE SCREEN '),
#  84387: ('BIRD ON BRANCH CANVAS SCREEN',),
#  35816: ('ACRYLIC JEWEL ANGEL,PINK',),
#  84201: ('HAPPY BIRTHDAY CARD TEDDY/CAKE',
#   'HAPPY BIRTHDAY CARD STRIPEY TEDDY'),
#  35819: ('ACRYLIC HANGING JEWEL,PINK', 'ACRYLIC HANGING JEWEL,BLUE'),
#  90182: ('BLACK 3 BEAD DROP EARRINGS',),
#  90012: ('BLACK DROP CRYSTAL NECKLACE', 'MIDNIGHT BLUE DROP CRYSTAL NECKLACE'),
#  79157: ('UBO-LIGHT TRIOBASE PURPLE', 'UBO-LIGHT TRIOBASE BLUE'),
#  90189: ('SILVER 2 STRAND NECKLACE-LEAF CHARM',),
#  90181: ('AMBER GLASS/SHELL/PEARL NECKLACE',),
#  79161: ('ST GEORGE SET OF 10 PARTY LIGHTS',),
#  17191: ('ROSE FLOWER CANDLE+INCENSE 16X16CM',)}

# %%
# from our observations, 6 digit StockCodes are indeed variants of each other,
# although a 'base variant' of 5 digits does not exist.
# Let's add a new column indicating the number of variations for that product. default = 1

productVar = dict()
for i in d:
    productVar[i] = len(d[i])
#1.dictionary to store StockCode : product variations
    
pd.options.mode.chained_assignment = None

df['ProductVariations'] = 1
#2.set default as 1

for i in range(len(df)):
    if len(str(df[colName].iloc[i])) == 6:
        df['ProductVariations'].iloc[i] = productVar[int(str(df[colName].iloc[i])[:5])]
#3.for every row in dataframe, if the StockCode is 6 digits, 
#change the ProductVariations value to the corresponding value in the productVar dictionary
#(key-value pair)
df
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ..       ...       ...                                  ...       ...
# 35    577129     22464          HANGING METAL HEART LANTERN         4
# 36    577168         M                               Manual         1
# 37    577314     23407       SET OF 2 TRAYS HOME SWEET HOME         2
# 38    577696         M                               Manual         1
# 39    578841     84826       ASSTD DESIGN 3D PAPER STICKERS     12540
#
#            InvoiceDate  UnitPrice  CustomerID         Country  \
# 0  2010-12-01 08:26:00   2.550000     17850.0  United Kingdom
# 1  2010-12-01 08:26:00   3.390000     17850.0  United Kingdom
# 2  2010-12-01 08:26:00   2.750000     17850.0  United Kingdom
# 3  2010-12-01 08:26:00   3.390000     17850.0  United Kingdom
# 4  2010-12-01 08:26:00   3.390000     17850.0  United Kingdom
# ..                 ...        ...         ...             ...
# 35 2011-11-17 19:52:00   0.215980     15602.0  United Kingdom
# 36 2011-11-18 10:42:00  67.885711     12603.0         Germany
# 37 2011-11-18 13:23:00   5.633640     12444.0          Norway
# 38 2011-11-21 11:57:00  67.885711     16406.0  United Kingdom
# 39 2011-11-25 15:57:00   0.019738     13256.0  United Kingdom
#
#     ProductVariations
# 0                   2
# 1                   1
# 2                   1
# 3                   2
# 4                   2
# ..                ...
# 35                  1
# 36                  1
# 37                  1
# 38                  1
# 39                  1
#
# [406829 rows x 9 columns]

# %%
# lastly, StockCodes that are less than 5 digits long, 
# i.e neither product code nor product variation

temp = df[df[colName].astype('str').str.len() < 5]
temp
# Out:
#      InvoiceNo StockCode Description  Quantity         InvoiceDate  UnitPrice  \
# 45      536370      POST     POSTAGE         3 2010-12-01 08:45:00  18.000000
# 141    C536379         D    Discount        -1 2010-12-01 09:41:00  27.500000
# 386     536403      POST     POSTAGE         1 2010-12-01 11:27:00  15.000000
# 1123    536527      POST     POSTAGE         1 2010-12-01 13:04:00  18.000000
# 1423    536540        C2    CARRIAGE         1 2010-12-01 14:05:00  50.000000
# ...        ...       ...         ...       ...                 ...        ...
# 22      568384         M      Manual         1 2011-09-27 09:46:00  67.885711
# 24      571035         M      Manual         1 2011-10-13 12:50:00  67.885711
# 28      574252         M      Manual         1 2011-11-03 13:24:00  67.885711
# 36      577168         M      Manual         1 2011-11-18 10:42:00  67.885711
# 38      577696         M      Manual         1 2011-11-21 11:57:00  67.885711
#
#       CustomerID         Country  ProductVariations
# 45       12583.0          France                  1
# 141      14527.0  United Kingdom                  1
# 386      12791.0     Netherlands                  1
# 1123     12662.0         Germany                  1
# 1423     14911.0            EIRE                  1
# ...          ...             ...                ...
# 22       12748.0  United Kingdom                  1
# 24       12446.0             RSA                  1
# 28       12437.0          France                  1
# 36       12603.0         Germany                  1
# 38       16406.0  United Kingdom                  1
#
# [1908 rows x 9 columns]

# %%
temp['Description'].unique()
# Out:
# array(['POSTAGE', 'Discount', 'CARRIAGE', 'Manual',
#        'PADS TO MATCH ALL CUSHIONS', 'DOTCOM POSTAGE', 'CRUK Commission'],
#       dtype=object)

# %%
#these don't seem like real products, so we drop them
if colName == 'StockCode':
    df = df.drop(temp.index)
df
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ..       ...       ...                                  ...       ...
# 33    575579     22437        SET OF 9 BLACK SKULL BALLOONS        20
# 34    575579     22089        PAPER BUNTING VINTAGE PAISLEY        24
# 35    577129     22464          HANGING METAL HEART LANTERN         4
# 37    577314     23407       SET OF 2 TRAYS HOME SWEET HOME         2
# 39    578841     84826       ASSTD DESIGN 3D PAPER STICKERS     12540
#
#            InvoiceDate  UnitPrice  CustomerID         Country  \
# 0  2010-12-01 08:26:00   2.550000     17850.0  United Kingdom
# 1  2010-12-01 08:26:00   3.390000     17850.0  United Kingdom
# 2  2010-12-01 08:26:00   2.750000     17850.0  United Kingdom
# 3  2010-12-01 08:26:00   3.390000     17850.0  United Kingdom
# 4  2010-12-01 08:26:00   3.390000     17850.0  United Kingdom
# ..                 ...        ...         ...             ...
# 33 2011-11-10 11:49:00   0.082794     13081.0  United Kingdom
# 34 2011-11-10 11:49:00   0.676032     13081.0  United Kingdom
# 35 2011-11-17 19:52:00   0.215980     15602.0  United Kingdom
# 37 2011-11-18 13:23:00   5.633640     12444.0          Norway
# 39 2011-11-25 15:57:00   0.019738     13256.0  United Kingdom
#
#     ProductVariations
# 0                   2
# 1                   1
# 2                   1
# 3                   2
# 4                   2
# ..                ...
# 33                  1
# 34                  1
# 35                  1
# 37                  1
# 39                  1
#
# [404914 rows x 9 columns]

# %% [markdown]
# ## // StockCode is done. //

# %% [markdown]
# ## === Circling back: negative quantities & order cancellations ===

# %%
cancel = df[(df['InvoiceNo'].astype('str').str.contains('C'))]
orders = df[~(df['InvoiceNo'].astype('str').str.contains('C'))]

# %%
cancel.loc[(cancel['CustomerID'] == 17315) & (cancel['StockCode']==20979)].sort_values(by='Description')
# Out:
#        InvoiceNo StockCode                    Description  Quantity  \
# 541717   C581569     20979  36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# 541717 2011-12-09 11:58:00       1.25     17315.0  United Kingdom
#
#         ProductVariations
# 541717                  1

# %%
orders.loc[(orders['CustomerID'] == 17315) & (orders['StockCode']==20979)].sort_values(by='Description')
# Out:
#        InvoiceNo StockCode                    Description  Quantity  \
# 433318    573911     20979  36 PENCILS TUBE RED RETROSPOT         6
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# 433318 2011-11-01 15:40:00       1.25     17315.0  United Kingdom
#
#         ProductVariations
# 433318                  1

# %%
# from observation, we can try to merge cancels and orders by the following keys: StockCode+CustomerID

cancel['CancelDetails'] = cancel.apply(lambda row: str(row.StockCode) + str(row.CustomerID), axis=1)
orders['OrdersDetails'] = orders.apply(lambda row: str(row.StockCode) + str(row.CustomerID), axis=1)
#1.create new column
#2.for every row in that column, concatenate strings StockCode and CustomerID and put that as the value

# %%
merged = pd.merge(cancel, orders, left_on='CancelDetails', right_on='OrdersDetails', how='left')
merged
# Out:
#       InvoiceNo_x StockCode_x                     Description_x  Quantity_x  \
# 0         C536383      35004C   SET OF 3 COLOURED  FLYING DUCKS          -1
# 1         C536383      35004C   SET OF 3 COLOURED  FLYING DUCKS          -1
# 2         C536383      35004C   SET OF 3 COLOURED  FLYING DUCKS          -1
# 3         C536383      35004C   SET OF 3 COLOURED  FLYING DUCKS          -1
# 4         C536391       22556    PLASTERS IN TIN CIRCUS PARADE          -12
# ...           ...         ...                               ...         ...
# 24249     C581569       84978  HANGING HEART JAR T-LIGHT HOLDER          -1
# 24250     C581569       84978  HANGING HEART JAR T-LIGHT HOLDER          -1
# 24251     C581569       84978  HANGING HEART JAR T-LIGHT HOLDER          -1
# 24252     C581569       84978  HANGING HEART JAR T-LIGHT HOLDER          -1
# 24253     C581569       20979     36 PENCILS TUBE RED RETROSPOT          -5
#
#             InvoiceDate_x  UnitPrice_x  CustomerID_x       Country_x  \
# 0     2010-12-01 09:49:00         4.65       15311.0  United Kingdom
# 1     2010-12-01 09:49:00         4.65       15311.0  United Kingdom
# 2     2010-12-01 09:49:00         4.65       15311.0  United Kingdom
# 3     2010-12-01 09:49:00         4.65       15311.0  United Kingdom
# 4     2010-12-01 10:24:00         1.65       17548.0  United Kingdom
# ...                   ...          ...           ...             ...
# 24249 2011-12-09 11:58:00         1.25       17315.0  United Kingdom
# 24250 2011-12-09 11:58:00         1.25       17315.0  United Kingdom
# 24251 2011-12-09 11:58:00         1.25       17315.0  United Kingdom
# 24252 2011-12-09 11:58:00         1.25       17315.0  United Kingdom
# 24253 2011-12-09 11:58:00         1.25       17315.0  United Kingdom
#
#        ProductVariations_x  CancelDetails InvoiceNo_y StockCode_y  \
# 0                        4  35004C15311.0      537195      35004C
# 1                        4  35004C15311.0      538651      35004C
# 2                        4  35004C15311.0      540157      35004C
# 3                        4  35004C15311.0      541293      35004C
# 4                        1   2255617548.0         NaN         NaN
# ...                    ...            ...         ...         ...
# 24249                    1   8497817315.0      548150       84978
# 24250                    1   8497817315.0      550828       84978
# 24251                    1   8497817315.0      552537       84978
# 24252                    1   8497817315.0      566624       84978
# 24253                    1   2097917315.0      573911       20979
#
#                           Description_y  Quantity_y       InvoiceDate_y  \
# 0       SET OF 3 COLOURED  FLYING DUCKS        12.0 2010-12-05 13:55:00
# 1       SET OF 3 COLOURED  FLYING DUCKS        12.0 2010-12-13 15:07:00
# 2       SET OF 3 COLOURED  FLYING DUCKS        12.0 2011-01-05 11:41:00
# 3       SET OF 3 COLOURED  FLYING DUCKS        12.0 2011-01-17 13:39:00
# 4                                   NaN         NaN                 NaT
# ...                                 ...         ...                 ...
# 24249  HANGING HEART JAR T-LIGHT HOLDER        36.0 2011-03-29 12:55:00
# 24250  HANGING HEART JAR T-LIGHT HOLDER         6.0 2011-04-21 10:19:00
# 24251  HANGING HEART JAR T-LIGHT HOLDER        36.0 2011-05-10 10:11:00
# 24252  HANGING HEART JAR T-LIGHT HOLDER        12.0 2011-09-14 09:36:00
# 24253     36 PENCILS TUBE RED RETROSPOT         6.0 2011-11-01 15:40:00
#
#        UnitPrice_y  CustomerID_y       Country_y  ProductVariations_y  \
# 0             4.65       15311.0  United Kingdom                  4.0
# 1             4.65       15311.0  United Kingdom                  4.0
# 2             4.65       15311.0  United Kingdom                  4.0
# 3             4.65       15311.0  United Kingdom                  4.0
# 4              NaN           NaN             NaN                  NaN
# ...            ...           ...             ...                  ...
# 24249         1.06       17315.0  United Kingdom                  1.0
# 24250         1.25       17315.0  United Kingdom                  1.0
# 24251         1.06       17315.0  United Kingdom                  1.0
# 24252         1.25       17315.0  United Kingdom                  1.0
# 24253         1.25       17315.0  United Kingdom                  1.0
#
#        OrdersDetails
# 0      35004C15311.0
# 1      35004C15311.0
# 2      35004C15311.0
# 3      35004C15311.0
# 4                NaN
# ...              ...
# 24249   8497817315.0
# 24250   8497817315.0
# 24251   8497817315.0
# 24252   8497817315.0
# 24253   2097917315.0
#
# [24254 rows x 20 columns]

# %%
# there seems to be some cancelled orders that didn't merge with a corresponding order...
nomerge = merged[merged['OrdersDetails'].isna()]
nomerge
# Out:
#       InvoiceNo_x StockCode_x                      Description_x  Quantity_x  \
# 4         C536391       22556     PLASTERS IN TIN CIRCUS PARADE          -12
# 5         C536391       21984   PACK OF 12 PINK PAISLEY TISSUES          -24
# 6         C536391       21983   PACK OF 12 BLUE PAISLEY TISSUES          -24
# 7         C536391       21980  PACK OF 12 RED RETROSPOT TISSUES          -24
# 8         C536391       21484        CHICK GREY HOT WATER BOTTLE         -12
# ...           ...         ...                                ...         ...
# 24035     C580989       22331   WOODLAND PARTY BAG + STICKER SET          -1
# 24041     C581100       22946       WOODEN ADVENT CALENDAR CREAM          -1
# 24077     C581121       22526          WHEELBARROW FOR CHILDREN           -1
# 24127     C581305       22627                MINT KITCHEN SCALES          -1
# 24139     C581323       21533           RETROSPOT LARGE MILK JUG          -1
#
#             InvoiceDate_x  UnitPrice_x  CustomerID_x        Country_x  \
# 4     2010-12-01 10:24:00         1.65       17548.0   United Kingdom
# 5     2010-12-01 10:24:00         0.29       17548.0   United Kingdom
# 6     2010-12-01 10:24:00         0.29       17548.0   United Kingdom
# 7     2010-12-01 10:24:00         0.29       17548.0   United Kingdom
# 8     2010-12-01 10:24:00         3.45       17548.0   United Kingdom
# ...                   ...          ...           ...              ...
# 24035 2011-12-06 16:42:00         1.65       12709.0          Germany
# 24041 2011-12-07 11:44:00        16.95       14534.0   United Kingdom
# 24077 2011-12-07 12:28:00        12.75       14087.0   United Kingdom
# 24127 2011-12-08 11:42:00         8.50       16933.0   United Kingdom
# 24139 2011-12-08 11:53:00         4.25       14442.0  Channel Islands
#
#        ProductVariations_x CancelDetails InvoiceNo_y StockCode_y  \
# 4                        1  2255617548.0         NaN         NaN
# 5                        1  2198417548.0         NaN         NaN
# 6                        1  2198317548.0         NaN         NaN
# 7                        1  2198017548.0         NaN         NaN
# 8                        1  2148417548.0         NaN         NaN
# ...                    ...           ...         ...         ...
# 24035                    1  2233112709.0         NaN         NaN
# 24041                    1  2294614534.0         NaN         NaN
# 24077                    1  2252614087.0         NaN         NaN
# 24127                    1  2262716933.0         NaN         NaN
# 24139                    1  2153314442.0         NaN         NaN
#
#       Description_y  Quantity_y InvoiceDate_y  UnitPrice_y  CustomerID_y  \
# 4               NaN         NaN           NaT          NaN           NaN
# 5               NaN         NaN           NaT          NaN           NaN
# 6               NaN         NaN           NaT          NaN           NaN
# 7               NaN         NaN           NaT          NaN           NaN
# 8               NaN         NaN           NaT          NaN           NaN
# ...             ...         ...           ...          ...           ...
# 24035           NaN         NaN           NaT          NaN           NaN
# 24041           NaN         NaN           NaT          NaN           NaN
# 24077           NaN         NaN           NaT          NaN           NaN
# 24127           NaN         NaN           NaT          NaN           NaN
# 24139           NaN         NaN           NaT          NaN           NaN
#
#       Country_y  ProductVariations_y OrdersDetails
# 4           NaN                  NaN           NaN
# 5           NaN                  NaN           NaN
# 6           NaN                  NaN           NaN
# 7           NaN                  NaN           NaN
# 8           NaN                  NaN           NaN
# ...         ...                  ...           ...
# 24035       NaN                  NaN           NaN
# 24041       NaN                  NaN           NaN
# 24077       NaN                  NaN           NaN
# 24127       NaN                  NaN           NaN
# 24139       NaN                  NaN           NaN
#
# [693 rows x 20 columns]

# %%
cancel.loc[(cancel['CustomerID'] == 17548) & (cancel['StockCode']==22556)].sort_values(by='Description')
# Out:
#     InvoiceNo StockCode                     Description  Quantity  \
# 235   C536391     22556  PLASTERS IN TIN CIRCUS PARADE        -12
#
#             InvoiceDate  UnitPrice  CustomerID         Country  \
# 235 2010-12-01 10:24:00       1.65     17548.0  United Kingdom
#
#      ProductVariations CancelDetails
# 235                  1  2255617548.0

# %%
orders.loc[(orders['CustomerID'] == 17548)].sort_values(by='Description')
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 165028    550755     22926  IVORY GIANT GARDEN THERMOMETER         4
# 165024    550755     22585       PACK OF 6 BIRDY GIFT TAGS        24
# 165026    550755     22081      RIBBON REEL FLORA + FAUNA         10
# 165027    550755     22079      RIBBON REEL HEARTS DESIGN         10
# 165025    550755     22082     RIBBON REEL STRIPES DESIGN         10
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# 165028 2011-04-20 12:01:00       5.95     17548.0  United Kingdom
# 165024 2011-04-20 12:01:00       1.25     17548.0  United Kingdom
# 165026 2011-04-20 12:01:00       1.65     17548.0  United Kingdom
# 165027 2011-04-20 12:01:00       1.65     17548.0  United Kingdom
# 165025 2011-04-20 12:01:00       1.65     17548.0  United Kingdom
#
#         ProductVariations OrdersDetails
# 165028                  1  2292617548.0
# 165024                  1  2258517548.0
# 165026                  1  2208117548.0
# 165027                  1  2207917548.0
# 165025                  1  2208217548.0

# %%
# from the above, it seems like for those cancels that didn't match an order, the order truly doesn't exist
# e.g. for the above, customer 17548 cancelled an order for plasters, but did not order a plaster at all...
# we will drop these columns

df = df[~df['InvoiceNo'].isin(nomerge['InvoiceNo_x'].unique())]
df
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ..       ...       ...                                  ...       ...
# 33    575579     22437        SET OF 9 BLACK SKULL BALLOONS        20
# 34    575579     22089        PAPER BUNTING VINTAGE PAISLEY        24
# 35    577129     22464          HANGING METAL HEART LANTERN         4
# 37    577314     23407       SET OF 2 TRAYS HOME SWEET HOME         2
# 39    578841     84826       ASSTD DESIGN 3D PAPER STICKERS     12540
#
#            InvoiceDate  UnitPrice  CustomerID         Country  \
# 0  2010-12-01 08:26:00   2.550000     17850.0  United Kingdom
# 1  2010-12-01 08:26:00   3.390000     17850.0  United Kingdom
# 2  2010-12-01 08:26:00   2.750000     17850.0  United Kingdom
# 3  2010-12-01 08:26:00   3.390000     17850.0  United Kingdom
# 4  2010-12-01 08:26:00   3.390000     17850.0  United Kingdom
# ..                 ...        ...         ...             ...
# 33 2011-11-10 11:49:00   0.082794     13081.0  United Kingdom
# 34 2011-11-10 11:49:00   0.676032     13081.0  United Kingdom
# 35 2011-11-17 19:52:00   0.215980     15602.0  United Kingdom
# 37 2011-11-18 13:23:00   5.633640     12444.0          Norway
# 39 2011-11-25 15:57:00   0.019738     13256.0  United Kingdom
#
#     ProductVariations
# 0                   2
# 1                   1
# 2                   1
# 3                   2
# 4                   2
# ..                ...
# 33                  1
# 34                  1
# 35                  1
# 37                  1
# 39                  1
#
# [403376 rows x 9 columns]

# %%
#re-do the merging
cancel = df[(df['InvoiceNo'].astype('str').str.contains('C'))]
orders = df[~(df['InvoiceNo'].astype('str').str.contains('C'))]

cancel['CancelDetails'] = cancel.apply(lambda row: str(row.StockCode) + str(row.CustomerID), axis=1)
orders['OrdersDetails'] = orders.apply(lambda row: str(row.StockCode) + str(row.CustomerID), axis=1)

merged = pd.merge(cancel, orders, left_on='CancelDetails', right_on='OrdersDetails', how='left')
merged
# Out:
#       InvoiceNo_x StockCode_x                     Description_x  Quantity_x  \
# 0         C536383      35004C   SET OF 3 COLOURED  FLYING DUCKS          -1
# 1         C536383      35004C   SET OF 3 COLOURED  FLYING DUCKS          -1
# 2         C536383      35004C   SET OF 3 COLOURED  FLYING DUCKS          -1
# 3         C536383      35004C   SET OF 3 COLOURED  FLYING DUCKS          -1
# 4         C536506       22960          JAM MAKING SET WITH JARS          -6
# ...           ...         ...                               ...         ...
# 20732     C581569       84978  HANGING HEART JAR T-LIGHT HOLDER          -1
# 20733     C581569       84978  HANGING HEART JAR T-LIGHT HOLDER          -1
# 20734     C581569       84978  HANGING HEART JAR T-LIGHT HOLDER          -1
# 20735     C581569       84978  HANGING HEART JAR T-LIGHT HOLDER          -1
# 20736     C581569       20979     36 PENCILS TUBE RED RETROSPOT          -5
#
#             InvoiceDate_x  UnitPrice_x  CustomerID_x       Country_x  \
# 0     2010-12-01 09:49:00         4.65       15311.0  United Kingdom
# 1     2010-12-01 09:49:00         4.65       15311.0  United Kingdom
# 2     2010-12-01 09:49:00         4.65       15311.0  United Kingdom
# 3     2010-12-01 09:49:00         4.65       15311.0  United Kingdom
# 4     2010-12-01 12:38:00         4.25       17897.0  United Kingdom
# ...                   ...          ...           ...             ...
# 20732 2011-12-09 11:58:00         1.25       17315.0  United Kingdom
# 20733 2011-12-09 11:58:00         1.25       17315.0  United Kingdom
# 20734 2011-12-09 11:58:00         1.25       17315.0  United Kingdom
# 20735 2011-12-09 11:58:00         1.25       17315.0  United Kingdom
# 20736 2011-12-09 11:58:00         1.25       17315.0  United Kingdom
#
#        ProductVariations_x  CancelDetails InvoiceNo_y StockCode_y  \
# 0                        4  35004C15311.0      537195      35004C
# 1                        4  35004C15311.0      538651      35004C
# 2                        4  35004C15311.0      540157      35004C
# 3                        4  35004C15311.0      541293      35004C
# 4                        1   2296017897.0      536488       22960
# ...                    ...            ...         ...         ...
# 20732                    1   8497817315.0      548150       84978
# 20733                    1   8497817315.0      550828       84978
# 20734                    1   8497817315.0      552537       84978
# 20735                    1   8497817315.0      566624       84978
# 20736                    1   2097917315.0      573911       20979
#
#                           Description_y  Quantity_y       InvoiceDate_y  \
# 0       SET OF 3 COLOURED  FLYING DUCKS          12 2010-12-05 13:55:00
# 1       SET OF 3 COLOURED  FLYING DUCKS          12 2010-12-13 15:07:00
# 2       SET OF 3 COLOURED  FLYING DUCKS          12 2011-01-05 11:41:00
# 3       SET OF 3 COLOURED  FLYING DUCKS          12 2011-01-17 13:39:00
# 4              JAM MAKING SET WITH JARS           8 2010-12-01 12:31:00
# ...                                 ...         ...                 ...
# 20732  HANGING HEART JAR T-LIGHT HOLDER          36 2011-03-29 12:55:00
# 20733  HANGING HEART JAR T-LIGHT HOLDER           6 2011-04-21 10:19:00
# 20734  HANGING HEART JAR T-LIGHT HOLDER          36 2011-05-10 10:11:00
# 20735  HANGING HEART JAR T-LIGHT HOLDER          12 2011-09-14 09:36:00
# 20736     36 PENCILS TUBE RED RETROSPOT           6 2011-11-01 15:40:00
#
#        UnitPrice_y  CustomerID_y       Country_y  ProductVariations_y  \
# 0             4.65       15311.0  United Kingdom                    4
# 1             4.65       15311.0  United Kingdom                    4
# 2             4.65       15311.0  United Kingdom                    4
# 3             4.65       15311.0  United Kingdom                    4
# 4             4.25       17897.0  United Kingdom                    1
# ...            ...           ...             ...                  ...
# 20732         1.06       17315.0  United Kingdom                    1
# 20733         1.25       17315.0  United Kingdom                    1
# 20734         1.06       17315.0  United Kingdom                    1
# 20735         1.25       17315.0  United Kingdom                    1
# 20736         1.25       17315.0  United Kingdom                    1
#
#        OrdersDetails
# 0      35004C15311.0
# 1      35004C15311.0
# 2      35004C15311.0
# 3      35004C15311.0
# 4       2296017897.0
# ...              ...
# 20732   8497817315.0
# 20733   8497817315.0
# 20734   8497817315.0
# 20735   8497817315.0
# 20736   2097917315.0
#
# [20737 rows x 20 columns]

# %%
# Get net quantity
merged['Quantity'] = merged['Quantity_x'] + merged['Quantity_y']
mergedKeys = merged['OrdersDetails'].unique()

# Tidy up the merged dataframe
merged = merged[['InvoiceNo_y', 'StockCode_y', 'Description_y', 'Quantity', 'InvoiceDate_y', 'UnitPrice_y', 'CustomerID_y', 'Country_y', 'ProductVariations_y']]
merged.columns = ['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country', 'ProductVariations']
merged
# Out:
#       InvoiceNo StockCode                       Description  Quantity  \
# 0        537195    35004C   SET OF 3 COLOURED  FLYING DUCKS        11
# 1        538651    35004C   SET OF 3 COLOURED  FLYING DUCKS        11
# 2        540157    35004C   SET OF 3 COLOURED  FLYING DUCKS        11
# 3        541293    35004C   SET OF 3 COLOURED  FLYING DUCKS        11
# 4        536488     22960          JAM MAKING SET WITH JARS         2
# ...         ...       ...                               ...       ...
# 20732    548150     84978  HANGING HEART JAR T-LIGHT HOLDER        35
# 20733    550828     84978  HANGING HEART JAR T-LIGHT HOLDER         5
# 20734    552537     84978  HANGING HEART JAR T-LIGHT HOLDER        35
# 20735    566624     84978  HANGING HEART JAR T-LIGHT HOLDER        11
# 20736    573911     20979     36 PENCILS TUBE RED RETROSPOT         1
#
#               InvoiceDate  UnitPrice  CustomerID         Country  \
# 0     2010-12-05 13:55:00       4.65     15311.0  United Kingdom
# 1     2010-12-13 15:07:00       4.65     15311.0  United Kingdom
# 2     2011-01-05 11:41:00       4.65     15311.0  United Kingdom
# 3     2011-01-17 13:39:00       4.65     15311.0  United Kingdom
# 4     2010-12-01 12:31:00       4.25     17897.0  United Kingdom
# ...                   ...        ...         ...             ...
# 20732 2011-03-29 12:55:00       1.06     17315.0  United Kingdom
# 20733 2011-04-21 10:19:00       1.25     17315.0  United Kingdom
# 20734 2011-05-10 10:11:00       1.06     17315.0  United Kingdom
# 20735 2011-09-14 09:36:00       1.25     17315.0  United Kingdom
# 20736 2011-11-01 15:40:00       1.25     17315.0  United Kingdom
#
#        ProductVariations
# 0                      4
# 1                      4
# 2                      4
# 3                      4
# 4                      1
# ...                  ...
# 20732                  1
# 20733                  1
# 20734                  1
# 20735                  1
# 20736                  1
#
# [20737 rows x 9 columns]

# %%
# check that total quantity cannot be less than zero
merged[merged['Quantity']<0]
# Out:
#       InvoiceNo StockCode                      Description  Quantity  \
# 12       537847     22839  3 TIER CAKE TIN GREEN AND CREAM        -1
# 94       562608     22847      BREAD BIN DINER STYLE IVORY        -3
# 95       566243     22847      BREAD BIN DINER STYLE IVORY        -2
# 107      562608     22847      BREAD BIN DINER STYLE IVORY        -3
# 108      566243     22847      BREAD BIN DINER STYLE IVORY        -2
# ...         ...       ...                              ...       ...
# 20570    581143     23249    VINTAGE RED ENAMEL TRIM PLATE        -8
# 20571    568480     23250    VINTAGE RED TRIM ENAMEL BOWL        -26
# 20573    581143     23250    VINTAGE RED TRIM ENAMEL BOWL         -7
# 20594    542533     22781            GUMBALL MAGAZINE RACK       -12
# 20725    572885     21258       VICTORIAN SEWING BOX LARGE        -4
#
#               InvoiceDate  UnitPrice  CustomerID         Country  \
# 12    2010-12-08 15:33:00      14.95     14766.0  United Kingdom
# 94    2011-08-08 11:45:00      16.95     15502.0  United Kingdom
# 95    2011-09-11 11:57:00      16.95     15502.0  United Kingdom
# 107   2011-08-08 11:45:00      16.95     15502.0  United Kingdom
# 108   2011-09-11 11:57:00      16.95     15502.0  United Kingdom
# ...                   ...        ...         ...             ...
# 20570 2011-12-07 13:46:00       1.65     17490.0  United Kingdom
# 20571 2011-09-27 11:52:00       1.25     17490.0  United Kingdom
# 20573 2011-12-07 13:46:00       1.25     17490.0  United Kingdom
# 20594 2011-01-28 13:18:00       6.75     16019.0  United Kingdom
# 20725 2011-10-26 13:45:00      12.75     15311.0  United Kingdom
#
#        ProductVariations
# 12                     1
# 94                     1
# 95                     1
# 107                    1
# 108                    1
# ...                  ...
# 20570                  1
# 20571                  1
# 20573                  1
# 20594                  1
# 20725                  1
#
# [1660 rows x 9 columns]

# %%
# some rows are less than zero...let's see why
df.loc[(df['CustomerID'] == 14766) & (df['StockCode']==22839)].sort_values(by='Description')
# somehow, seems like they cancelled more than they bought...
# let's remove these columns in the final dataset
# Out:
#       InvoiceNo StockCode                      Description  Quantity  \
# 3410    C536625     22839  3 TIER CAKE TIN GREEN AND CREAM        -2
# 19222    537847     22839  3 TIER CAKE TIN GREEN AND CREAM         1
#
#               InvoiceDate  UnitPrice  CustomerID         Country  \
# 3410  2010-12-02 10:46:00      14.95     14766.0  United Kingdom
# 19222 2010-12-08 15:33:00      14.95     14766.0  United Kingdom
#
#        ProductVariations
# 3410                   1
# 19222                  1

# %%
mergedKeys
# Out:
# array(['35004C15311.0', '2296017897.0', '2091414092.0', ...,
#        '2314414397.0', '8497817315.0', '2097917315.0'], dtype=object)

# %%
df['OrderDetails'] = df.apply(lambda row: str(row.StockCode) + str(row.CustomerID), axis=1)
df = df[~df['OrderDetails'].isin(mergedKeys)]
df = pd.concat([df, merged])

# %%
df = df[df['Quantity']>0]

# %%
df['Quantity'].describe()
# Out:
# count    394271.000000
# mean         12.591083
# std          47.108602
# min           1.000000
# 25%           2.000000
# 50%           5.000000
# 75%          12.000000
# max       12540.000000
# Name: Quantity, dtype: float64

# %%
df['UnitPrice'].describe()
# Out:
# count    394271.000000
# mean          2.848911
# std           3.817935
# min           0.001000
# 25%           1.250000
# 50%           1.860000
# 75%           3.750000
# max         295.000000
# Name: UnitPrice, dtype: float64

# %%
df = df.drop(['OrderDetails'], axis=1)
df = df.drop(['InvoiceNo'], axis=1)
df = df.drop(['StockCode'], axis=1)
df
# Out:
#                                Description  Quantity         InvoiceDate  \
# 0       WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1                      WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2           CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3      KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4           RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
# ...                                    ...       ...                 ...
# 20732     HANGING HEART JAR T-LIGHT HOLDER        35 2011-03-29 12:55:00
# 20733     HANGING HEART JAR T-LIGHT HOLDER         5 2011-04-21 10:19:00
# 20734     HANGING HEART JAR T-LIGHT HOLDER        35 2011-05-10 10:11:00
# 20735     HANGING HEART JAR T-LIGHT HOLDER        11 2011-09-14 09:36:00
# 20736        36 PENCILS TUBE RED RETROSPOT         1 2011-11-01 15:40:00
#
#        UnitPrice  CustomerID         Country  ProductVariations
# 0           2.55     17850.0  United Kingdom                  2
# 1           3.39     17850.0  United Kingdom                  1
# 2           2.75     17850.0  United Kingdom                  1
# 3           3.39     17850.0  United Kingdom                  2
# 4           3.39     17850.0  United Kingdom                  2
# ...          ...         ...             ...                ...
# 20732       1.06     17315.0  United Kingdom                  1
# 20733       1.25     17315.0  United Kingdom                  1
# 20734       1.06     17315.0  United Kingdom                  1
# 20735       1.25     17315.0  United Kingdom                  1
# 20736       1.25     17315.0  United Kingdom                  1
#
# [394271 rows x 7 columns]

# %% [markdown]
# ## ==== Description ====
#
# - Description: Product (item) name. Nominal.

# %%
import sys
import numpy
numpy.set_printoptions(threshold=sys.maxsize)
df['Description'].unique()
# Out:
# array(['WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN',
#        'CREAM CUPID HEARTS COAT HANGER',
#        'KNITTED UNION FLAG HOT WATER BOTTLE',
#        'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES',
#        'GLASS STAR FROSTED T-LIGHT HOLDER', 'HAND WARMER UNION JACK',
#        'HAND WARMER RED POLKA DOT', 'ASSORTED COLOUR BIRD ORNAMENT',
#        "POPPY'S PLAYHOUSE BEDROOM ", "POPPY'S PLAYHOUSE KITCHEN",
#        'FELTCRAFT PRINCESS CHARLOTTE DOLL', 'IVORY KNITTED MUG COSY ',
#        'BOX OF VINTAGE ALPHABET BLOCKS', 'HOME BUILDING BLOCK WORD',
#        'LOVE BUILDING BLOCK WORD', 'RECIPE BOX WITH METAL HEART',
#        'DOORMAT NEW ENGLAND', 'YELLOW COAT RACK PARIS FASHION',
#        'BATH BUILDING BLOCK WORD', 'ALARM CLOCK BAKELIKE PINK',
#        'ALARM CLOCK BAKELIKE RED ', 'PANDA AND BUNNIES STICKER SHEET',
#        'STARS GIFT TAPE ', 'INFLATABLE POLITICAL GLOBE ',
#        'VINTAGE HEADS AND TAILS CARD GAME ',
#        'SET/2 RED RETROSPOT TEA TOWELS ',
#        'ROUND SNACK BOXES SET OF4 WOODLAND ', 'SPACEBOY LUNCH BOX ',
#        'CIRCUS PARADE LUNCH BOX ', 'RED TOADSTOOL LED NIGHT LIGHT',
#        ' SET 2 TEA TOWELS I LOVE LONDON ',
#        'VINTAGE SEASIDE JIGSAW PUZZLES', 'MINI JIGSAW CIRCUS PARADE ',
#        'MINI JIGSAW SPACEBOY', 'MINI PAINT SET VINTAGE ',
#        "PAPER CHAIN KIT 50'S CHRISTMAS ", 'EDWARDIAN PARASOL RED',
#        'RETRO COFFEE MUGS ASSORTED', 'SAVE THE PLANET MUG',
#        'VINTAGE BILLBOARD DRINK ME MUG',
#        'VINTAGE BILLBOARD LOVE/HATE MUG',
#        'WOOD 2 DRAWER CABINET WHITE FINISH',
#        'WOOD S/3 CABINET ANT WHITE FINISH',
#        'WOODEN PICTURE FRAME WHITE FINISH', 'WOODEN FRAME ANTIQUE WHITE ',
#        'HOT WATER BOTTLE TEA AND SYMPATHY',
#        'RED HANGING HEART T-LIGHT HOLDER', 'JUMBO BAG PINK POLKADOT',
#        'JUMBO  BAG BAROQUE BLACK WHITE',
#        'JUMBO BAG CHARLIE AND LOLA TOYS',
#        'RED 3 PIECE RETROSPOT CUTLERY SET',
#        'BLUE 3 PIECE POLKADOT CUTLERY SET',
#        'SET/6 RED SPOTTY PAPER PLATES',
#        'STRAWBERRY LUNCH BOX WITH CUTLERY',
#        'LUNCH BOX WITH CUTLERY RETROSPOT ',
#        'PACK OF 60 DINOSAUR CAKE CASES',
#        'TOMATO CHARLIE+LOLA COASTER SET',
#        'CHARLIE & LOLA WASTEPAPER BIN FLORA',
#        'RED CHARLIE+LOLA PERSONAL DOORSIGN',
#        'JUMBO BAG PINK VINTAGE PAISLEY', 'JAM MAKING SET PRINTED',
#        'RETROSPOT TEA SET CERAMIC 11 PC ', 'GIRLY PINK TOOL SET',
#        'AIRLINE LOUNGE,METAL SIGN', 'WHITE SPOT RED CERAMIC DRAWER KNOB',
#        'CLEAR DRAWER KNOB ACRYLIC EDWARDIAN', 'PHOTO CLIP LINE',
#        'FELT EGG COSY CHICKEN', 'PIGGY BANK RETROSPOT ',
#        'SKULL SHOULDER BAG', "YOU'RE CONFUSING ME METAL SIGN ",
#        'COOK WITH WINE METAL SIGN ', 'GIN + TONIC DIET METAL SIGN',
#        'YELLOW BREAKFAST CUP AND SAUCER',
#        'PINK BREAKFAST CUP AND SAUCER ', 'PAPER CHAIN KIT RETROSPOT',
#        'SMALL HEART FLOWERS HOOK ', 'TEA TIME DES TEA COSY',
#        'FELT EGG COSY WHITE RABBIT ', 'ZINC WILLIE WINKIE  CANDLE STICK',
#        'CERAMIC CHERRY CAKE MONEY BANK', 'RETROSPOT LARGE MILK JUG',
#        'SET OF 6 FUNKY BEAKERS', 'EDWARDIAN PARASOL BLACK',
#        'EDWARDIAN PARASOL NATURAL', 'BLUE OWL SOFT TOY',
#        'BALLOON ART MAKE YOUR OWN FLOWERS',
#        'DOORMAT FANCY FONT HOME SWEET HOME', 'VINTAGE SNAKES & LADDERS',
#        'CHOCOLATE CALCULATOR', 'JUMBO SHOPPER VINTAGE RED PAISLEY',
#        'RECYCLING BAG RETROSPOT ', 'TOY TIDY PINK POLKADOT',
#        'ANTIQUE GLASS DRESSING TABLE POT', 'ALARM CLOCK BAKELIKE GREEN',
#        'IVORY GIANT GARDEN THERMOMETER',
#        '3 TIER CAKE TIN GREEN AND CREAM', '3 TIER CAKE TIN RED AND CREAM',
#        'SET 3 WICKER OVAL BASKETS W LIDS',
#        'WOOD BLACK BOARD ANT WHITE FINISH',
#        'COLOUR GLASS T-LIGHT HOLDER HANGING',
#        'HANGING METAL HEART LANTERN', 'HANGING MEDINA LANTERN SMALL',
#        'NATURAL SLATE HEART CHALKBOARD ', 'HEART OF WICKER SMALL',
#        'HEART OF WICKER LARGE', 'WHITE LOVEBIRD LANTERN',
#        'CLASSIC METAL BIRDCAGE PLANT HOLDER', 'CREAM HEART CARD HOLDER',
#        'ENAMEL FLOWER JUG CREAM', 'ENAMEL FIRE BUCKET CREAM',
#        'ENAMEL BREAD BIN CREAM', 'JAM MAKING SET WITH JARS',
#        'JUMBO BAG DOLLY GIRL DESIGN', 'TRADITIONAL CHRISTMAS RIBBONS',
#        'ORGANISER WOOD ANTIQUE WHITE ', 'LUNCH BAG DOLLY GIRL DESIGN',
#        'WHITE WIRE EGG HOLDER', 'CHILLI LIGHTS',
#        'LIGHT GARLAND BUTTERFILES PINK', 'WOODEN OWLS LIGHT GARLAND ',
#        'FAIRY TALE COTTAGE NIGHTLIGHT', 'HOME SMALL WOOD LETTERS',
#        'GINGHAM HEART  DOORSTOP RED', 'FIVE HEART HANGING DECORATION',
#        'ASSORTED BOTTLE TOP  MAGNETS ',
#        'FRIDGE MAGNETS US DINER ASSORTED', 'HOMEMADE JAM SCENTED CANDLES',
#        'FRIDGE MAGNETS LES ENFANTS ASSORTED', 'ROSE CARAVAN DOORSTOP',
#        '5 HOOK HANGER MAGIC TOADSTOOL', 'CHRISTMAS LIGHTS 10 REINDEER',
#        'VINTAGE UNION JACK CUSHION COVER',
#        'SET OF 3 COLOURED  FLYING DUCKS', 'SET OF 3 GOLD FLYING DUCKS',
#        'RED RETROSPOT UMBRELLA', 'BLACK/BLUE POLKADOT UMBRELLA',
#        'RED DINER WALL CLOCK', 'BLUE DINER WALL CLOCK',
#        'IVORY DINER WALL CLOCK', 'LARGE HEART MEASURING SPOONS',
#        'SMALL HEART MEASURING SPOONS', 'JAM JAR WITH PINK LID',
#        'JAM JAR WITH GREEN LID', 'ROSE COTTAGE KEEPSAKE BOX ',
#        'HANGING HEART ZINC T-LIGHT HOLDER',
#        'PAPER CHAIN KIT VINTAGE CHRISTMAS',
#        'DISCO BALL CHRISTMAS DECORATION', 'LARGE POPCORN HOLDER ',
#        'SET/20 RED RETROSPOT PAPER NAPKINS ',
#        'SET/6 RED SPOTTY PAPER CUPS', 'POLKADOT RAIN HAT ',
#        'DELUXE SEWING KIT ', 'RETROSPOT HEART HOT WATER BOTTLE',
#        'ENGLISH ROSE HOT WATER BOTTLE', 'PHOTO CUBE',
#        '3 STRIPEY MICE FELTCRAFT', 'SET OF 6 SOLDIER SKITTLES',
#        'TRADITIONAL WOODEN SKIPPING ROPE', 'WOODEN BOX OF DOMINOES',
#        'RUSTIC  SEVENTEEN DRAWER SIDEBOARD',
#        'PARTY CONES CARNIVAL ASSORTED', 'PARTY CONES CANDY ASSORTED',
#        'PICNIC BASKET WICKER SMALL', 'STAR DECORATION PAINTED ZINC ',
#        'RETROSPOT LAMP', 'FANCY FONT BIRTHDAY CARD, ',
#        'HAND WARMER SCOTTY DOG DESIGN', 'HAND WARMER OWL DESIGN',
#        'HAND WARMER RED RETROSPOT', 'DOG BOWL CHASING BALL DESIGN',
#        'CLOTHES PEGS RETROSPOT PACK 24 ',
#        'HAND OVER THE CHOCOLATE   SIGN ', 'TRAVEL SEWING KIT',
#        'BLACK HEART CARD HOLDER', 'PACK OF 60 PINK PAISLEY CAKE CASES',
#        '60 TEATIME FAIRY CAKE CASES', 'PACK OF 72 RETROSPOT CAKE CASES',
#        'CHICK GREY HOT WATER BOTTLE', 'HAND WARMER BIRD DESIGN',
#        'IVORY EMBROIDERED QUILT ', 'PACK OF 12 RED RETROSPOT TISSUES ',
#        'RED RETROSPOT MUG', 'BABUSHKA LIGHTS STRING OF 10',
#        'DOORMAT FAIRY CAKE', 'STRAWBERRY CERAMIC TRINKET BOX',
#        'PINK DOUGHNUT TRINKET POT ', 'SILK PURSE BABUSHKA PINK',
#        'HOT WATER BOTTLE I AM SO POORLY', 'CHOCOLATE HOT WATER BOTTLE',
#        'WHITE SKULL HOT WATER BOTTLE ', 'SCOTTIE DOG HOT WATER BOTTLE',
#        'BIRD HOUSE HOT WATER BOTTLE', 'BOUDOIR SQUARE TISSUE BOX',
#        'SKULLS SQUARE TISSUE BOX', 'PHOTO FRAME CORNICE',
#        'SILK PURSE BABUSHKA RED', 'PICTURE DOMINOES',
#        'S/6 SEW ON CROCHET FLOWERS', 'SCANDINAVIAN REDS RIBBONS',
#        'BALLOONS  WRITING SET ', 'LAVENDER INCENSE IN TIN',
#        'TV DINNER TRAY VINTAGE PAISLEY',
#        'SET OF 4 ENGLISH ROSE PLACEMATS',
#        'SET OF 4 ENGLISH ROSE COASTERS', 'TRIPLE PHOTO FRAME CORNICE ',
#        'FAMILY PHOTO FRAME CORNICE', 'MIRRORED DISCO BALL ',
#        'DISCO BALL ROTATOR BATTERY OPERATED', 'SILVER LOOKING MIRROR',
#        'LADIES & GENTLEMEN METAL SIGN',
#        'METAL SIGN HER DINNER IS SERVED ', 'DOORMAT TOPIARY',
#        'BATHROOM METAL SIGN', 'KITCHEN METAL SIGN', 'TOILET METAL SIGN',
#        'METAL SIGN TAKE IT OR LEAVE IT ', "I'M ON HOLIDAY METAL SIGN",
#        'GROW YOUR OWN BASIL IN ENAMEL MUG',
#        'SET/10 PINK POLKADOT PARTY CANDLES',
#        'SET 20 NAPKINS FAIRY CAKES DESIGN ', 'SET OF 6 T-LIGHTS SNOWMEN',
#        'SET OF 6 T-LIGHTS SANTA', 'SET OF 9 HEART SHAPED BALLOONS',
#        'SANDWICH BATH SPONGE', 'APPLE BATH SPONGE',
#        'STRAWBERRY BATH SPONGE ', 'BLACK PIRATE TREASURE CHEST',
#        'STAR PORTABLE TABLE LIGHT ', 'SNOWFLAKE PORTABLE TABLE LIGHT ',
#        'PINK OVAL JEWELLED MIRROR', 'RETROSPOT CIGAR BOX MATCHES ',
#        'COSY HOUR GIANT TUBE MATCHES', 'JAZZ HEARTS PURSE NOTEBOOK',
#        'CANDLEHOLDER PINK HANGING HEART', 'ASSORTED COLOUR MINI CASES',
#        'LUNCH BAG RED RETROSPOT', 'LUNCH BAG SPACEBOY DESIGN ',
#        'LUNCH BAG WOODLAND', 'LUNCH BAG PINK POLKADOT',
#        'GUMBALL COAT RACK', 'BLUE NEW BAROQUE CANDLESTICK CANDLE',
#        'PINK NEW BAROQUECANDLESTICK CANDLE',
#        'FAIRY CAKE FLANNEL ASSORTED COLOUR', 'BREAD BIN DINER STYLE PINK',
#        'TEA TIME TABLE CLOTH', 'HOT WATER BOTTLE BABUSHKA ',
#        'HEART IVORY TRELLIS SMALL', 'PINK DRAWER KNOB ACRYLIC EDWARDIAN',
#        'GREEN DRAWER KNOB ACRYLIC EDWARDIAN',
#        'BLUE DRAWER KNOB ACRYLIC EDWARDIAN', 'SMALL POPCORN HOLDER',
#        'SET 6 FOOTBALL CELEBRATION CANDLES',
#        'SET OF 6 GIRLS CELEBRATION CANDLES', 'ROMANTIC PINKS RIBBONS ',
#        'BRIGHT BLUES RIBBONS ', 'CHOCOLATE BOX RIBBONS ',
#        'PARTY INVITES FOOTBALL', 'PARTY INVITES JAZZ HEARTS',
#        'PARTY INVITES SPACEMAN', 'SET OF 3 BUTTERFLY COOKIE CUTTERS',
#        'SET OF 3 HEART COOKIE CUTTERS',
#        '3 PIECE SPACEBOY COOKIE CUTTER SET',
#        'PACK OF 72 SKULL CAKE CASES', 'PACK OF 60 SPACEBOY CAKE CASES',
#        '72 SWEETHEART FAIRY CAKE CASES', 'LUNCH BAG SUKI  DESIGN ',
#        'LUNCH BAG CARS BLUE', 'LUNCH BAG  BLACK SKULL.',
#        'HEART IVORY TRELLIS LARGE', 'SET/5 RED RETROSPOT LID GLASS BOWLS',
#        'MAGIC DRAWING SLATE DINOSAUR', 'MAGIC DRAWING SLATE BAKE A CAKE ',
#        '12 PENCILS TALL TUBE SKULLS', 'RED  HARMONICA IN BOX ',
#        'BLUE HARMONICA IN BOX ', 'SKULLS  WATER TRANSFER TATTOOS ',
#        'PACK 3 BOXES BIRD PANNETONE ', 'SET OF 20 KIDS COOKIE CUTTERS',
#        '10 COLOUR SPACEBOY PEN', 'VICTORIAN GLASS HANGING T-LIGHT',
#        'SINGLE HEART ZINC T-LIGHT HOLDER', 'HANGING METAL STAR LANTERN',
#        'SILVER HANGING T-LIGHT HOLDER', 'DOORMAT RED RETROSPOT',
#        'DOORMAT HEARTS', 'NATURAL SLATE RECTANGLE CHALKBOARD',
#        'LOVEBIRD HANGING DECORATION WHITE ', 'PENS ASSORTED FUNNY FACE',
#        'CARD CIRCUS PARADE', 'WRAP COWBOYS  ',
#        'AIRLINE BAG VINTAGE TOKYO 78',
#        'SET OF 72 RETROSPOT PAPER  DOILIES',
#        'BLUE COAT RACK PARIS FASHION', 'PLASTERS IN TIN SKULLS',
#        'SLEEPING CAT ERASERS', 'CARD BIRTHDAY COWBOY',
#        'PACK 3 BOXES CHRISTMAS PANNETONE',
#        'ROTATING SILVER ANGELS T-LIGHT HLDR',
#        'RIBBON REEL MAKING SNOWMEN ', '4 TRADITIONAL SPINNING TOPS',
#        'BAG 500g SWIRLY MARBLES', '5 STRAND GLASS NECKLACE CRYSTAL',
#        'SQUARECUSHION COVER PINK UNION FLAG',
#        'SPACEBOY CHILDRENS EGG CUP', "CHILDREN'S SPACEBOY MUG",
#        'FELTCRAFT CUSHION OWL', 'BLACK CANDELABRA T-LIGHT HOLDER',
#        'TOY TIDY DOLLY GIRL DESIGN',
#        'SET 12 LAVENDER  BOTANICAL T-LIGHTS',
#        'UNION JACK FLAG LUGGAGE TAG', 'RED HEART LUGGAGE TAG',
#        'RED GLASS TASSLE BAG CHARM', 'CLEAR ACRYLIC FACETED BANGLE',
#        'DOORMAT UNION JACK GUNS AND ROSES',
#        'VANILLA SCENT CANDLE JEWELLED BOX',
#        'FULL ENGLISH BREAKFAST PLATE',
#        'MAGIC DRAWING SLATE CIRCUS PARADE  ',
#        'CHRISTMAS HANGING HEART WITH BELL',
#        'CAKE STAND VICTORIAN FILIGREE MED', 'PAISLEY PATTERN  STICKERS',
#        'FLOWERS  STICKERS', 'JUMBO STORAGE BAG SUKI',
#        'BLACK LOVE BIRD CANDLE', 'PARTY TIME PENCIL ERASERS',
#        "PINK B'FLY C/COVER W BOBBLES", 'PINK UNION JACK  LUGGAGE TAG',
#        '6 RIBBONS ELEGANT CHRISTMAS ', 'AGED GLASS SILVER T-LIGHT HOLDER',
#        'BOOM BOX SPEAKER GIRLS', '6 RIBBONS SHIMMERING PINKS ',
#        'JUMBO BAG OWLS', 'OWL DOORSTOP',
#        'PAINTED METAL STAR WITH HOLLY BELLS',
#        'PAINTED METAL HEART WITH HOLLY BELL',
#        'ANGEL DECORATION STARS ON DRESS', 'JUMBO BAG RED RETROSPOT',
#        'JUMBO BAG STRAWBERRY', 'STRAWBERRY SHOPPER BAG',
#        'STRAWBERRY CHARLOTTE BAG', 'ROUND SNACK BOXES SET OF 4 FRUITS ',
#        'ROUND SNACK BOXES SET OF 4 SKULLS', 'DOLLY GIRL LUNCH BOX',
#        'GREEN POLKADOT PLATE ', 'BLUE POLKADOT PLATE ',
#        'RED RETROSPOT PLATE ', 'PINK  POLKADOT PLATE ',
#        'FELTCRAFT DOLL MOLLY', 'FELTCRAFT CHRISTMAS FAIRY',
#        'SET OF 3 NOTEBOOKS IN PARCEL', 'RED RETROSPOT TAPE',
#        'COSY SLIPPER SHOES SMALL  RED ', '6 RIBBONS RUSTIC CHARM',
#        '12 DAISY PEGS IN WOOD BOX', '5 HOOK HANGER RED MAGIC TOADSTOOL',
#        'CHRISTMAS CRAFT TREE TOP ANGEL', 'CHRISTMAS CRAFT LITTLE FRIENDS',
#        'COSY SLIPPER SHOES SMALL GREEN', 'FELTCRAFT DOLL ROSIE',
#        'FELTCRAFT DOLL EMILY', 'FELTCRAFT PRINCESS OLIVIA DOLL',
#        'REX CASH+CARRY JUMBO SHOPPER', 'FELTCRAFT CUSHION RABBIT',
#        'FELTCRAFT CUSHION BUTTERFLY', 'TOTE BAG I LOVE LONDON',
#        'FOLDING UMBRELLA PINKWHITE POLKADOT',
#        'FOLDING UMBRELLA CREAM POLKADOT',
#        'FOLDING UMBRELLA WHITE/RED POLKADOT', 'SET 10 LIGHTS NIGHT OWL',
#        'FOLDING UMBRELLA RED/WHITE POLKADOT',
#        'S/4 VALENTINE DECOUPAGE HEART BOX', 'SOLDIERS EGG CUP ',
#        'RED RETROSPOT MINI CASES', '60 CAKE CASES VINTAGE CHRISTMAS',
#        'RIBBON REEL CHRISTMAS SOCK BAUBLE', 'RIBBON REEL SNOWY VILLAGE',
#        'SET OF 20 VINTAGE CHRISTMAS NAPKINS', 'TURQUOISE CHRISTMAS TREE ',
#        'RED STAR CARD HOLDER', 'WICKER WREATH SMALL',
#        'ADVENT CALENDAR GINGHAM SACK', 'FELTCRAFT BUTTERFLY HEARTS',
#        'PARTY CONE CHRISTMAS DECORATION ', 'WICKER STAR ',
#        'VINTAGE SNAP CARDS', 'FELTCRAFT 6 FLOWER FRIENDS',
#        'BIRD DECORATION RED RETROSPOT', 'CHRISTMAS GINGHAM TREE',
#        'CHRISTMAS GINGHAM STAR', 'CHRISTMAS GINGHAM HEART',
#        'PACK OF 12 PINK POLKADOT TISSUES', 'FELTCRAFT PRINCESS LOLA DOLL',
#        'PACK OF 12 LONDON TISSUES ',
#        'PURPLE DRAWERKNOB ACRYLIC EDWARDIAN',
#        "CHILDREN'S APRON DOLLY GIRL ", 'CHILDRENS APRON SPACEBOY DESIGN',
#        'CHRISTMAS LIGHTS 10 SANTAS ', 'PACK OF 60 MUSHROOM CAKE CASES',
#        '60 CAKE CASES DOLLY GIRL DESIGN', 'HAND WARMER BABUSHKA DESIGN',
#        'SET 12 RETRO WHITE CHALK STICKS',
#        'FELTCRAFT HAIRBAND RED AND BLUE',
#        'FELTCRAFT HAIRBAND PINK AND PURPLE',
#        'FELTCRAFT HAIRBANDS PINK AND WHITE ', 'TV DINNER TRAY DOLLY GIRL',
#        'PLASTERS IN TIN VINTAGE PAISLEY ', 'PLASTERS IN TIN SPACEBOY',
#        'PLASTERS IN TIN WOODLAND ANIMALS',
#        'MAGIC DRAWING SLATE SPACEBOY ',
#        'MAGIC DRAWING SLATE GO TO THE FAIR ',
#        'MAGIC DRAWING SLATE DOLLY GIRL ',
#        'CHARLIE + LOLA RED HOT WATER BOTTLE', 'URBAN BLACK RIBBONS ',
#        'SET OF 6 T-LIGHTS TOADSTOOLS', 'ROTATING LEAVES T-LIGHT HOLDER',
#        'CUPCAKE LACE PAPER SET 6', 'TRADITIONAL WOODEN CATCH CUP GAME ',
#        'S/6 WOODEN SKITTLES IN COTTON BAG', 'RED METAL BEACH SPADE ',
#        'BOYS VINTAGE TIN SEASIDE BUCKET',
#        'GIRLS VINTAGE TIN SEASIDE BUCKET', 'GREY HEART HOT WATER BOTTLE',
#        'KINGS CHOICE TEA CADDY ', 'KINGS CHOICE BISCUIT TIN',
#        'METAL SIGN EMPIRE TEA', 'FAWN BLUE HOT WATER BOTTLE',
#        'PACK OF 6 BIRDY GIFT TAGS', 'CERAMIC STRAWBERRY MONEY BOX',
#        'CERAMIC STRAWBERRY CAKE MONEY BANK',
#        'CERAMIC HEART FAIRY CAKE MONEY BANK',
#        'CERAMIC PIRATE CHEST MONEY BANK', 'DOORSTOP RETROSPOT HEART',
#        'RETROSPOT BABUSHKA DOORSTOP', 'SWEETHEART WIRE WALL TIDY',
#        'RED RETROSPOT OVEN GLOVE ', 'NAMASTE SWAGAT INCENSE',
#        'CERAMIC STRAWBERRY DESIGN MUG', 'CLASSICAL ROSE SMALL VASE',
#        'HYACINTH BULB T-LIGHT CANDLES', 'CHRISTMAS CRAFT WHITE FAIRY ',
#        'COSY HOUR CIGAR BOX MATCHES ', 'RED TEA TOWEL CLASSIC DESIGN',
#        'HEART FILIGREE DOVE  SMALL', 'RETROSPOT CHILDRENS APRON',
#        'COLOURING PENCILS BROWN TUBE',
#        '4 IVORY DINNER CANDLES SILVER FLOCK',
#        'ZINC METAL HEART DECORATION', 'GREEN FERN NOTEBOOK',
#        'BLUE PAISLEY NOTEBOOK', 'CHRYSANTHEMUM NOTEBOOK',
#        'LARGE CHINESE STYLE SCISSOR', 'SMALL CHINESE STYLE SCISSOR',
#        'HANGING GLASS ETCHED TEALIGHT', 'COOKING SET RETROSPOT',
#        'KINGS CHOICE GIANT TUBE MATCHES', 'PLACE SETTING WHITE STAR',
#        'S/15 SILVER GLASS BAUBLES IN BAG', 'FRENCH WC SIGN BLUE METAL',
#        'FAIRY SOAP SOAP HOLDER', 'GREEN GIANT GARDEN THERMOMETER',
#        'BLUE GIANT GARDEN THERMOMETER', 'VICTORIAN SEWING BOX SMALL ',
#        'VICTORIAN SEWING BOX MEDIUM', 'SET/10 RED POLKADOT PARTY CANDLES',
#        'WASHROOM METAL SIGN', 'BLACK SWEETHEART BRACELET',
#        'DIAMANTE HAIR GRIP PACK/2 BLACK DIA',
#        'BLACK DIAMANTE EXPANDABLE RING', 'DIAMANTE HAIR GRIP PACK/2 RUBY',
#        'DIAMANTE HAIR GRIP PACK/2 MONTANA', 'BLUE SWEETHEART BRACELET',
#        'PINK SWEETHEART BRACELET', 'PURPLE SWEETHEART BRACELET',
#        'RIBBON REEL CHRISTMAS PRESENT ', 'FIRST AID TIN',
#        'MAKE YOUR OWN MONSOON CARD KIT',
#        'PACK OF 12 HEARTS DESIGN TISSUES ', 'HEART FILIGREE DOVE LARGE',
#        'SWIRLY CIRCULAR RUBBERS IN BAG', 'VINTAGE PAISLEY STATIONERY SET',
#        'SET/10 BLUE POLKADOT PARTY CANDLES',
#        'RIBBON REEL SOCKS AND MITTENS', 'CHRISTMAS METAL TAGS ASSORTED ',
#        'CHRISTMAS TREE T-LIGHT HOLDER', 'STAR  T-LIGHT HOLDER ',
#        'HEART T-LIGHT HOLDER ', 'MINI FUNKY DESIGN TAPES',
#        'STAR WOODEN CHRISTMAS DECORATION',
#        'WOODEN HEART CHRISTMAS SCANDINAVIAN',
#        'CHRISTMAS RETROSPOT TREE WOOD',
#        'SET/9 CHRISTMAS T-LIGHTS SCENTED ', 'BLUE ROSE FABRIC MIRROR',
#        'THREE CANVAS LUGGAGE TAGS', 'RETROSPOT PARTY BAG + STICKER SET',
#        'RETROSPOT SMALL TUBE MATCHES', '3D CHRISTMAS STAMPS STICKERS ',
#        '36 FOIL HEART CAKE CASES', 'PACK OF 6 SWEETIE GIFT BOXES',
#        'CINAMMON SET OF 9 T-LIGHTS', 'ORANGE SCENTED SET/9 T-LIGHTS',
#        'RIBBON REEL STRIPES DESIGN ', 'SET OF 2 TINS JARDIN DE PROVENCE',
#        'MAKE YOUR OWN PLAYTIME CARD KIT', 'DINOSAURS  WRITING SET ',
#        'SKULLS WRITING SET ', 'DOORMAT BLACK FLOCK ',
#        'CHRISTMAS DECOUPAGE CANDLE', 'OFFICE MUG WARMER POLKADOT',
#        'SMALL GLASS HEART TRINKET POT', 'BLACK RECORD COVER FRAME',
#        'RECORD FRAME 7" SINGLE SIZE ', '36 PENCILS TUBE RED RETROSPOT',
#        '36 PENCILS TUBE WOODLAND', 'ROCKING HORSE RED CHRISTMAS ',
#        'REGENCY CAKESTAND 3 TIER', 'VINTAGE UNION JACK BUNTING',
#        'RETRO LONGBOARD IRONING BOARD COVER',
#        '3D DOG PICTURE PLAYING CARDS', 'SAVE THE PLANET COTTON TOTE BAG',
#        'PAPER BUNTING WHITE LACE', 'GENTLEMAN SHIRT REPAIR KIT ',
#        'CARD I LOVE LONDON ', 'MIRRORED WALL ART FOXY',
#        'MIRRORED WALL ART GENTS', 'AIRLINE BAG VINTAGE JET SET WHITE',
#        "POTTING SHED SOW 'N' GROW SET",
#        'AIRLINE BAG VINTAGE WORLD CHAMPION ', 'PINK HEARTS PAPER GARLAND',
#        'POTTING SHED SEED ENVELOPES', 'HI TEC ALPINE HAND WARMER',
#        'POLYESTER FILLER PAD 45x45cm', 'CARD DOLLY GIRL ',
#        'CARD BILLBOARD FONT', 'RAINY LADIES BIRTHDAY CARD',
#        'RED WHITE SCARF  HOT WATER BOTTLE',
#        'SET OF 2 TEA TOWELS APPLE AND PEARS', 'LANTERN CREAM GAZEBO ',
#        'BLUE BIRDHOUSE DECORATION', 'ANTIQUE SILVER TEA GLASS ENGRAVED',
#        'SET OF 2 WOODEN MARKET CRATES',
#        'CLASSIC FRENCH STYLE BASKET NATURAL',
#        'CRAZY DAISY HEART DECORATION', 'CARD HOLDER GINGHAM HEART',
#        'SMALL STRIPES CHOCOLATE GIFT BAG ', 'TRAY, BREAKFAST IN BED',
#        'PIZZA PLATE IN BOX', 'PINK HEART DOTS HOT WATER BOTTLE',
#        'PLACE SETTING WHITE HEART', 'SET OF 4 NAPKIN CHARMS LEAVES   ',
#        'SET OF 4 NAPKIN CHARMS STARS   ',
#        'SET OF 4 NAPKIN CHARMS CUTLERY', 'CARAVAN SQUARE TISSUE BOX',
#        'BUTTON BOX ', '12 MESSAGE CARDS WITH ENVELOPES',
#        'SMALL RED BABUSHKA NOTEBOOK ', 'HERB MARKER MINT',
#        'HERB MARKER ROSEMARY', 'HERB MARKER BASIL', 'HERB MARKER CHIVES ',
#        'HERB MARKER PARSLEY', 'HERB MARKER THYME',
#        'METAL MERRY CHRISTMAS WREATH',
#        'WHITE CHRISTMAS GARLAND STARS TREES',
#        'RETROSPOT GIANT TUBE MATCHES', '36 FOIL STAR CAKE CASES ',
#        'PACK OF 6 HANDBAG GIFT BOXES', 'GARLAND WOODEN HAPPY EASTER',
#        'CALENDAR PAPER CUT DESIGN', 'CALENDAR IN SEASON DESIGN',
#        'BLUE PAISLEY TISSUE BOX', 'PINK PAISLEY SQUARE TISSUE BOX ',
#        'TOAST ITS - HAPPY BIRTHDAY',
#        'SET/10 IVORY POLKADOT PARTY CANDLES', 'SKULLS STORAGE BOX SMALL',
#        'JUMBO STORAGE BAG SKULLS', 'GARDEN PATH JOURNAL',
#        'BLACK ORANGE SQUEEZER', 'SET OF 72 GREEN PAPER DOILIES',
#        'RETROSPOT RED WASHING UP GLOVES', 'SMALL LICORICE DES PINK BOWL',
#        'SWISS ROLL TOWEL, CHOCOLATE  SPOTS', 'PICNIC BASKET WICKER LARGE',
#        'CREAM SWEETHEART EGG HOLDER', 'PINK 3 PIECE POLKADOT CUTLERY SET',
#        'PINK PARTY BAGS', 'BLUE PARTY BAGS ',
#        'PINK CREAM FELT CRAFT TRINKET BOX ',
#        'RED RETROSPOT OVEN GLOVE DOUBLE',
#        'RIDGED GLASS STORAGE JAR CREAM LID',
#        'BOX OF 6 ASSORTED COLOUR TEASPOONS',
#        'PACK OF 20 NAPKINS PANTRY DESIGN', 'SWEETHEART CAKESTAND 3 TIER',
#        'CHRISTMAS HANGING STAR WITH BELL',
#        'MULTICOLOUR  CONFETTI IN TUBE',
#        'CHOCOLATE 3 WICK MORRIS BOX CANDLE',
#        'SET OF 16 VINTAGE PISTACHIO CUTLERY', 'CHRISTMAS TOILET ROLL',
#        'WHITE BELL HONEYCOMB PAPER ', ' 4 PURPLE FLOCK DINNER CANDLES',
#        'PINK & WHITE BREAKFAST TRAY', 'ENGLISH ROSE SPIRIT LEVEL ',
#        'LARGE ROUND WICKER PLATTER ', 'BLACK TEA TOWEL CLASSIC DESIGN',
#        'CHRISTMAS LIGHTS 10 VINTAGE BAUBLES',
#        'ROSES REGENCY TEACUP AND SAUCER ', 'T-LIGHT HOLDER HANGING LACE',
#        'HANGING HEART MIRROR DECORATION ',
#        'CREAM SLICE FLANNEL CHOCOLATE SPOT ',
#        'CREAM SLICE FLANNEL PINK SPOT ',
#        'GREEN REGENCY TEACUP AND SAUCER', 'EIGHT PIECE DINOSAUR SET',
#        'HEADS AND TAILS SPORTING FUN',
#        "ASS COL SMALL SAND GECKO P'WEIGHT", 'ENAMEL MEASURING JUG CREAM',
#        '12 PENCILS SMALL TUBE SKULL', '12 PENCIL SMALL TUBE WOODLAND',
#        'BLUE PAPER PARASOL ', 'VICTORIAN  METAL POSTCARD SPRING',
#        'METAL 4 HOOK HANGER FRENCH CHATEAU', 'BLACK KITCHEN SCALES',
#        'RED KITCHEN SCALES', 'IVORY KITCHEN SCALES',
#        'MULTI COLOUR SILVER T-LIGHT HOLDER', '3 HOOK HANGER MAGIC GARDEN',
#        'ASSORTED COLOUR LIZARD SUCTION HOOK',
#        'JUMBO BAG WOODLAND ANIMALS', "CHILDREN'S CIRCUS PARADE MUG",
#        'PACK 3 FIRE ENGINE/CAR PATCHES', 'CARD PSYCHEDELIC APPLES',
#        'IVORY ENCHANTED FOREST PLACEMAT',
#        'PACK OF 6 PANNETONE GIFT BOXES', 'MEASURING TAPE BABUSHKA RED',
#        'RED ENCHANTED FOREST PLACEMAT', 'CHILDRENS DOLLY GIRL MUG',
#        'TOADSTOOL MONEY BOX', 'MAKE YOUR OWN FLOWERPOWER CARD KIT',
#        'PAPER CHAIN KIT LONDON', 'MEASURING TAPE BABUSHKA BLUE',
#        'PENCIL CASE LIFE IS BEAUTIFUL', 'WOODEN ROUNDERS GARDEN SET ',
#        'CHILDS BREAKFAST SET DOLLY GIRL ',
#        'CHILDS BREAKFAST SET SPACEBOY ', 'CAKE PLATE LOVEBIRD WHITE',
#        'WOODEN ADVENT CALENDAR RED', 'GREEN CHRISTMAS TREE CARD HOLDER',
#        'STRING OF STARS CARD HOLDER', 'SET/12 TAPER CANDLES',
#        'VICTORIAN SEWING BOX LARGE', 'MINT KITCHEN SCALES',
#        'WHITE WOOD GARDEN PLANT LADDER',
#        'GLASS JAR ENGLISH CONFECTIONERY', 'GLASS JAR DIGESTIVE BISCUITS',
#        'MILK BOTTLE WITH GLASS STOPPER ', 'WELCOME  WOODEN BLOCK LETTERS',
#        'SET/4 MODERN VINTAGE COTTON NAPKINS', 'VINTAGE UNION JACK APRON',
#        'SWALLOW SQUARE TISSUE BOX', 'NO JUNK MAIL METAL SIGN',
#        'SLATE TILE NATURAL HANGING', 'VINTAGE GLASS COFFEE CADDY',
#        'SILVER GLASS T-LIGHT SET', 'RIDGED GLASS FINGER BOWL',
#        'GLASS  BEURRE DISH', 'GIN & TONIC DIET GREETING CARD ',
#        'BIRTHDAY CARD, RETRO SPOT', 'WRAP RED APPLES ',
#        'RED RETROSPOT WRAP ', 'WRAP CHRISTMAS SCREEN PRINT',
#        'FANCY FONTS BIRTHDAY WRAP', 'CLASSIC WHITE FRAME',
#        'ALARM CLOCK BAKELIKE IVORY', 'BLACK DINER WALL CLOCK',
#        'DOORMAT PEACE ON EARTH BLUE', 'BOX OF 24 COCKTAIL PARASOLS',
#        'GROW YOUR OWN PLANT IN A CAN ', 'PLASTERS IN TIN CIRCUS PARADE ',
#        'PLASTERS IN TIN STRONGMAN', 'MINI JIGSAW DINOSAUR ',
#        'MINI JIGSAW BAKE A CAKE ', 'MINI JIGSAW DOLLY GIRL',
#        'WOODEN SCHOOL COLOURING SET', 'PACK OF 12 TRADITIONAL CRAYONS',
#        'CARD PARTY GAMES ', 'BOOZE & WOMEN GREETING CARD ',
#        'PACK OF 12 SUKI TISSUES ', 'PACK OF 12 WOODLAND TISSUES ',
#        'PACK OF 12 SKULL TISSUES', 'PACK OF 12 BLUE PAISLEY TISSUES ',
#        'PACK OF 12 CIRCUS PARADE TISSUES ', 'PACK OF 12 SPACEBOY TISSUES',
#        'LADS ONLY TISSUE BOX', 'RED RETROSPOT TISSUE BOX',
#        'PACK OF 12 PINK PAISLEY TISSUES ',
#        'GINGERBREAD MAN COOKIE CUTTER', 'GIN AND TONIC MUG',
#        "IF YOU CAN'T STAND THE HEAT MUG",
#        'I CAN ONLY PLEASE ONE PERSON MUG',
#        'PINK HEART SHAPE EGG FRYING PAN', '200 RED + WHITE BENDY STRAWS',
#        'RECIPE BOX RETROSPOT ', 'RECIPE BOX PANTRY YELLOW DESIGN',
#        'RECIPE BOX BLUE SKETCHBOOK DESIGN', '20 DOLLY PEGS RETROSPOT',
#        'NO SINGING METAL SIGN', 'BISCUIT TIN VINTAGE RED',
#        'EMERGENCY FIRST AID TIN ', 'POLKADOT PEN',
#        'DECORATIVE PLANT POT WITH FRIEZE',
#        'CHEST OF DRAWERS GINGHAM HEART ', 'RED RETROSPOT CAKE STAND',
#        'JOY WOODEN BLOCK LETTERS', 'NOEL WOODEN BLOCK LETTERS ',
#        'PEACE WOODEN BLOCK LETTERS', 'OFFICE MUG WARMER BLACK+SILVER ',
#        'SET OF 2 CHRISTMAS DECOUPAGE CANDLE',
#        'COSMETIC BAG VINTAGE ROSE PAISLEY', 'PINK ROSE FABRIC MIRROR',
#        'SILVER PLATE CANDLE BOWL SMALL', 'SMALL REGAL  SILVER CANDLEPOT ',
#        'ANTIQUE TALL SWIRLGLASS TRINKET POT',
#        'ANTIQUE GLASS PEDESTAL BOWL', 'GUMBALL MAGAZINE RACK',
#        'RED FLOWER CROCHET FOOD COVER', 'CHERRY CROCHET FOOD COVER',
#        'STRAWBERRY RAFFIA FOOD COVER', 'POLKA DOT RAFFIA FOOD COVER',
#        'DOORMAT SPOTTY HOME SWEET HOME', 'T-LIGHT GLASS FLUTED ANTIQUE',
#        'SILVER  CANDLEPOT JARDIN ', 'POLKADOT MUG PINK ',
#        'PAPER BUNTING COLOURED LACE', 'ANTIQUE GLASS HEART DECORATION ',
#        'SET OF 6 KASHMIR FOLKART BAUBLES',
#        'CHRISTMAS RETROSPOT ANGEL WOOD', 'CHRISTMAS RETROSPOT STAR WOOD',
#        'HEART WOODEN CHRISTMAS DECORATION',
#        'LARGE HANGING IVORY & RED WOOD BIRD',
#        'SMALL HANGING IVORY/RED WOOD BIRD', 'GRAND CHOCOLATECANDLE',
#        'FAIRY CAKE BIRTHDAY CANDLE SET',
#        '3 HOOK PHOTO SHELF ANTIQUE WHITE',
#        'CREAM SWEETHEART WALL CABINET', 'DOORMAT ENGLISH ROSE ',
#        'DOORMAT UNION FLAG', 'ROMANTIC IMAGES NOTEBOOK SET',
#        'CURIOUS  IMAGES NOTEBOOK SET', 'VINTAGE KEEPSAKE BOX PARIS DAYS',
#        'RED GINGHAM ROSE JEWELLERY BOX',
#        'BLUE CHARLIE+LOLA PERSONAL DOORSIGN',
#        'CHARLIE+LOLA"EXTREMELY BUSY" SIGN', 'CHARLOTTE BAG SUKI DESIGN',
#        'LOLITA  DESIGN  COTTON TOTE BAG',
#        'LETS GO SHOPPING COTTON TOTE BAG', 'PAINT YOUR OWN CANVAS SET',
#        'CAMOUFLAGE LED TORCH', 'BLUE DRAGONFLY HELICOPTER',
#        'YELLOW SHARK HELICOPTER', 'RED SHARK HELICOPTER',
#        'TOOL BOX SOFT TOY ', "DOCTOR'S BAG SOFT TOY",
#        'JUMBO BAG SCANDINAVIAN PAISLEY', 'JUMBO BAG TOYS ',
#        'PAINTED LIGHTBULB STAR+ MOON', 'BLUE TEA TOWEL CLASSIC DESIGN',
#        'LUNCH BOX I LOVE LONDON', 'SET 12 KIDS  WHITE CHALK STICKS',
#        'CHRISTMAS MUSICAL ZINC STAR', 'CHRISTMAS MUSICAL ZINC HEART ',
#        'DOVE DECORATION PAINTED ZINC ',
#        'UNION STRIPE WITH FRINGE  HAMMOCK',
#        'FOLKART ZINC HEART CHRISTMAS DEC', 'SKULLS AND CROSSBONES WRAP',
#        'POLYESTER FILLER PAD 45x30cm', 'POLYESTER FILLER PAD 40x40cm',
#        'PINK FLOWER FABRIC PONY', 'BIRTHDAY PARTY CORDON BARRIER TAPE',
#        'CAMOUFLAGE DESIGN TEDDY', 'TV DINNER TRAY AIR HOSTESS ',
#        'CUSHION COVER PINK UNION JACK', 'CREAM SWEETHEART LETTER RACK',
#        'FRENCH BLUE METAL DOOR SIGN 3', 'FRENCH BLUE METAL DOOR SIGN No',
#        'SET OF 3 BABUSHKA STACKING TINS',
#        'SMALL PURPLE BABUSHKA NOTEBOOK ', 'CHERRY BLOSSOM PASSPORT COVER',
#        'SMALL YELLOW BABUSHKA NOTEBOOK ', 'SWEETHEART WIRE MAGAZINE RACK',
#        'CARDHOLDER HOLLY WREATH METAL',
#        'SILVER CHRISTMAS TREE BAUBLE STAND ',
#        'SWEETHEART RECIPE BOOK STAND',
#        'OVERNIGHT BAG VINTAGE ROSE PAISLEY',
#        'ANT WHITE WIRE HEART SPIRAL', 'FEATHER PEN,COAL BLACK',
#        'FEATHER PEN,LIGHT PINK', 'FEATHER PEN,HOT PINK',
#        'DOORMAT AIRMAIL ', 'NUMBER TILE COTTAGE GARDEN 8',
#        'DOORMAT 3 SMILEY CATS', 'BREAD BIN DINER STYLE IVORY',
#        'MAGNETS PACK OF 4 VINTAGE COLLAGE',
#        'MAGNETS PACK OF 4 HOME SWEET HOME',
#        'MAGNETS PACK OF 4 CHILDHOOD MEMORY', 'ART LIGHTS,FUNK MONKEY',
#        'MINI CAKE STAND WITH HANGING CAKES',
#        'SWEETHEART CERAMIC TRINKET BOX', 'SET OF 4 FAIRY CAKE PLACEMATS',
#        'OFFICE MUG WARMER PINK', 'OFFICE MUG WARMER CHOC+BLUE',
#        'PLEASE ONE PERSON METAL SIGN', 'GLITTER CHRISTMAS HEART ',
#        'CIRCUS PARADE CHILDRENS EGG CUP ',
#        'RED STRIPE CERAMIC DRAWER KNOB',
#        'RED DRAWER KNOB ACRYLIC EDWARDIAN',
#        'NURSERY A,B,C PAINTED LETTERS',
#        'SET OF 2 ROUND TINS DUTCH CHEESE', 'GREEN GEISHA GIRL ',
#        'BLUE GEISHA GIRL ', 'NEWSPAPER STAND', 'CINAMMON & ORANGE WREATH',
#        'LARGE WHITE HONEYCOMB PAPER BELL  ',
#        'WOOD STOCKING CHRISTMAS SCANDISPOT',
#        'SET OF 4 NAPKIN CHARMS HEARTS',
#        'WOODEN TREE CHRISTMAS SCANDINAVIAN',
#        'ROCKING HORSE GREEN CHRISTMAS ',
#        'CHRISTMAS HANGING TREE WITH BELL', 'JINGLE BELLS TREE DECORATION',
#        'SET OF 4 NAPKIN CHARMS 3 KEYS ',
#        'SET OF 4 NAPKIN CHARMS INSTRUMENT',
#        'SET OF 4 NAPKIN CHARMS CROWNS ',
#        'SWALLOW WOODEN CHRISTMAS DECORATION', 'GLITTER CHRISTMAS TREE',
#        'GARLAND WITH STARS AND BELLS', 'CHRISTMAS GARLAND STARS,TREES',
#        'SWISS CHALET TREE DECORATION ',
#        'BIRD BOX CHRISTMAS TREE DECORATION',
#        'WOODEN ADVENT CALENDAR CREAM', 'CARD MOTORBIKE SANTA',
#        'CARD CHRISTMAS VILLAGE', 'DOORMAT I LOVE LONDON',
#        'WOOD AND GLASS MEDICINE CABINET', 'MA CAMPAGNE CUTLERY BOX',
#        'YULETIDE IMAGES GIFT WRAP SET', 'WICKER WREATH LARGE',
#        'TABLE LAMP WHITE SHADE WOOD BASE',
#        'SMALL FOLKART STAR CHRISTMAS DEC',
#        'SMALLFOLKART BAUBLE CHRISTMAS DEC',
#        'SMALL HANGING GLASS+ZINC LANTERN',
#        'SET/3 CHRISTMAS DECOUPAGE CANDLES',
#        'PINK/WHITE CHRISTMAS TREE 60CM',
#        'GREEN CHRISTMAS TREE STRING 20LIGHT',
#        'EUCALYPTUS & PINECONE  WREATH', 'CHRISTMAS PUDDING TRINKET POT ',
#        'BLACK CHRISTMAS TREE 60CM', '15CM CHRISTMAS GLASS BALL 20 LIGHTS',
#        'CARDHOLDER GINGHAM STAR', 'WOODEN STAR CHRISTMAS SCANDINAVIAN',
#        'FINE WICKER HEART ', 'EDWARDIAN PARASOL PINK',
#        'S/4 CACTI CANDLES', 'PINK MARSHMALLOW SCARF KNITTING KIT',
#        '6 CHOCOLATE LOVE HEART T-LIGHTS',
#        'PINK BLUE FELT CRAFT TRINKET BOX', 'TOAST ITS - BEST MUM',
#        'ALARM CLOCK BAKELIKE ORANGE', '3 TRADITIONAL COOKIE CUTTERS  SET',
#        'CHILDRENS SPACEBOY MUG', 'MIRRORED WALL ART SKULLS',
#        'MIRRORED WALL ART STARS', 'CHARLIE+LOLA PINK HOT WATER BOTTLE',
#        'CHARLIE+LOLA RED HOT WATER BOTTLE ',
#        'COWBOYS AND INDIANS BIRTHDAY CARD ',
#        'RING OF ROSES BIRTHDAY CARD', 'BREAD BIN DINER STYLE RED ',
#        'ALARM CLOCK BAKELIKE CHOCOLATE',
#        'CERAMIC CAKE DESIGN SPOTTED MUG', 'LIPSTICK PEN FUSCHIA',
#        'BROCADE RING PURSE ', 'GREEN 3 PIECE POLKADOT CUTLERY SET',
#        'PAINTED METAL PEARS ASSORTED',
#        'COLOUR GLASS. STAR T-LIGHT HOLDER', 'SWALLOWS GREETING CARD',
#        'LADLE LOVE HEART PINK', 'LETTER "M" BLING KEY RING',
#        'LETTER "V" BLING KEY RING', 'LETTER "S" BLING KEY RING',
#        'LETTER "J" BLING KEY RING', 'WALL TIDY RETROSPOT ', 'BINGO SET',
#        'RED RETROSPOT CUP', 'SQUARE FLOOR CUSHION VINTAGE RED',
#        'SET/3 VANILLA SCENTED CANDLE IN BOX',
#        'SET OF 2 TINS VINTAGE BATHROOM ',
#        'BLUE  DIAMANTE PEN IN GIFT BOX', '36 PENCILS TUBE SKULLS',
#        'GREEN FERN JOURNAL ', 'RIBBON REEL FLORA + FAUNA ',
#        'BLACK EAR MUFF HEADPHONES', 'RED POLKADOT COFFEE  MUG',
#        'EMPIRE UNION JACK TV DINNER TRAY', 'ASSORTED TUTTI FRUTTI MIRROR',
#        'SET OF 4 ROSE BOTANICAL CANDLES',
#        'CERAMIC CAKE STAND + HANGING CAKES', 'FELT EGG COSY BLUE RABBIT ',
#        'LOVE HEART SOCK HANGER', 'SCOTTIES CHILDRENS APRON',
#        'CHILDS GARDEN BRUSH PINK', 'LADYBIRD + BEE RAFFIA FOOD COVER',
#        'HOME SWEET HOME MUG', 'CHILDRENS GARDEN GLOVES BLUE',
#        'CHRYSANTHEMUM SKETCHBOOK ', 'BAG 250g SWIRLY MARBLES',
#        'BAG 125g SWIRLY MARBLES', 'ROSE 3 WICK MORRIS BOX CANDLE',
#        'ROSE SCENT CANDLE JEWELLED DRAWER',
#        'RED RETROSPOT CHILDRENS UMBRELLA', 'WHITE BAMBOO RIBS LAMPSHADE',
#        'FOLDING UMBRELLA CHOCOLATE POLKADOT',
#        'CAKE STAND LOVEBIRD 2 TIER WHITE',
#        '3 GARDENIA MORRIS BOXED CANDLES',
#        'SET/4 GARDEN ROSE DINNER CANDLE', 'GOLD PRINT PAPER BAG',
#        'WOODEN HAPPY BIRTHDAY GARLAND', 'SET/4 BADGES CUTE CREATURES',
#        'BLUE PAISLEY POCKET BOOK', 'PORCELAIN ROSE LARGE ',
#        'PORCELAIN ROSE SMALL', 'BAKING SET SPACEBOY DESIGN',
#        'SOAP DISH BROCANTE', 'FLUTED ANTIQUE CANDLE HOLDER',
#        'PEACE SMALL WOOD LETTERS', 'RED RETROSPOT APRON ',
#        'TEA TIME KITCHEN APRON', 'FELTCRAFT DOLL MARIA',
#        'PARTY METAL SIGN ', 'VINTAGE CREAM 3 BASKET CAKE STAND',
#        'CHRISTMAS RETROSPOT HEART WOOD', 'DOORMAT RESPECTABLE HOUSE',
#        'MEMO BOARD RETROSPOT  DESIGN', 'PINK/YELLOW FLOWERS HANDBAG',
#        'CHARLIE+LOLA MY ROOM DOOR SIGN', 'SALLE DE BAIN HOOK',
#        'CHRISTMAS CARD STACK OF PRESENTS',
#        'SET 12 KIDS COLOUR  CHALK STICKS', 'SPACEBOY BIRTHDAY CARD',
#        'ROBOT BIRTHDAY CARD', 'JOY LARGE WOOD LETTERS',
#        'WORLD WAR 2 GLIDERS ASSTD DESIGNS',
#        'CHILDRENS APRON APPLES DESIGN', 'TOAST ITS - FAIRY FLOWER',
#        'CACTI T-LIGHT CANDLES', '12 PENCILS SMALL TUBE RED RETROSPOT',
#        'BALLOON WATER BOMB PACK OF 35', 'BALLOON PUMP WITH 10 BALLOONS',
#        'ALPHABET STENCIL CRAFT', '3 TRADITIONAl BISCUIT CUTTERS  SET',
#        'IVORY PAPER CUP CAKE CASES ', 'PARTY INVITES WOODLAND',
#        'PARTY INVITES BALLOON GIRL', 'LOVELY BONBON STICKER SHEET',
#        'SWEET PUDDING STICKER SHEET', 'ASSTD DESIGN 3D PAPER STICKERS',
#        'CUTE CATS TAPE', 'TOOTHPASTE TUBE PEN',
#        'MAGIC DRAWING SLATE PURDEY', 'PACK OF 12 COLOURED PENCILS',
#        'TOAST ITS - I LOVE YOU ', 'BANK ACCOUNT  GREETING  CARD ',
#        'EMPIRE BIRTHDAY CARD', 'TEA PARTY BIRTHDAY CARD',
#        'CARD CAT AND TREE ', 'CARD DOG AND BALL ',
#        'PENNY FARTHING BIRTHDAY CARD', 'BLUE SPOT CERAMIC DRAWER KNOB',
#        'BLUE STRIPE CERAMIC DRAWER KNOB', 'RED SPOT CERAMIC DRAWER KNOB',
#        'WHITE SPOT BLUE CERAMIC DRAWER KNOB',
#        'HOOK, 1 HANGER ,MAGIC GARDEN', 'EMBOSSED GLASS TEALIGHT HOLDER',
#        'WATERING CAN PINK BUNNY', 'WATERING CAN GREEN DINOSAUR',
#        'WATERING CAN BLUE ELEPHANT', 'FLYING PIG WATERING CAN',
#        'VINTAGE BILLBOARD TEA MUG', 'VINTAGE BILLBOARD MUG ',
#        'LIPSTICK PEN RED', 'FRENCH BLUE METAL DOOR SIGN 1',
#        'FRENCH BATHROOM SIGN BLUE METAL',
#        'YELLOW GIANT GARDEN THERMOMETER', 'CAKESTAND, 3 TIER, LOVEHEART',
#        'GLASS BELL JAR LARGE', 'WATERING CAN GARDEN MARKER',
#        'KINGS CHOICE MUG', 'FRIDGE MAGNETS LA VIE EN ROSE',
#        'RED RETROSPOT ROUND CAKE TINS', 'RETRO MOD TRAY',
#        'PIN CUSHION BABUSHKA PINK', 'BROCANTE SHELF WITH HOOKS',
#        'GREEN POLKADOT BOWL', 'RED RETROSPOT BOWL',
#        'AREA PATROLLED METAL SIGN', 'PICTURE FRAME WOOD TRIPLE PORTRAIT',
#        'SKULLS  STICKERS', 'SET3 BOOK BOX GREEN GINGHAM FLOWER ',
#        'POTTING SHED TEA MUG', 'ROUND CAKE TIN VINTAGE RED',
#        'RETRO PLASTIC ELEPHANT TRAY', 'GOLD MINI TAPE MEASURE ',
#        'RAINBOW PEGS PHOTO CLIP STRING', 'TEATIME PEN CASE & PENS',
#        'PHOTO FRAME 3 CLASSIC HANGING',
#        '3D TRADITIONAL CHRISTMAS STICKERS', 'TRADITIONAL MODELLING CLAY',
#        'SEASIDE FLYING DISC', 'PEG BAG APPLES DESIGN',
#        'GREY FLORAL FELTCRAFT SHOULDER BAG',
#        'CHARLIE LOLA BLUE HOT WATER BOTTLE ',
#        'SET/3 RED GINGHAM ROSE STORAGE BOX',
#        'GLASS HEART T-LIGHT HOLDER ', 'TEA TIME PARTY BUNTING',
#        'WOODEN UNION JACK BUNTING', 'PAPER BUNTING RETROSPOT',
#        'SMALL WHITE RETROSPOT MUG IN BOX ',
#        'SMALL RED RETROSPOT MUG IN BOX ',
#        'SET 3 RETROSPOT TEA,COFFEE,SUGAR',
#        '12 PENCILS TALL TUBE RED RETROSPOT', 'RED RETROSPOT PUDDING BOWL',
#        'RED RETROSPOT TRADITIONAL TEAPOT ', 'DAIRY MAID  PUDDING BOWL',
#        'ASSORTED CAKES FRIDGE MAGNETS',
#        'FOOD CONTAINER SET 3 LOVE HEART ',
#        'DO NOT TOUCH MY STUFF DOOR HANGER ', 'MOODY GIRL DOOR HANGER ',
#        'KEEP OUT BOYS DOOR HANGER ', 'MOODY BOY  DOOR HANGER ',
#        'FOUR HOOK  WHITE LOVEBIRDS', 'FILIGRIS HEART WITH BUTTERFLY',
#        'HEART DECORATION PAINTED ZINC ',
#        'DECORATION HEN ON NEST, HANGING', 'HEN HOUSE DECORATION',
#        'PACK OF 12 STICKY BUNNIES', 'MINI WOODEN HAPPY BIRTHDAY GARLAND',
#        'PINK HAPPY BIRTHDAY BUNTING', 'BLUE HAPPY BIRTHDAY BUNTING',
#        'WOOD STAMP SET BEST WISHES', 'WOOD STAMP SET HAPPY BIRTHDAY',
#        'WOOD STAMP SET THANK YOU', 'GLAMOROUS  MUG',
#        'CREAM WALL PLANTER HEART SHAPED', 'JUMBO BAG SPACEBOY DESIGN',
#        'RED FLORAL FELTCRAFT SHOULDER BAG',
#        'PINK FLORAL FELTCRAFT SHOULDER BAG',
#        'AIRLINE BAG VINTAGE JET SET RED',
#        'AIRLINE BAG VINTAGE JET SET BROWN',
#        'COSY SLIPPER SHOES LARGE GREEN',
#        'WHITE JEWELLED HEART DECORATION',
#        'IVORY HANGING DECORATION  HEART',
#        'STRIPEY CHOCOLATE NESTING BOXES',
#        'CHRISTMAS TREE STAR DECORATION',
#        'CHRISTMAS TREE DECORATION WITH BELL',
#        'CHINESE DRAGON PAPER LANTERNS', 'MILK PAN PINK POLKADOT',
#        'BOOM BOX SPEAKER BOYS', 'PINK FAIRY CAKE CHILDRENS APRON',
#        'SMALL PINK MAGIC CHRISTMAS TREE',
#        'SET OF 4 FAIRY CAKE PLACEMATS ',
#        'RECYCLED PENCIL WITH RABBIT ERASER', 'BLUE CALCULATOR RULER',
#        'RED FLOCK LOVE HEART PHOTO FRAME',
#        'SCENTED CANDLE IN DIGITALIS TIN',
#        'GROW YOUR OWN FLOWERS SET OF 3', 'RED HEART SHAPE LOVE BUCKET ',
#        'VINTAGE POST OFFICE CABINET', 'SET OF 6 3D KIT CARDS FOR KIDS',
#        'CLEAR MILKSHAKE GLASS', 'RED BABY BUNTING ',
#        'BIRDS MOBILE VINTAGE DESIGN', 'WOODLAND  HEIGHT CHART STICKERS ',
#        'DINOSAUR LUNCH BOX WITH CUTLERY', 'RED SPOTTY BISCUIT TIN',
#        'CHARLIE + LOLA BISCUITS TINS', 'CHARLIE AND LOLA TABLE TINS',
#        'CHARLIE AND LOLA FIGURES TINS', 'CAKE STAND WHITE TWO TIER LACE',
#        'BLUE POLKADOT BOWL', 'PINK  POLKADOT CUP',
#        'SKULL AND CROSSBONES  GARLAND ', 'PACK OF 6 SKULL PAPER CUPS',
#        'PACK OF 6 SKULL PAPER PLATES', 'PACK OF 20 SKULL PAPER NAPKINS',
#        '200 BENDY SKULL STRAWS', 'SKULLS PARTY BAG + STICKER SET',
#        'SET OF 9 BLACK SKULL BALLOONS', 'STRAWBERRY HONEYCOMB  GARLAND ',
#        'PINK POLKADOT BOWL', 'SET OF 6 T-LIGHTS WEDDING CAKE ',
#        'MINI CAKE STAND T-LIGHT HOLDER', 'SHOE SHINE BOX ',
#        'BREAD BIN DINER STYLE MINT', 'VANILLA INCENSE 40 CONES IN TIN',
#        'LAVENDER INCENSE 40 CONES IN TIN', 'COLUMBIAN CANDLE ROUND ',
#        'COLUMBIAN CANDLE RECTANGLE', 'ZINC FINISH 15CM PLANTER POTS',
#        'SMALL SQUARE CUT GLASS CANDLESTICK', 'SILK PURSE BABUSHKA BLUE',
#        'ARMY CAMO BOOKCOVER TAPE', 'CARROT CHARLIE+LOLA COASTER SET',
#        'MEMO BOARD COTTAGE DESIGN', 'CHILDS GARDEN SPADE BLUE',
#        'LOVE HEART NAPKIN BOX ', 'SKULLS GREETING CARD',
#        'HANGING CHICK  YELLOW DECORATION',
#        'SET OF 72 SKULL PAPER  DOILIES',
#        'SET OF 36 PAISLEY FLOWER DOILIES', 'SPACEBOY GIFT WRAP',
#        'BLUE GLASS CHUNKY CHARM BRACELET',
#        'BLACK+WHITE NECKLACE W TASSEL',
#        'AMBER CHUNKY GLASS+BEAD NECKLACE',
#        "POPPY'S PLAYHOUSE LIVINGROOM ", 'GINGHAM ROSE WRAP',
#        '12 PENCILS TALL TUBE POSY', '12 COLOURED PARTY BALLOONS',
#        'PINK FLOWER CROCHET FOOD COVER', 'FLOWER VINE RAFFIA FOOD COVER',
#        'FOOD/DRINK SPONGE STICKERS', 'PINK HEART SHAPE PHOTO FRAME',
#        'LILAC DIAMANTE PEN IN GIFT BOX',
#        'SILVER DIAMANTE PEN IN GIFT BOX', 'BLUE JUICY FRUIT PHOTO FRAME',
#        'GREEN JUICY FRUIT PHOTO FRAME', 'GLITTER BUTTERFLY CLIPS',
#        'ASSORTED CREEPY CRAWLIES', 'VINTAGE UNION JACK MEMOBOARD',
#        'BASKET OF FLOWERS SEWING KIT', 'ANTIQUE SILVER TEA GLASS ETCHED',
#        'FAMILY ALBUM WHITE PICTURE FRAME', 'WRAP PINK FAIRY CAKES ',
#        'BABY BOOM RIBBONS ', 'ENAMEL WASH BOWL CREAM', 'LOCAL CAFE MUG',
#        'DIAMANTE BOW BROOCH BLACK COLOUR',
#        'DIAMANTE BOW BROOCH GREEN COLOUR',
#        'DIAMANTE BOW BROOCH RED COLOUR', 'LILY BROOCH AMETHYST COLOUR',
#        'PAIR OF ENAMEL BUTTERFLY HAIRCLIP',
#        'AMETHYST DIAMANTE EXPANDABLE RING', 'PURPLE GEMSTONE BRACELET',
#        'BLACK GEMSTONE BRACELET', 'PURPLE GEMSTONE NECKLACE 45CM',
#        '5 STRAND GLASS NECKLACE BLACK', 'DROP DIAMANTE EARRINGS CRYSTAL',
#        'AMETHYST HOOP EARRING FLORAL LEAF',
#        'HANGING BAUBLE T-LIGHT HOLDER LARGE',
#        'CUT GLASS HEXAGON T-LIGHT HOLDER', 'CLAM SHELL SMALL ',
#        'CLAM SHELL LARGE', 'COCKLE SHELL DISH',
#        'PARTY PIZZA DISH RED RETROSPOT', 'SPACEBOY TV DINNER TRAY',
#        'PINK TALL PORCELAIN T-LIGHT HOLDER ',
#        'WHITE TALL PORCELAIN T-LIGHT HOLDER',
#        'DOLLY GIRL CHILDRENS EGG CUP', 'KEY FOB , GARAGE DESIGN',
#        'GARDEN METAL SIGN ', 'KEY FOB , FRONT  DOOR ',
#        'KEY FOB , BACK DOOR ', 'SET OF 6 CAKE CHOPSTICKS',
#        'SET OF 6 STRAWBERRY CHOPSTICKS', 'CHRYSANTHEMUM POCKET BOOK ',
#        'GARDEN PATH POCKET BOOK', 'RED DAISY POCKET BOOK ',
#        '12 PENCILS TALL TUBE WOODLAND', 'FROG SOCK PUPPET',
#        'PINK HORSE SOCK PUPPET', 'BLACK WINE GLASS',
#        'CLASSICAL ROSE CANDLESTAND', 'GAOLERS KEYS DECORATIVE GARDEN ',
#        'RED RETROSPOT PEG BAG', 'FAIRY CAKE DESIGN UMBRELLA',
#        'BIG DOUGHNUT FRIDGE MAGNETS', 'WRAP, BILLBOARD FONTS DESIGN',
#        'GIFT BAG PSYCHEDELIC APPLES', 'BLACK ENCHANTED FOREST PLACEMAT',
#        'WRAP GREEN PEARS ', 'RED RETROSPOT CHARLOTTE BAG',
#        'PAPER CHAIN KIT EMPIRE', 'CHARLOTTE BAG PINK POLKADOT',
#        'TOY TIDY SPACEBOY  ', '4 ROSE PINK DINNER CANDLES',
#        '4 SKY BLUE DINNER CANDLES', 'CHARLOTTE BAG DOLLY GIRL DESIGN',
#        'TWO DOOR CURIO CABINET', 'PINK POLKADOT WRAP ',
#        'ASSORTED COLOURS SILK FAN', 'SPOTTY PINK DUCK DOORSTOP',
#        'Bank Charges', 'RED RETROSPOT SHOPPER BAG',
#        'RED RETROSPOT BUTTER DISH', 'LOVE GARLAND PAINTED ZINC ',
#        'MEASURING TAPE BABUSHKA PINK', 'VINTAGE KID DOLLY CARD ',
#        'ELEPHANT, BIRTHDAY CARD, ', 'BLUE POLKADOT WRAP',
#        'MIRROR LOVE BIRD T-LIGHT HOLDER',
#        'BLACK LOVE BIRD T-LIGHT HOLDER', 'HAND OPEN SHAPE GOLD',
#        'FELT FARM ANIMAL WHITE BUNNY ', 'RED RETROSPOT PURSE ',
#        'SNOWSTORM PHOTO FRAME FRIDGE MAGNET', 'RED POLKADOT PUDDING BOWL',
#        'BLUE POLKADOT PUDDING BOWL', 'VINTAGE BLUE TINSEL REEL',
#        'JARDIN ETCHED GLASS BUTTER DISH', 'SPACE FROG',
#        'SPACE CADET BLACK', 'SPACE CADET RED', 'SPACE OWL',
#        'SPACE CADET WHITE', 'WOODLAND DESIGN  COTTON TOTE BAG',
#        'ILLUSTRATED CAT BOWL ', 'TOAST ITS - DINOSAUR',
#        'WOODLAND CHARLOTTE BAG', 'GARDEN PATH SKETCHBOOK',
#        'BLUE POLKADOT COFFEE MUG', 'BOX OF VINTAGE JIGSAW BLOCKS ',
#        'MONSTERS STENCIL CRAFT', 'CITRONELLA CANDLE GARDEN POT',
#        'MODERN FLORAL STATIONERY SET', 'FUNKY WASHING UP GLOVES ASSORTED',
#        'FLORAL FOLK STATIONERY SET', 'SUKI  SHOULDER BAG',
#        'BLUE POLKADOT WASHING UP GLOVES',
#        'CHILDS BREAKFAST SET CIRCUS PARADE', 'WOODLAND STORAGE BOX SMALL',
#        'SKULLS  DESIGN  COTTON TOTE BAG',
#        'FLOWER BURST SILVER RING CRYSTAL', 'LAUNDRY 15C METAL SIGN',
#        "FANNY'S REST STOPMETAL SIGN", 'CHOCOLATE THIS WAY METAL SIGN',
#        'HOT BATHS METAL SIGN', 'POTTERING IN THE SHED METAL SIGN',
#        'KEY FOB , SHED', 'LOVE HEART POCKET WARMER',
#        'BOTANICAL LAVENDER BIRTHDAY CARD', 'GLASS CLOCHE LARGE',
#        'GLASS CLOCHE SMALL', 'CORONA MEXICAN TRAY', 'KIDS RAIN MAC BLUE',
#        'MONEY BOX CONFECTIONERY DESIGN', 'MONEY BOX KINGS CHOICE DESIGN',
#        'MONEY BOX POCKET MONEY DESIGN', 'ASSORTED COLOUR T-LIGHT HOLDER',
#        'WEEKEND BAG VINTAGE ROSE PAISLEY',
#        'CERAMIC CAKE BOWL + HANGING CAKES',
#        'CHRISTMAS CARD SCREEN PRINT ', 'CHRISTMAS CARD SINGING ANGEL',
#        'PAPER BUNTING VINTAGE PAISLEY', 'PARTY INVITES DINOSAURS',
#        'ENAMEL WATERING CAN CREAM', 'ENAMEL COLANDER CREAM',
#        'BLUE POLKADOT CUP', 'BLUE/CREAM STRIPE CUSHION COVER ',
#        'UNION STRIPE CUSHION COVER ', 'KEY CABINET MA CAMPAGNE',
#        'CREAM SWEETHEART MINI CHEST', 'DINOSAUR PARTY BAG + STICKER SET',
#        'IVY HEART WREATH', 'VINTAGE RED KITCHEN CABINET',
#        'LARGE CAKE STAND HANGING HEARTS',
#        'LARGE CAKE STAND  HANGING STRAWBERY',
#        'RED RETROSPOT SUGAR JAM BOWL', 'RED RETROSPOT SHOPPING BAG',
#        'RED RETROSPOT WASHBAG', 'TEA TIME OVEN GLOVE',
#        'STRAWBERRY FAIRY CAKE TEAPOT', 'WRAP ENGLISH ROSE ',
#        'WRAP  PINK FLOCK', 'TUB 24 PINK FLOWER PEGS',
#        'FENG SHUI PILLAR CANDLE', 'DECOUPAGE,GREETING CARD,',
#        'NOVELTY BISCUITS CAKE STAND 3 TIER',
#        'ROUND CAKE TIN VINTAGE GREEN', 'DAIRY MAID TOASTRACK',
#        'DAIRY MAID TRADITIONAL TEAPOT ',
#        'GLITTER HEART GARLAND WITH BELLS ',
#        'GLITTER STAR GARLAND WITH BELLS ', 'HEART GARLAND RUSTIC PADDED',
#        'LAVENDER SCENTED FABRIC HEART', 'BLUE POLKADOT PASSPORT COVER',
#        'SET/6 BEAD COASTERS GAUZE BAG GOLD',
#        'GROW YOUR OWN HERBS SET OF 3', 'PINK POLKADOT CHILDRENS UMBRELLA',
#        'WOODEN CROQUET GARDEN SET', 'STAR DECORATION RUSTIC',
#        'WHITE CHRISTMAS STAR DECORATION',
#        'HEART DECORATION RUSTIC HANGING ',
#        'PORCELAIN T-LIGHT HOLDERS ASSORTED',
#        'CHOC TRUFFLE GOLD TRINKET POT ', 'WASH BAG VINTAGE ROSE PAISLEY',
#        'CABIN BAG VINTAGE PAISLEY', "POPPY'S PLAYHOUSE BATHROOM",
#        'TRADITIONAL KNITTING NANCY', 'VINTAGE CREAM CAT FOOD CONTAINER',
#        'FAUX FUR CHOCOLATE THROW', 'RIBBON REEL LACE DESIGN ',
#        'LUSH GREENS RIBBONS', 'PACK OF 6 SANDCASTLE FLAGS ASSORTED',
#        'BEADED PEARL HEART WHITE ON STICK',
#        '3 HEARTS HANGING DECORATION RUSTIC',
#        'COFFEE MUG CAT + BIRD DESIGN', 'HEARTS WRAPPING TAPE ',
#        'DOGGY RUBBER', 'MAGIC TREE -PAPER FLOWERS',
#        'BLUE PAISLEY JOURNAL ', 'NECKLACE+BRACELET SET FRUIT SALAD ',
#        'LARGE PURPLE BABUSHKA NOTEBOOK  ', 'SKULLS TAPE',
#        'CAKES AND BOWS GIFT  TAPE', 'LARGE YELLOW BABUSHKA NOTEBOOK ',
#        'LARGE RED BABUSHKA NOTEBOOK ', 'ANGEL DECORATION 3 BUTTONS ',
#        '75 GREEN PETIT FOUR CASES', 'SET OF 36 TEATIME PAPER DOILIES',
#        'ROSE DU SUD OVEN GLOVE', 'BROWN CHECK CAT DOORSTOP ',
#        'BLACK AND WHITE CAT BOWL', 'HOLIDAY FUN LUDO',
#        '6 RIBBONS EMPIRE  ', 'RED COAT RACK PARIS FASHION',
#        'LA PALMIERA WALL THERMOMETER',
#        'PACK 20 ENGLISH ROSE PAPER NAPKINS',
#        'SET/20 STRAWBERRY PAPER NAPKINS ', 'ASSORTED INCENSE PACK',
#        'VANILLA INCENSE IN TIN', 'YULETIDE IMAGES S/6 PAPER BOXES',
#        '3D VINTAGE CHRISTMAS STICKERS ',
#        'SET/3 FLORAL GARDEN TOOLS IN BAG', 'ROBOT MUG IN DISPLAY BOX',
#        'PACK/12 BLUE FOLKART CARDS', 'FOLK ART GREETING CARD,pack/12',
#        'VINTAGE CARAVAN GREETING CARD ', 'SET OF SKULL WALL STICKERS',
#        'HEARTS  STICKERS', 'ENGLISH ROSE GARDEN SECATEURS',
#        'ASSORTED FLOWER COLOUR "LEIS"', 'EIGHT PIECE SNAKE  SET',
#        'SMALL CAMPHOR WOOD FIELD  MUSHROOM',
#        'CAMPHOR WOOD PORTOBELLO MUSHROOM',
#        'PINK/GREEN FLOWER DESIGN BIG MUG',
#        "FLOWER FAIRY,5 SUMMER B'DRAW LINERS", 'RED LOVE HEART SHAPE CUP',
#        'PINK LOVE HEART SHAPE CUP', 'BLUE/YELLOW FLOWER DESIGN BIG MUG',
#        'GREEN/BLUE FLOWER DESIGN BIG MUG',
#        'PINK  HEART SHAPE LOVE BUCKET ',
#        'SCANDINAVIAN PAISLEY PICNIC BAG',
#        'PINK VINTAGE PAISLEY PICNIC BAG',
#        'CHARLIE AND LOLA CHARLOTTE BAG',
#        'YELLOW/PINK FLOWER DESIGN BIG MUG',
#        'RED RETROSPOT TEA CUP AND SAUCER ', 'FAIRY CAKE NOTEBOOK A5 SIZE',
#        'ENGLISH ROSE NOTEBOOK A7 SIZE', 'MORE BUTTER METAL SIGN ',
#        'HOME SWEET HOME METAL SIGN ', 'PARTY BUNTING',
#        'STRAWBERRIES  DESIGN FLANNEL ',
#        'VINTAGE CREAM DOG FOOD CONTAINER', 'DOORMAT NEIGHBOURHOOD WITCH ',
#        'PHARMACIE FIRST AID TIN', 'NATURAL SLATE CHALKBOARD LARGE ',
#        'METAL SIGN HIS DINNER IS SERVED',
#        'BEADED PEARL HEART WHITE LARGE',
#        'BEADED CRYSTAL HEART BLUE SMALL',
#        'SET OF SALT AND PEPPER TOADSTOOLS', 'RIBBON REEL POLKADOTS ',
# ...
#        'PURPLE FRANGIPANI NECKLACE', 'ROSE PENDANT TRIPLE SHELL NECKLACE',
#        'ORANGE PENDANT TRIPLE SHELL NECKLAC', 'WRAP ALPHABET POSTER  ',
#        'LAUREL STAR ANTIQUE GOLD', 'PURPLE/BLUE CERAMIC CANDLE HOLDER',
#        'BLUE/YELLOW CERAMIC CANDLE HOLDER',
#        'GREEN/BLUE CERAMIC CANDLE HOLDER', 'PURPLE DRESS JEWELLERY STAND',
#        'WRAP BIRD GARDEN ', 'WRAP PAISLEY PARK ',
#        'THE KING GIFT BAG 25x24x12cm', 'CUTE RABBIT CEATURE SCREEN ',
#        'CUTE BIRD CEATURE SCREEN', 'WRAP RED DOILEY',
#        'WRAP FLOWER SHOP  ', 'WRAP MAGIC FOREST ',
#        'BIRD ON BRANCH CANVAS SCREEN', "WRAP 50'S  CHRISTMAS",
#        'BLUE MONTE CARLO HANDBAG', 'PINK/BLUE STRING CURTAIN ',
#        'I LOVE LONDON BEAKER', ' DOLLY GIRL BEAKER', 'SPACEBOY BEAKER',
#        'DOORKNOB CERAMIC IVORY', 'ORIENTAL RED CUSHION COVER ',
#        'PINK BITTY LIGHT CHAIN', 'LIGHT PINK FLOCK GLASS CANDLEHOLDER',
#        'MONEY BOX FIRST AID DESIGN', 'VINTAGE CHRISTMAS CAKE FRILL',
#        'MISELTOE HEART WREATH CREAM', 'VINTAGE BEAD PINK JEWEL STAND',
#        'GOLD M.O.P ORBIT BRACELET', 'SET 8 CANDLES VINTAGE DOILEY',
#        'SET OF 12 T-LIGHTS VINTAGE DOILEY',
#        'VINTAGE CHRISTMAS PAPER GIFT BAG',
#        'GIFT BAG LARGE VINTAGE CHRISTMAS',
#        '6 GIFT TAGS VINTAGE CHRISTMAS ', "6 GIFT TAGS 50'S CHRISTMAS ",
#        'RED SPOT PAPER GIFT BAG', 'WHITE FRANGIPANI NECKLACE',
#        ' RED SPOT GIFT BAG LARGE', 'SET OF 12 FORK CANDLES',
#        'BLUE PAINTED KASHMIRI CHAIR', 'ROLL WRAP VINTAGE CHRISTMAS',
#        'ROLL WRAP VINTAGE SPOT ', 'GIFT BAG LARGE SPOT ',
#        "ROLL WRAP 50'S RED CHRISTMAS ", "ROLL WRAP 50'S CHRISTMAS",
#        'JUMBO BAG VINTAGE DOILEY ', 'ADULT APRON APPLE DELIGHT',
#        'WRAP  VINTAGE DOILEY ', 'SET OF 4 KNICK KNACK TINS DOILY ',
#        'RUSTIC STRAWBERRY JAMPOT LARGE ', 'PURPLE ENAMEL+GLASS HAIR COMB',
#        'JUMBO BAG VINTAGE DOILY ', 'LUNCH BAG VINTAGE DOILY ',
#        'SET 8 CANDLES VINTAGE DOILY', 'STORAGE TIN VINTAGE DOILY ',
#        'IVORY WICKER HEART LARGE', 'DECORATIVE WICKER HEART LARGE',
#        'ASSORTED COLOURED CIRCLE MOBILE ',
#        'MIDNIGHT BLUE VINTAGE EARRINGS', 'DECORATIVE WICKER HEART MEDIUM',
#        'IVORY WICKER HEART SMALL', 'IVORY WICKER HEART MEDIUM',
#        'LUNCH BAG VINTAGE DOILEY ', 'WRAP  VINTAGE DOILY ',
#        'STORAGE TIN VINTAGE DOILEY ',
#        'SET OF 4 KNICK KNACK TINS  DOILEY ',
#        'SET 6 SCHOOL MILK BOTTLES IN CRATE',
#        'DECORATIVE WICKER HEART SMALL', 'HANGING CLEAR MINI BOTTLE',
#        'SET OF 12 T-LIGHTS VINTAGE DOILY',
#        'HANGING MINI COLOURED BOTTLES', 'RUSTIC STRAWBERRY JAMPOT SMALL',
#        'PINK ACRYLIC JEWEL SNOWFLAKE', 'ACRYLIC JEWEL ANGEL,PINK',
#        'WRAP RED VINTAGE DOILY', 'RUSTIC STRAWBERRY JAM POT SMALL',
#        'PINK/WHITE CHRISTMAS TREE 30CM', 'ACRYLIC JEWEL ICICLE, BLUE',
#        'RUSTIC STRAWBERRY JAM POT LARGE ',
#        'VINTAGE CHRISTMAS GIFT BAG LARGE ',
#        'BLUE FELT HANGING HEART WITH FLOWER', 'HOT WATER BOTTLE SEX BOMB',
#        'HOT STUFF HOT WATER BOTTLE', "50'S CHRISTMAS PAPER GIFT BAG",
#        'LOVE HOT WATER BOTTLE', '3 BLACK CATS W HEARTS BLANK CARD',
#        'HAPPY BIRTHDAY CARD STRIPEY TEDDY', 'HOT WATER BOTTLE KEEP CALM',
#        'DIAMANTE NECKLACE', 'DIAMANTE NECKLACE GREEN',
#        " 50'S CHRISTMAS GIFT BAG LARGE", 'GREEN PAIR HEART HAIR SLIDES',
#        'CORDIAL JUG', 'ICE CREAM BUBBLES', 'NOEL GARLAND PAINTED ZINC ',
#        'HAND WARMER RED LOVE HEART', 'SILVER BLACK ORBIT DROP EARRINGS',
#        "NEW BAROQUE B'FLY NECKLACE RED",
#        'DIAMOND LAS VEGAS NECKLACE 45CM',
#        'NATURAL HANGING QUILTED HEARTS ',
#        'HANGING QUILTED PATCHWORK APPLES',
#        'HAPPY BIRTHDAY CARD TEDDY/CAKE',
#        '3 DRAWER ANTIQUE WHITE WOOD CABINET',
#        'FLOWER FAIRY 5 DRAWER LINERS', 'ELEPHANT BIRTHDAY CARD ',
#        'ACRYLIC HANGING JEWEL,BLUE', 'PRETTY HANGING QUILTED HEARTS',
#        'HANGING JAM JAR T-LIGHT HOLDERS', 'SWEETHEART 3 TIER CAKE STAND ',
#        'PACK OF 12 VINTAGE CHRISTMAS TISSUE',
#        "PACK OF 12 50'S CHRISTMAS TISSUES",
#        'AMBER DROP EARRINGS W LONG BEADS',
#        'PACK OF 12 PAISLEY PARK TISSUES ',
#        'CHILDRENS TOY COOKING UTENSIL SET', 'MINT DINER CLOCK',
#        'BUTTERFLY CUSHION COVER', 'BELLE JARDINIERE CUSHION COVER',
#        'POSTE FRANCE CUSHION COVER', 'SET OF 2 TRAYS HOME SWEET HOME',
#        'HOME SWEET HOME CUSHION COVER ', 'STOOL HOME SWEET HOME ',
#        'PACK OF 12 DOLLY GIRL TISSUES', 'HOME SWEET HOME HANGING HEART',
#        ' TRELLIS COAT RACK', 'HANGING HEART BONHEUR',
#        'LA JARDIN BOTANIQUE CUSHION COVER', 'FOOT STOOL HOME SWEET HOME ',
#        'HOME SWEET HOME BLACKBOARD', 'GINGHAM RECIPE BOOK BOX',
#        'HOME SWEET HOME KEY HOLDER', 'ZINC BOX SIGN HOME',
#        'HOME SWEET HOME 2 DRAWER CABINET', 'PACK OF 12 RED APPLE TISSUES',
#        'PACK OF 12 VINTAGE LEAF TISSUES ',
#        'PACK OF 12 VINTAGE DOILY TISSUES',
#        'HOME SWEEET HOME 3 PEG HANGER ', 'LETTER HOLDER HOME SWEET HOME',
#        "GIFT BAG LARGE 50'S CHRISTMAS", 'METAL SIGN DROP YOUR PANTS',
#        'STORAGE TIN HOME SWEET HOME', 'HEART MIRROR ANTIQUE WHITE',
#        'SPACEBOY ROCKET LOLLY MAKERS',
#        'SHELF WITH 4 HOOKS HOME SWEET HOME', 'ENAMEL DINNER PLATE PANTRY',
#        'SILVER BLACK ORBIT BRACELET',
#        'GLASS AND PAINTED BEADS BRACELET TO',
#        'FAIRY TALE COTTAGE NIGHT LIGHT', 'HOME SWEET HOME HOOK',
#        'BATHROOM HOOK', 'HOME SWEET HOME 3 PEG HANGER ',
#        'VINTAGE COFFEE GRINDER BOX', 'PHOTO FRAME LINEN AND LACE LARGE',
#        'PHOTO FRAME LINEN AND LACE SMALL',
#        'RUSTIC MIRROR WITH LACE HEART', 'CURIO CABINET LINEN AND LACE ',
#        'WOODLAND BUNNIES LOLLY MAKERS',
#        'PANTRY 3 HOOK ROLLING PIN HANGER', 'PANTRY HOOK SPATULA',
#        'PANTRY HOOK BALLOON WHISK ', 'METALIC LEAVES BAG CHARMS',
#        'LAVENDER TOILETTE BOTTLE', 'HOME SWEET HOME BOTTLE ',
#        '3 RAFFIA RIBBONS VINTAGE CHRISTMAS',
#        "3 RAFFIA RIBBONS 50'S CHRISTMAS ", ' I LOVE LONDON MINI BACKPACK',
#        'DOLLY GIRL MINI BACKPACK', 'SPACEBOY MINI BACKPACK',
#        'EMBOSSED HEART TRINKET BOX', 'WOODLAND MINI BACKPACK',
#        'PAINTED HEART WREATH WITH BELL', 'CHAMBRE HOOK',
#        'CHRISTMAS HANGING SNOWFLAKE', 'FLAG OF ST GEORGE CAR FLAG',
#        'PANTRY HOOK TEA STRAINER ', 'PANTRY CHOPPING BOARD',
#        'ACRYLIC HANGING JEWEL,PINK', 'BLUE CLIMBING HYDRANGA ART FLOWER',
#        'LE JARDIN BOTANIQUE CUSHION COVER',
#        'FLOWER FAIRY 5 SUMMER DRAW LINERS',
#        'CRYSTAL SEA HORSE PHONE CHARM',
#        'PLAYING CARDS KEEP CALM & CARRY ON',
#        'SET 12 COLOURING PENCILS DOILY',
#        'SET 12 COLOUR PENCILS SPACEBOY ',
#        'PLAYING CARDS JUBILEE UNION JACK',
#        'SET 36 COLOUR PENCILS SPACEBOY ', 'MINI PLAYING CARDS SPACEBOY ',
#        'PLAYING CARDS VINTAGE DOILEY ', 'SET 36 COLOUR PENCILS DOILEY',
#        'SET 12 COLOUR PENCILS DOILEY', 'PACK OF 12 DOILEY TISSUES',
#        'VINTAGE DOILY TRAVEL SEWING KIT',
#        'SET 12 COLOUR PENCILS LOVE LONDON',
#        'SET 36 COLOUR PENCILS LOVE LONDON',
#        'EMBROIDERED RIBBON REEL RUBY ', 'EMBROIDERED RIBBON REEL EMILY ',
#        'EMBROIDERED RIBBON REEL REBECCA ',
#        'SET 36 COLOURING PENCILS DOILY',
#        'SET 12 COLOUR PENCILS DOLLY GIRL ',
#        'PLAYING CARDS I LOVE LONDON ', 'SET 36 COLOUR PENCILS DOLLY GIRL',
#        'EMBROIDERED RIBBON REEL ROSIE', 'EMBROIDERED RIBBON REEL DAISY ',
#        'EMBROIDERED RIBBON REEL SALLY ',
#        'EMBROIDERED RIBBON REEL RACHEL ', 'MINI PLAYING CARDS GYMKHANA',
#        'MINI PLAYING CARDS DOLLY GIRL ', 'MINI PLAYING CARDS FUN FAIR ',
#        'MINI PLAYING CARDS BUFFALO BILL ',
#        'EMBROIDERED RIBBON REEL SUSIE ', 'FOLKART CLIP ON STARS',
#        'ROUND CACTUS CANDLE', 'DOLLY GIRL MINI RUCKSACK',
#        'SPACEBOY MINI RUCKSACK', 'PLAYING CARDS VINTAGE DOILY ',
#        'LARGE BLACK DIAMANTE HAIRSLIDE',
#        'EMBROIDERED RIBBON REEL SOPHIE  ',
#        'EMBROIDERED RIBBON REEL CLAIRE',
#        'VINTAGE DOILY DELUXE SEWING KIT ',
#        'PACK OF 12 CHRISTMAS FUN CARDS', 'SMOKEY GREY COLOUR GLASS',
#        'NEW BAROQUE LARGE NECKLACE BLK/WHIT',
#        'BLACK DIAMOND CLUSTER NECKLACE', 'SWEETHEART BIRD HOUSE',
#        'TUSCAN VILLA DOVECOTE', 'CARD HOLDER LOVE BIRD SMALL',
#        'HEART TRELLISTRIPLE T-LIGHT HOLDER',
#        'VINTAGE LEAF CHOPPING BOARD  ', 'POPPY FIELDS CHOPPING BOARD',
#        'RED APPLES CHOPPING BOARD   ', 'SIX DRAWER OFFICE TIDY',
#        'VEGETABLE GARDEN CHOPPING BOARD', ' NINE DRAWER OFFICE TIDY',
#        'CARD HOLDER LOVE BIRD LARGE ', 'HORSE & PONY WALL ART',
#        'BICYCLE SAFTEY WALL ART', 'STOP FOR TEA WALL ART',
#        'WALL ART CLASSIC PUDDINGS ', 'PARTY CONES CANDY DECORATION',
#        "WALL ART LOVES' SECRET ", 'DOG AND BALL WALL ART',
#        'DOG LICENCE WALL ART', 'WALL ART GARDEN HAVEN ',
#        "70'S ALPHABET WALL ART", 'SPACEBOY WALL ART',
#        'KEEP CALM WALL ART ', 'WALL ART ONLY ONE PERSON ',
#        'WALL ART VINTAGE HEART', 'CAT AND BIRD WALL ART',
#        'TREASURE AHOY WALL ART', 'WALL ART BIG LOVE ',
#        'ANIMALS AND NATURE WALL ART', 'DOLLY GIRL WALL ART',
#        'VILLAGE SHOW WALL ART', 'WALL ART MID CENTURY MODERN ',
#        'WALL ART WORK REST AND PLAY  ', 'BUFFALO BILL WALL ART ',
#        'WALL ART THE MAGIC FOREST ', 'I LOVE LONDON WALL ART',
#        'WALL ART KEEP CALM ', 'WALL ART BICYCLE SAFTEY ',
#        'WALL ART BUFFALO BILL ', 'HANGING  BUTTERFLY T-LIGHT HOLDER',
#        'WALL ART VILLAGE SHOW ', 'WALL ART STOP FOR TEA ',
#        'WALL ART DOG LICENCE ', 'WALL ART I LOVE LONDON ',
#        "WALL ART 70'S ALPHABET ", 'KEY RING BASEBALL BOOT ASSORTED ',
#        'WALL ART HORSE & PONY ', 'WALL ART ANIMALS AND NATURE ',
#        'PINK HORSE SOCK PUPPET KIT', 'TUSCAN VILLA FEEDING STATION',
#        'KEY RING BASEBALL BOOT UNION JACK',
#        'AMBER GLASS TASSLE BAG CHARM', 'PURPLE GLASS TASSLE BAG CHARM',
#        'WALL ART SPACEBOY', 'WALL ART DOLLY GIRL ',
#        ' I LOVE LONDON MINI RUCKSACK', 'SET 36 COLOURING PENCILS DOILEY',
#        'SET 12 COLOURING PENCILS DOILEY', 'WOODLAND MINI RUCKSACK ',
#        'HEART TRELLIS TRIPLE T-LIGHT HOLDER', 'WALL ART DOG AND BALL ',
#        'WALL ART CAT AND BIRD ', 'WALL ART BICYCLE SAFETY',
#        "WALL ART , LOVES' SECRET ", 'WALL ART,ONLY ONE PERSON ',
#        'WALL ART ,PUDDINGS ', 'MIDNIGHT BLUE DROP CRYSTAL NECKLACE',
#        'TUSCAN VILLA BIRD TABLE ', 'VINTAGE  2 METRE FOLDING RULER',
#        'N0 SINGING METAL SIGN', 'UBO-LIGHT TRIOBASE PURPLE',
#        'SILVER 2 STRAND NECKLACE-LEAF CHARM',
#        'CRACKED GLAZE EARRINGS RED', 'DROP EARRINGS W FLOWER & LEAF',
#        'SILVER M.O.P. ORBIT NECKLACE', 'RUBY GLASS CLUSTER EARRINGS',
#        'GOLD M.O.P. ORBIT NECKLACE', 'TUSCAN VILLA DOVECOTE BIRD FEEDER',
#        'WALL ART , THE MAGIC FOREST ', 'CREAM BUNNY EASTER EGG BASKET',
#        'PINK BUNNY EASTER EGG BASKET', 'BLUE BUNNY EASTER EGG BASKET',
#        'BLACK DROP CRYSTAL NECKLACE', 'WALL ART TREASURE AHOY ',
#        'BOX OF 6 CHRISTMAS CAKE DECORATIONS', 'HENRIETTA HEN MUG ',
#        'MILK MAIDS MUG ', 'EGG CUP MILKMAID INGRID',
#        'PINK HANGING HEART T-LIGHT HOLDER', 'EGG CUP HENRIETTA HEN PINK',
#        'T-LIGHT HOLDER HANGING LOVE BIRD', 'OVAL  MINI PORTRAIT FRAME',
#        'HEART MINI PORTRAIT FRAME', 'SQUARE MINI PORTRAIT FRAME',
#        'PEARLISED IVORY HEART LARGE ', 'DOLLY CABINET 2 DRAWERS ',
#        'EGG CUP MILKMAID HELGA ', 'MEDIUM PARLOUR PICTURE FRAME ',
#        'VINTAGE ZINC WATERING CAN', 'VINTAGE ZINC WATERING CAN SMALL',
#        'LARGE PARLOUR PICTURE FRAME', 'SMALL PARLOUR PICTURE FRAME',
#        'EGG CUP HENRIETTA HEN CREAM ', 'EGG CUP MILKMAID HEIDI',
#        'VINTAGE ZINC PLANTER  ', 'WIRE EGG BASKET ',
#        'PEARLISED IVORY HEART SMALL ', 'DOLLY CABINET 3 DRAWERS ',
#        'SWEET HEART CAKE CARRIER', 'SNACK TRAY I LOVE LONDON',
#        'High Resolution Image', 'LANDMARK FRAME LONDON BRIDGE ',
#        'LANDMARK FRAME COVENT GARDEN ', 'LANDMARK FRAME OXFORD STREET',
#        'LANDMARK FRAME BAKER STREET ', 'LANDMARK FRAME NOTTING HILL ',
#        'LANDMARK FRAME CAMDEN TOWN ', 'GARLAND, VINTAGE BELLS',
#        'VINTAGE JINGLE BELLS HEART', 'VINTAGE JINGLE BELLS WREATH',
#        'WOODLAND LARGE BLUE FELT HEART', 'WOODLAND LARGE PINK FELT HEART',
#        'WOODLAND LARGE RED FELT HEART', 'ANTIQUE HEART SHELF UNIT',
#        'MINI LIGHTS WOODLAND MUSHROOMS', 'WOODLAND SMALL RED FELT HEART',
#        'SWEETHEART WALL TIDY ', 'ROCOCO WALL MIRROR WHITE',
#        'SET 12 VINTAGE DOILY CHALK ', 'BOTANICAL GARDENS WALL CLOCK ',
#        'VINTAGE BELLS GARLAND', 'BAROQUE BUTTERFLY EARRINGS CRYSTAL',
#        'DECROTIVEVINTAGE COFFEE GRINDER BOX',
#        'TRADITIONAL PICK UP STICKS GAME ',
#        'SET OF 3 MINI HANGING PORTRAITS', 'TRADITIONAL NAUGHTS & CROSSES',
#        'TRADTIONAL ALPHABET STAMP SET', 'SET 4 PICNIC CUTLERY BLUEBERRY',
#        'THREE MINI HANGING FRAMES', 'WOODLAND SMALL BLUE FELT HEART',
#        'VINTAGE DOILY JUMBO BAG RED ', 'LUNCH BAG PAISLEY PARK  ',
#        'JUMBO BAG PAISLEY PARK', 'UBO-LIGHT TRIOBASE BLUE',
#        'SET OF 36 VINTAGE CHRISTMAS DOILIES',
#        'SET OF 36 SPACEBOY PAPER DOILIES',
#        'SET OF 36 DOLLY GIRL PAPER DOILIES',
#        'STRAWBERRY CERAMIC TRINKET POT', 'DECORATIVE VINTAGE COFFEE  BOX',
#        'SET OF 36 PANTRY PAPER DOILIES', 'SET 4 PICNIC CUTLERY FONDANT',
#        'WOODLAND SMALL PINK FELT HEART', 'SILVER RECORD COVER FRAME',
#        'CLASSIC CHROME BICYCLE BELL ', 'SET 4 PICNIC CUTLERY CHERRY ',
#        'SET OF 3 PANTRY WOODEN SPOONS', 'PANTRY KITCHEN THERMOMETER ',
#        'LIGHT DECORATION BATTERY OPERATED', 'KEEP CALM BIRTHDAY WRAP',
#        'AMBER GLASS/SHELL/PEARL NECKLACE',
#        'JET BLACK LAS VEGAS NECKLACE 45CM',
#        '5 STRAND GLASS NECKLACE AMETHYST', 'RUBY GLASS CLUSTER NECKLACE',
#        'DIAMANTE NECKLACE BLACK ', 'WRAP KEEP CALM BIRTHDAY',
#        'LUNCH BAG RED VINTAGE DOILY', "BLACK SIL'T SQU CANDLE PLATE ",
#        'ANT SILVER TURQUOISE BOUDICCA RING', 'PINK POLKADOT PLATE ',
#        'ST GEORGE SET OF 10 PARTY LIGHTS', 'WRAP A PRETTY THANK YOU',
#        'CLASSIC CROME BICYCLE BELL ', 'DOILY THANK YOU CARD',
#        'A PRETTY THANK YOU CARD', 'BLACK VINT ART DEC CRYSTAL BRACELET',
#        'TUSCAN VILLA BIRD FEEDER', 'PAPER BUNTING VINTAGE PARTY',
#        'PAPER BUNTING PAISLEY PARK', 'LARGE PARLOUR FRAME',
#        'MEDIUM PARLOUR FRAME ', 'SMALL PARLOUR FRAME',
#        'FLOWER SHOP DESIGN MUG', 'ROSE FLOWER CANDLE+INCENSE 16X16CM',
#        'WHITE CHRISTMAS TREE 60CM', 'PAISLEY PARK CARD',
#        'VINTAGE KEEPSAKE BOX PINK FLOWER',
#        'PACK 3 BOXES CHRISTMAS PANETTONE', 'PACK 3 BOXES BIRD PANETTONE ',
#        'COLOURED GLASS STAR T-LIGHT HOLDER',
#        'CRYSTAL CZECH CROSS PHONE CHARM', '12 HANGING EGGS HAND PAINTED',
#        'SET OF 6 EASTER RAINBOW CHICKS', 'DUSTY PINK CHRISTMAS TREE 60CM',
#        'IVORY RETRO KITCHEN WALL CLOCK', 'PACK OF 6 PANETTONE GIFT BOXES',
#        'CAT WITH SUNGLASSES BLANK CARD', 'BLUE RETRO KITCHEN WALL CLOCK',
#        'RED RETRO KITCHEN WALL CLOCK', 'WHITE MOROCCAN METAL LANTERN',
#        'HAND PAINTED HANGING EASTER EGG', 'UNION JACK HOT WATER BOTTLE ',
#        'WHITE STONE/CRYSTAL EARRINGS',
#        'MIDNIGHT BLUE CRYSTAL DROP EARRINGS',
#        'PAINT YOUR OWN EGGS IN CRATE', 'BICYCLE PUNCTURE REPAIR KIT ',
#        'CLASSIC BICYCLE CLIPS ', 'CROCHET LILAC/RED BEAR KEYRING',
#        'SNACK TRAY RED GINGHAM', 'SNACK TRAY HAPPY FOREST  ',
#        'SNACK TRAY PAISLEY PARK', 'SET OF 6 RIBBONS COUNTRY STYLE',
#        'SNACK TRAY RED VINTAGE DOILY',
#        'SET OF 6 RIBBONS PERFECTLY PRETTY  ',
#        'GIN AND TONIC DIET METAL SIGN', 'SET OF 6 RIBBONS PARTY',
#        'SILVER AND BLACK ORBIT NECKLACE', 'LETTER "F" BLING KEY RING',
#        'LETTER "O" BLING KEY RING', 'LETTER "T" BLING KEY RING',
#        'LETTER "U" BLING KEY RING', 'LETTER "W" BLING KEY RING',
#        'LETTER "Z" BLING KEY RING', 'PINK CRYSTAL SKULL PHONE CHARM',
#        'CREAM HANGING HEART T-LIGHT HOLDER',
#        'HANGING RIDGE GLASS T-LIGHT HOLDER', 'GLASS BELL JAR SMALL',
#        'BLACK CHERRY LIGHTS', 'MONTANA DIAMOND CLUSTER EARRINGS',
#        '16 PC CUTLERY SET PANTRY DESIGN', 'LUNCH BAG RED SPOTTY',
#        'ROCOCO WALL MIROR', 'CLASSIC DIAMANTE NECKLACE JET'], dtype=object)

# %%
descriptions = {}

for row in df['Description'].unique():
    for word in row.split():
        if word not in descriptions:
            #print('new word')
            descriptions[word] = 1
        else:
            #print('increment count')
            descriptions[word] += 1

descriptions
# Out:
# {'WHITE': 128,
#  'HANGING': 100,
#  'HEART': 235,
#  'T-LIGHT': 89,
#  'HOLDER': 116,
#  'METAL': 111,
#  'LANTERN': 24,
#  'CREAM': 48,
#  'CUPID': 3,
#  'HEARTS': 31,
#  'COAT': 8,
#  'HANGER': 18,
#  'KNITTED': 8,
#  'UNION': 28,
#  'FLAG': 11,
#  'HOT': 30,
#  'WATER': 28,
#  'BOTTLE': 41,
#  'RED': 194,
#  'WOOLLY': 1,
#  'HOTTIE': 1,
#  'HEART.': 1,
#  'SET': 279,
#  '7': 7,
#  'BABUSHKA': 23,
#  'NESTING': 3,
#  'BOXES': 19,
#  'GLASS': 146,
#  'STAR': 58,
#  'FROSTED': 2,
#  'HAND': 20,
#  'WARMER': 19,
#  'JACK': 21,
#  'POLKA': 3,
#  'DOT': 2,
#  'ASSORTED': 58,
#  'COLOUR': 35,
#  'BIRD': 44,
#  'ORNAMENT': 1,
#  "POPPY'S": 4,
#  'PLAYHOUSE': 4,
#  'BEDROOM': 1,
#  'KITCHEN': 26,
#  'FELTCRAFT': 24,
#  'PRINCESS': 3,
#  'CHARLOTTE': 11,
#  'DOLL': 11,
#  'IVORY': 63,
#  'MUG': 68,
#  'COSY': 16,
#  'BOX': 133,
#  'OF': 238,
#  'VINTAGE': 215,
#  'ALPHABET': 15,
#  'BLOCKS': 2,
#  'HOME': 49,
#  'BUILDING': 3,
#  'BLOCK': 7,
#  'WORD': 3,
#  'LOVE': 57,
#  'RECIPE': 6,
#  'WITH': 79,
#  'DOORMAT': 27,
#  'NEW': 17,
#  'ENGLAND': 4,
#  'YELLOW': 18,
#  'RACK': 14,
#  'PARIS': 6,
#  'FASHION': 3,
#  'BATH': 6,
#  'ALARM': 7,
#  'CLOCK': 44,
#  'BAKELIKE': 6,
#  'PINK': 283,
#  'PANDA': 1,
#  'AND': 76,
#  'BUNNIES': 6,
#  'STICKER': 12,
#  'SHEET': 8,
#  'STARS': 12,
#  'GIFT': 53,
#  'TAPE': 18,
#  'INFLATABLE': 2,
#  'POLITICAL': 1,
#  'GLOBE': 1,
#  'HEADS': 2,
#  'TAILS': 2,
#  'CARD': 73,
#  'GAME': 5,
#  'SET/2': 1,
#  'RETROSPOT': 96,
#  'TEA': 55,
#  'TOWELS': 7,
#  'ROUND': 31,
#  'SNACK': 9,
#  'OF4': 1,
#  'WOODLAND': 27,
#  'SPACEBOY': 37,
#  'LUNCH': 27,
#  'CIRCUS': 12,
#  'PARADE': 12,
#  'TOADSTOOL': 10,
#  'LED': 5,
#  'NIGHT': 5,
#  'LIGHT': 20,
#  '2': 39,
#  'I': 20,
#  'LONDON': 24,
#  'SEASIDE': 4,
#  'JIGSAW': 15,
#  'PUZZLES': 1,
#  'MINI': 58,
#  'PAINT': 3,
#  'PAPER': 83,
#  'CHAIN': 10,
#  'KIT': 29,
#  "50'S": 14,
#  'CHRISTMAS': 148,
#  'EDWARDIAN': 13,
#  'PARASOL': 15,
#  'RETRO': 28,
#  'COFFEE': 21,
#  'MUGS': 1,
#  'SAVE': 3,
#  'THE': 15,
#  'PLANET': 3,
#  'BILLBOARD': 7,
#  'DRINK': 1,
#  'ME': 2,
#  'LOVE/HATE': 1,
#  'WOOD': 40,
#  'DRAWER': 32,
#  'CABINET': 22,
#  'FINISH': 5,
#  'S/3': 3,
#  'ANT': 12,
#  'WOODEN': 47,
#  'PICTURE': 14,
#  'FRAME': 50,
#  'ANTIQUE': 38,
#  'SYMPATHY': 1,
#  'JUMBO': 28,
#  'BAG': 163,
#  'POLKADOT': 71,
#  'BAROQUE': 22,
#  'BLACK': 93,
#  'CHARLIE': 9,
#  'LOLA': 10,
#  'TOYS': 2,
#  '3': 91,
#  'PIECE': 12,
#  'CUTLERY': 34,
#  'BLUE': 209,
#  'SET/6': 18,
#  'SPOTTY': 9,
#  'PLATES': 5,
#  'STRAWBERRY': 25,
#  'PACK': 64,
#  '60': 12,
#  'DINOSAUR': 11,
#  'CAKE': 81,
#  'CASES': 28,
#  'TOMATO': 1,
#  'CHARLIE+LOLA': 7,
#  'COASTER': 9,
#  '&': 30,
#  'WASTEPAPER': 2,
#  'BIN': 10,
#  'FLORA': 2,
#  'PERSONAL': 2,
#  'DOORSIGN': 2,
#  'PAISLEY': 42,
#  'JAM': 18,
#  'MAKING': 3,
#  'PRINTED': 2,
#  'CERAMIC': 44,
#  '11': 1,
#  'PC': 2,
#  'GIRLY': 1,
#  'TOOL': 2,
#  'AIRLINE': 6,
#  'LOUNGE,METAL': 1,
#  'SIGN': 64,
#  'SPOT': 25,
#  'KNOB': 21,
#  'CLEAR': 10,
#  'ACRYLIC': 20,
#  'PHOTO': 37,
#  'CLIP': 8,
#  'LINE': 1,
#  'FELT': 35,
#  'EGG': 58,
#  'CHICKEN': 7,
#  'PIGGY': 1,
#  'BANK': 7,
#  'SKULL': 19,
#  'SHOULDER': 6,
#  "YOU'RE": 1,
#  'CONFUSING': 1,
#  'COOK': 1,
#  'WINE': 6,
#  'GIN': 4,
#  '+': 17,
#  'TONIC': 5,
#  'DIET': 3,
#  'BREAKFAST': 11,
#  'CUP': 35,
#  'SAUCER': 10,
#  'SMALL': 112,
#  'FLOWERS': 23,
#  'HOOK': 38,
#  'TIME': 12,
#  'DES': 6,
#  'RABBIT': 28,
#  'ZINC': 49,
#  'WILLIE': 4,
#  'WINKIE': 4,
#  'CANDLE': 92,
#  'STICK': 6,
#  'CHERRY': 14,
#  'MONEY': 15,
#  'LARGE': 102,
#  'MILK': 13,
#  'JUG': 11,
#  '6': 62,
#  'FUNKY': 12,
#  'BEAKERS': 1,
#  'NATURAL': 11,
#  'OWL': 8,
#  'SOFT': 13,
#  'TOY': 17,
#  'BALLOON': 6,
#  'ART': 77,
#  'MAKE': 4,
#  'YOUR': 11,
#  'OWN': 10,
#  'FANCY': 3,
#  'FONT': 14,
#  'SWEET': 24,
#  'SNAKES': 1,
#  'LADDERS': 1,
#  'CHOCOLATE': 29,
#  'CALCULATOR': 3,
#  'SHOPPER': 5,
#  'RECYCLING': 1,
#  'TIDY': 13,
#  'DRESSING': 3,
#  'TABLE': 27,
#  'POT': 25,
#  'GREEN': 93,
#  'GIANT': 9,
#  'GARDEN': 71,
#  'THERMOMETER': 7,
#  'TIER': 11,
#  'TIN': 44,
#  'WICKER': 20,
#  'OVAL': 11,
#  'BASKETS': 2,
#  'W': 41,
#  'LIDS': 1,
#  'BOARD': 9,
#  'MEDINA': 6,
#  'SLATE': 13,
#  'CHALKBOARD': 5,
#  'LOVEBIRD': 8,
#  'CLASSIC': 18,
#  'BIRDCAGE': 2,
#  'PLANT': 13,
#  'ENAMEL': 35,
#  'FLOWER': 111,
#  'FIRE': 8,
#  'BUCKET': 8,
#  'BREAD': 5,
#  'JARS': 3,
#  'DOLLY': 40,
#  'GIRL': 42,
#  'DESIGN': 127,
#  'TRADITIONAL': 13,
#  'RIBBONS': 19,
#  'ORGANISER': 8,
#  'WIRE': 22,
#  'CHILLI': 1,
#  'LIGHTS': 14,
#  'GARLAND': 39,
#  'BUTTERFILES': 1,
#  'OWLS': 3,
#  'FAIRY': 34,
#  'TALE': 2,
#  'COTTAGE': 15,
#  'NIGHTLIGHT': 1,
#  'LETTERS': 11,
#  'GINGHAM': 27,
#  'DOORSTOP': 12,
#  'FIVE': 2,
#  'DECORATION': 98,
#  'TOP': 11,
#  'MAGNETS': 23,
#  'FRIDGE': 9,
#  'US': 1,
#  'DINER': 12,
#  'HOMEMADE': 1,
#  'SCENTED': 15,
#  'CANDLES': 40,
#  'LES': 1,
#  'ENFANTS': 1,
#  'ROSE': 99,
#  'CARAVAN': 4,
#  '5': 20,
#  'MAGIC': 26,
#  '10': 11,
#  'REINDEER': 4,
#  'CUSHION': 52,
#  'COVER': 67,
#  'COLOURED': 7,
#  'FLYING': 6,
#  'DUCKS': 6,
#  'GOLD': 39,
#  'UMBRELLA': 14,
#  'BLACK/BLUE': 1,
#  'WALL': 97,
#  'MEASURING': 9,
#  'SPOONS': 4,
#  'JAR': 38,
#  'LID': 7,
#  'KEEPSAKE': 5,
#  'DISCO': 6,
#  'BALL': 16,
#  'POPCORN': 3,
#  'SET/20': 2,
#  'NAPKINS': 10,
#  'CUPS': 6,
#  'RAIN': 5,
#  'HAT': 1,
#  'DELUXE': 4,
#  'SEWING': 13,
#  'ENGLISH': 16,
#  'CUBE': 4,
#  'STRIPEY': 3,
#  'MICE': 1,
#  'SOLDIER': 1,
#  'SKITTLES': 4,
#  'SKIPPING': 1,
#  'ROPE': 3,
#  'DOMINOES': 2,
#  'RUSTIC': 12,
#  'SEVENTEEN': 1,
#  'SIDEBOARD': 1,
#  'PARTY': 42,
#  'CONES': 7,
#  'CARNIVAL': 4,
#  'CANDY': 15,
#  'PICNIC': 13,
#  'BASKET': 22,
#  'PAINTED': 32,
#  'LAMP': 11,
#  'BIRTHDAY': 32,
#  'CARD,': 7,
#  'SCOTTY': 1,
#  'DOG': 23,
#  'BOWL': 53,
#  'CHASING': 1,
#  'CLOTHES': 2,
#  'PEGS': 6,
#  '24': 3,
#  'OVER': 1,
#  'TRAVEL': 17,
#  'TEATIME': 9,
#  '72': 8,
#  'CHICK': 16,
#  'GREY': 6,
#  'EMBROIDERED': 11,
#  'QUILT': 1,
#  '12': 58,
#  'TISSUES': 18,
#  'STRING': 14,
#  'TRINKET': 23,
#  'DOUGHNUT': 3,
#  'SILK': 5,
#  'PURSE': 24,
#  'AM': 1,
#  'SO': 1,
#  'POORLY': 1,
#  'SCOTTIE': 4,
#  'HOUSE': 13,
#  'BOUDOIR': 2,
#  'SQUARE': 16,
#  'TISSUE': 12,
#  'SKULLS': 20,
#  'CORNICE': 4,
#  'S/6': 3,
#  'SEW': 1,
#  'ON': 22,
#  'CROCHET': 12,
#  'SCANDINAVIAN': 9,
#  'REDS': 1,
#  'BALLOONS': 6,
#  'WRITING': 3,
#  'LAVENDER': 13,
#  'INCENSE': 17,
#  'IN': 71,
#  'TV': 8,
#  'DINNER': 20,
#  'TRAY': 32,
#  '4': 66,
#  'PLACEMATS': 5,
#  'COASTERS': 5,
#  'TRIPLE': 11,
#  'FAMILY': 4,
#  'MIRRORED': 12,
#  'ROTATOR': 1,
#  'BATTERY': 2,
#  'OPERATED': 2,
#  'SILVER': 83,
#  'LOOKING': 2,
#  'MIRROR': 49,
#  'LADIES': 3,
#  'GENTLEMEN': 1,
#  'HER': 1,
#  'IS': 3,
#  'SERVED': 2,
#  'TOPIARY': 1,
#  'BATHROOM': 15,
#  'TOILET': 4,
#  'TAKE': 1,
#  'IT': 2,
#  'OR': 3,
#  'LEAVE': 1,
#  "I'M": 1,
#  'HOLIDAY': 7,
#  'GROW': 6,
#  'BASIL': 2,
#  'SET/10': 4,
#  '20': 12,
#  'CAKES': 12,
#  'T-LIGHTS': 20,
#  'SNOWMEN': 2,
#  'SANTA': 3,
#  '9': 15,
#  'SHAPED': 6,
#  'SANDWICH': 1,
#  'SPONGE': 5,
#  'APPLE': 8,
#  'PIRATE': 3,
#  'TREASURE': 12,
#  'CHEST': 7,
#  'PORTABLE': 2,
#  'SNOWFLAKE': 3,
#  'JEWELLED': 14,
#  'CIGAR': 2,
#  'MATCHES': 6,
#  'HOUR': 2,
#  'TUBE': 23,
#  'JAZZ': 3,
#  'NOTEBOOK': 31,
#  'CANDLEHOLDER': 9,
#  'GUMBALL': 3,
#  'CANDLESTICK': 6,
#  'BAROQUECANDLESTICK': 1,
#  'FLANNEL': 8,
#  'STYLE': 18,
#  'CLOTH': 1,
#  'TRELLIS': 6,
#  'FOOTBALL': 3,
#  'CELEBRATION': 2,
#  'GIRLS': 4,
#  'ROMANTIC': 5,
#  'PINKS': 2,
#  'BRIGHT': 1,
#  'BLUES': 1,
#  'INVITES': 6,
#  'SPACEMAN': 1,
#  'BUTTERFLY': 34,
#  'COOKIE': 7,
#  'CUTTERS': 5,
#  'CUTTER': 2,
#  'SWEETHEART': 30,
#  'SUKI': 9,
#  'CARS': 1,
#  'SKULL.': 1,
#  'SET/5': 2,
#  'BOWLS': 4,
#  'DRAWING': 9,
#  'BAKE': 2,
#  'A': 8,
#  'PENCILS': 25,
#  'TALL': 11,
#  'HARMONICA': 2,
#  'TRANSFER': 1,
#  'TATTOOS': 1,
#  'PANNETONE': 3,
#  'KIDS': 10,
#  'PEN': 17,
#  'VICTORIAN': 12,
#  'SINGLE': 8,
#  'RECTANGLE': 3,
#  'PENS': 6,
#  'FUNNY': 1,
#  'FACE': 1,
#  'WRAP': 65,
#  'COWBOYS': 2,
#  'TOKYO': 1,
#  '78': 1,
#  'DOILIES': 16,
#  'PLASTERS': 6,
#  'SLEEPING': 1,
#  'CAT': 21,
#  'ERASERS': 3,
#  'COWBOY': 1,
#  'ROTATING': 2,
#  'ANGELS': 1,
#  'HLDR': 2,
#  'RIBBON': 21,
#  'REEL': 21,
#  'SPINNING': 1,
#  'TOPS': 1,
#  '500g': 1,
#  'SWIRLY': 4,
#  'MARBLES': 3,
#  'STRAND': 6,
#  'NECKLACE': 84,
#  'CRYSTAL': 43,
#  'SQUARECUSHION': 2,
#  'CHILDRENS': 27,
#  "CHILDREN'S": 4,
#  'CANDELABRA': 1,
#  'BOTANICAL': 16,
#  'LUGGAGE': 11,
#  'TAG': 10,
#  'TASSLE': 6,
#  'CHARM': 30,
#  'FACETED': 4,
#  'BANGLE': 4,
#  'GUNS': 1,
#  'ROSES': 6,
#  'VANILLA': 10,
#  'SCENT': 9,
#  'FULL': 1,
#  'PLATE': 30,
#  'BELL': 23,
#  'STAND': 33,
#  'FILIGREE': 10,
#  'MED': 1,
#  'PATTERN': 4,
#  'STICKERS': 19,
#  'STORAGE': 26,
#  'PENCIL': 10,
#  "B'FLY": 5,
#  'C/COVER': 2,
#  'BOBBLES': 1,
#  'ELEGANT': 1,
#  'AGED': 1,
#  'BOOM': 3,
#  'SPEAKER': 2,
#  'SHIMMERING': 1,
#  'HOLLY': 9,
#  'BELLS': 15,
#  'ANGEL': 7,
#  'DRESS': 3,
#  'FRUITS': 2,
#  'MOLLY': 1,
#  'NOTEBOOKS': 1,
#  'PARCEL': 1,
#  'SLIPPER': 4,
#  'SHOES': 3,
#  'DAISY': 21,
#  'CRAFT': 12,
#  'TREE': 53,
#  'LITTLE': 3,
#  'FRIENDS': 3,
#  'ROSIE': 2,
#  'EMILY': 2,
#  'OLIVIA': 1,
#  'REX': 1,
#  'CASH+CARRY': 1,
#  'TOTE': 7,
#  'FOLDING': 18,
#  'PINKWHITE': 1,
#  'WHITE/RED': 1,
#  'RED/WHITE': 1,
#  'S/4': 7,
#  'VALENTINE': 2,
#  'DECOUPAGE': 6,
#  'SOLDIERS': 1,
#  'SOCK': 6,
#  'BAUBLE': 6,
#  'SNOWY': 1,
#  'VILLAGE': 6,
#  'TURQUOISE': 8,
#  'WREATH': 19,
#  'ADVENT': 4,
#  'CALENDAR': 9,
#  'SACK': 2,
#  'CONE': 1,
#  'SNAP': 1,
#  'CARDS': 16,
#  'PURPLE': 31,
#  'DRAWERKNOB': 1,
#  'APRON': 14,
#  'SANTAS': 1,
#  'MUSHROOM': 6,
#  'CHALK': 4,
#  'STICKS': 4,
#  'HAIRBAND': 3,
#  'HAIRBANDS': 1,
#  'ANIMALS': 5,
#  'GO': 3,
#  'TO': 4,
#  'FAIR': 3,
#  'URBAN': 1,
#  'TOADSTOOLS': 4,
#  'LEAVES': 9,
#  'CUPCAKE': 3,
#  'LACE': 15,
#  'CATCH': 1,
#  'COTTON': 12,
#  'BEACH': 7,
#  'SPADE': 3,
#  'BOYS': 4,
#  'KINGS': 7,
#  'CHOICE': 7,
#  'CADDY': 3,
#  'BISCUIT': 11,
#  'EMPIRE': 8,
#  'FAWN': 2,
#  'BIRDY': 1,
#  'TAGS': 6,
#  'OVEN': 6,
#  'GLOVE': 5,
#  'NAMASTE': 1,
#  'SWAGAT': 1,
#  'CLASSICAL': 3,
#  'VASE': 3,
#  'HYACINTH': 1,
#  'BULB': 2,
#  'TOWEL': 12,
#  'DOVE': 4,
#  'COLOURING': 6,
#  'BROWN': 11,
#  'FLOCK': 25,
#  'FERN': 4,
#  'CHRYSANTHEMUM': 4,
#  'CHINESE': 4,
#  'SCISSOR': 4,
#  'ETCHED': 8,
#  'TEALIGHT': 3,
#  'COOKING': 2,
#  'PLACE': 7,
#  'SETTING': 4,
#  'S/15': 1,
#  'BAUBLES': 3,
#  'FRENCH': 39,
#  'WC': 1,
#  'SOAP': 11,
#  'MEDIUM': 15,
#  'WASHROOM': 1,
#  'BRACELET': 63,
#  'DIAMANTE': 34,
#  'HAIR': 20,
#  'GRIP': 4,
#  'PACK/2': 4,
#  'DIA': 1,
#  'EXPANDABLE': 4,
#  'RING': 46,
#  'RUBY': 6,
#  'MONTANA': 3,
#  'PRESENT': 1,
#  'FIRST': 9,
#  'AID': 5,
#  'MONSOON': 1,
#  'CIRCULAR': 3,
#  'RUBBERS': 1,
#  'STATIONERY': 6,
#  'SOCKS': 1,
#  'MITTENS': 1,
#  'TAPES': 1,
#  'SET/9': 2,
#  'FABRIC': 9,
#  'THREE': 2,
#  'CANVAS': 6,
#  '3D': 10,
#  'STAMPS': 1,
#  '36': 24,
#  'FOIL': 2,
#  'SWEETIE': 1,
#  'CINAMMON': 2,
#  'ORANGE': 10,
#  'STRIPES': 7,
#  'TINS': 24,
#  'JARDIN': 9,
#  'DE': 7,
#  'PROVENCE': 1,
#  'PLAYTIME': 1,
#  'DINOSAURS': 2,
#  'OFFICE': 9,
#  'RECORD': 4,
#  '7"': 1,
#  'SIZE': 6,
#  'ROCKING': 4,
#  'HORSE': 9,
#  'REGENCY': 17,
#  'CAKESTAND': 2,
#  'BUNTING': 19,
#  'LONGBOARD': 1,
#  'IRONING': 1,
#  'PLAYING': 11,
#  'GENTLEMAN': 1,
#  'SHIRT': 1,
#  'REPAIR': 2,
#  'FOXY': 1,
#  'GENTS': 1,
#  'JET': 7,
#  'POTTING': 6,
#  'SHED': 8,
#  'SOW': 1,
#  "'N'": 1,
#  'WORLD': 2,
#  'CHAMPION': 1,
#  'SEED': 4,
#  'ENVELOPES': 2,
#  'HI': 1,
#  'TEC': 1,
#  'ALPINE': 1,
#  'POLYESTER': 6,
#  'FILLER': 6,
#  'PAD': 8,
#  '45x45cm': 1,
#  'RAINY': 1,
#  'SCARF': 6,
#  'PEARS': 5,
#  'GAZEBO': 1,
#  'BIRDHOUSE': 7,
#  'ENGRAVED': 3,
#  'MARKET': 1,
#  'CRATES': 1,
#  'CRAZY': 1,
#  'TRAY,': 1,
#  'BED': 1,
#  'PIZZA': 5,
#  'DOTS': 1,
#  'NAPKIN': 11,
#  'CHARMS': 10,
#  'BUTTON': 1,
#  'MESSAGE': 1,
#  'HERB': 9,
#  'MARKER': 9,
#  'MINT': 8,
#  'ROSEMARY': 1,
#  'CHIVES': 1,
#  'PARSLEY': 1,
#  'THYME': 1,
#  'MERRY': 2,
#  'TREES': 2,
#  'HANDBAG': 13,
#  'HAPPY': 12,
#  'EASTER': 48,
#  'CUT': 7,
#  'SEASON': 1,
#  'TOAST': 5,
#  'ITS': 5,
#  '-': 5,
#  'PATH': 4,
#  'JOURNAL': 6,
#  'SQUEEZER': 1,
#  'WASHING': 4,
#  'UP': 8,
#  'GLOVES': 5,
#  'LICORICE': 1,
#  'SWISS': 4,
#  'ROLL': 8,
#  'TOWEL,': 3,
#  'SPOTS': 8,
#  'BAGS': 2,
#  'DOUBLE': 2,
#  'RIDGED': 5,
#  'TEASPOONS': 1,
#  'PANTRY': 32,
#  'MULTICOLOUR': 10,
#  'CONFETTI': 4,
#  'WICK': 7,
#  'MORRIS': 9,
#  '16': 8,
#  'PISTACHIO': 2,
#  'HONEYCOMB': 14,
#  'SPIRIT': 2,
#  'LEVEL': 2,
#  'PLATTER': 3,
#  'TEACUP': 3,
#  'SLICE': 3,
#  'EIGHT': 3,
#  'SPORTING': 1,
#  'FUN': 7,
#  'ASS': 7,
#  'COL': 6,
#  'SAND': 3,
#  'GECKO': 1,
#  "P'WEIGHT": 2,
#  'POSTCARD': 3,
#  'SPRING': 6,
#  'CHATEAU': 5,
#  'SCALES': 6,
#  'MULTI': 4,
#  'LIZARD': 1,
#  'SUCTION': 4,
#  'ENGINE/CAR': 1,
#  'PATCHES': 6,
#  'PSYCHEDELIC': 6,
#  'APPLES': 13,
#  'ENCHANTED': 5,
#  'FOREST': 7,
#  'PLACEMAT': 4,
#  'FLOWERPOWER': 1,
#  'CASE': 3,
#  'LIFE': 3,
#  'BEAUTIFUL': 1,
#  'ROUNDERS': 1,
#  'CHILDS': 14,
#  'SET/12': 2,
#  'TAPER': 1,
#  'LADDER': 3,
#  'CONFECTIONERY': 2,
#  'DIGESTIVE': 1,
#  'BISCUITS': 5,
#  'STOPPER': 1,
#  'WELCOME': 4,
#  'SET/4': 15,
#  'MODERN': 5,
#  'SWALLOW': 2,
#  'NO': 2,
#  'JUNK': 1,
#  'MAIL': 1,
#  'TILE': 32,
#  'FINGER': 1,
#  'BEURRE': 1,
#  'DISH': 20,
#  'GREETING': 14,
#  'SCREEN': 6,
#  'PRINT': 11,
#  'FONTS': 3,
#  'PEACE': 3,
#  'EARTH': 1,
#  'COCKTAIL': 3,
#  'PARASOLS': 1,
#  'CAN': 12,
#  'STRONGMAN': 1,
#  'SCHOOL': 4,
#  'CRAYONS': 1,
#  'GAMES': 1,
#  'BOOZE': 1,
#  'WOMEN': 1,
#  'LADS': 1,
#  'ONLY': 3,
#  'GINGERBREAD': 1,
#  'MAN': 3,
#  'IF': 1,
#  'YOU': 6,
#  "CAN'T": 1,
#  'HEAT': 1,
#  'PLEASE': 2,
#  'ONE': 5,
#  'PERSON': 4,
#  'SHAPE': 16,
#  'FRYING': 11,
#  'PAN': 15,
#  '200': 2,
#  'BENDY': 2,
#  'STRAWS': 5,
#  'SKETCHBOOK': 10,
#  'SINGING': 3,
#  'EMERGENCY': 1,
#  'DECORATIVE': 16,
#  'FRIEZE': 1,
#  'DRAWERS': 6,
#  'JOY': 2,
#  'NOEL': 2,
#  'BLACK+SILVER': 1,
#  'COSMETIC': 5,
#  'REGAL': 1,
#  'CANDLEPOT': 4,
#  'SWIRLGLASS': 1,
#  'PEDESTAL': 1,
#  'MAGAZINE': 3,
#  'FOOD': 14,
#  'RAFFIA': 6,
#  'FLUTED': 2,
#  'KASHMIR': 1,
#  'FOLKART': 14,
#  'IVORY/RED': 1,
#  'GRAND': 3,
#  'CHOCOLATECANDLE': 1,
#  'SHELF': 8,
#  'IMAGES': 14,
#  'CURIOUS': 4,
#  'DAYS': 3,
#  'JEWELLERY': 10,
#  'CHARLIE+LOLA"EXTREMELY': 1,
#  'BUSY"': 1,
#  'LOLITA': 1,
#  'LETS': 1,
#  'SHOPPING': 9,
#  'CAMOUFLAGE': 3,
#  'TORCH': 1,
#  'DRAGONFLY': 3,
#  'HELICOPTER': 6,
#  'SHARK': 3,
#  "DOCTOR'S": 1,
#  'LIGHTBULB': 2,
#  'STAR+': 1,
#  'MOON': 3,
#  'MUSICAL': 4,
#  'STRIPE': 11,
#  'FRINGE': 1,
#  'HAMMOCK': 3,
#  'DEC': 7,
#  'CROSSBONES': 2,
#  '45x30cm': 1,
#  '40x40cm': 1,
#  'PONY': 4,
#  'CORDON': 2,
#  'BARRIER': 2,
#  'TEDDY': 7,
#  'AIR': 1,
#  'HOSTESS': 1,
#  'LETTER': 31,
#  'DOOR': 22,
#  'No': 3,
#  'STACKING': 3,
#  'BLOSSOM': 15,
#  'PASSPORT': 8,
#  'CARDHOLDER': 3,
#  'BOOK': 22,
#  'OVERNIGHT': 1,
#  'SPIRAL': 2,
#  'FEATHER': 10,
#  'PEN,COAL': 1,
#  'PEN,LIGHT': 1,
#  'PEN,HOT': 1,
#  'AIRMAIL': 1,
#  'NUMBER': 22,
#  '8': 6,
#  'SMILEY': 1,
#  'CATS': 6,
#  'COLLAGE': 5,
#  'CHILDHOOD': 2,
#  'MEMORY': 1,
#  'LIGHTS,FUNK': 1,
#  'MONKEY': 9,
#  'CHOC+BLUE': 1,
#  'GLITTER': 11,
#  'NURSERY': 2,
#  'A,B,C': 1,
#  'DUTCH': 1,
#  'CHEESE': 3,
#  'GEISHA': 2,
#  'NEWSPAPER': 1,
#  'STOCKING': 6,
#  'SCANDISPOT': 1,
#  'JINGLE': 6,
#  'KEYS': 2,
#  'INSTRUMENT': 1,
#  'CROWNS': 1,
#  'STARS,TREES': 1,
#  'CHALET': 1,
#  'MOTORBIKE': 1,
#  'MEDICINE': 1,
#  'MA': 4,
#  'CAMPAGNE': 4,
#  'YULETIDE': 2,
#  'SHADE': 3,
#  'BASE': 5,
#  'SMALLFOLKART': 1,
#  'GLASS+ZINC': 1,
#  'SET/3': 11,
#  'PINK/WHITE': 5,
#  '60CM': 7,
#  '20LIGHT': 2,
#  'EUCALYPTUS': 1,
#  'PINECONE': 1,
#  'PUDDING': 8,
#  '15CM': 2,
#  'FINE': 4,
#  'CACTI': 3,
#  'MARSHMALLOW': 1,
#  'KNITTING': 4,
#  'BEST': 3,
#  'MUM': 2,
#  'INDIANS': 1,
#  'SPOTTED': 3,
#  'LIPSTICK': 3,
#  'FUSCHIA': 6,
#  'BROCADE': 1,
#  'GLASS.': 1,
#  'SWALLOWS': 2,
#  'LADLE': 4,
#  '"M"': 1,
#  'BLING': 25,
#  'KEY': 37,
#  '"V"': 1,
#  '"S"': 1,
#  '"J"': 1,
#  'BINGO': 1,
#  ...}

# %%
descList = []

for k in sorted(descriptions, key=descriptions.get, reverse=True):
    descList.append(k)

descList
# Out:
# ['PINK',
#  'SET',
#  'OF',
#  'HEART',
#  'VINTAGE',
#  'BLUE',
#  'RED',
#  'BAG',
#  'CHRISTMAS',
#  'GLASS',
#  'BOX',
#  'WHITE',
#  'DESIGN',
#  'HOLDER',
#  'SMALL',
#  'METAL',
#  'FLOWER',
#  'LARGE',
#  'HANGING',
#  'ROSE',
#  'DECORATION',
#  'WALL',
#  'RETROSPOT',
#  'BLACK',
#  'GREEN',
#  'CANDLE',
#  '3',
#  'T-LIGHT',
#  'NECKLACE',
#  'PAPER',
#  'SILVER',
#  'CAKE',
#  'WITH',
#  'ART',
#  'AND',
#  'CARD',
#  'POLKADOT',
#  'GARDEN',
#  'IN',
#  'MUG',
#  'COVER',
#  '4',
#  'WRAP',
#  'PACK',
#  'SIGN',
#  'IVORY',
#  'BRACELET',
#  '6',
#  'STAR',
#  'ASSORTED',
#  'MINI',
#  'EGG',
#  '12',
#  'LOVE',
#  'TEA',
#  'GIFT',
#  'BOWL',
#  'TREE',
#  'CUSHION',
#  'FRAME',
#  'HOME',
#  'ZINC',
#  'MIRROR',
#  'CREAM',
#  'EASTER',
#  'WOODEN',
#  'RING',
#  'EARRINGS',
#  'BIRD',
#  'CLOCK',
#  'CERAMIC',
#  'TIN',
#  'CRYSTAL',
#  'PAISLEY',
#  'GIRL',
#  'PARTY',
#  'BOTTLE',
#  'W',
#  'WOOD',
#  'DOLLY',
#  'CANDLES',
#  '2',
#  'GARLAND',
#  'GOLD',
#  'FRENCH',
#  'ANTIQUE',
#  'HOOK',
#  'JAR',
#  'SPACEBOY',
#  'PHOTO',
#  'KEY',
#  'COLOUR',
#  'FELT',
#  'CUP',
#  'ENAMEL',
#  'CUTLERY',
#  'FAIRY',
#  'BUTTERFLY',
#  'DIAMANTE',
#  'STAND',
#  'DRAWER',
#  'PAINTED',
#  'BIRTHDAY',
#  'TRAY',
#  'PANTRY',
#  'TILE',
#  'HEARTS',
#  'ROUND',
#  'NOTEBOOK',
#  'PURPLE',
#  'LETTER',
#  'HOT',
#  '&',
#  'SWEETHEART',
#  'CHARM',
#  'PLATE',
#  'BEAD',
#  'KIT',
#  'CHOCOLATE',
#  'UNION',
#  'WATER',
#  'RETRO',
#  'JUMBO',
#  'CASES',
#  'RABBIT',
#  'DOORMAT',
#  'WOODLAND',
#  'LUNCH',
#  'TABLE',
#  'GINGHAM',
#  'CHILDRENS',
#  'KITCHEN',
#  'MAGIC',
#  'STORAGE',
#  'STRAWBERRY',
#  'SPOT',
#  'POT',
#  'PENCILS',
#  'FLOCK',
#  'BLING',
#  'LANTERN',
#  'FELTCRAFT',
#  'LONDON',
#  'SWEET',
#  'PURSE',
#  '36',
#  'TINS',
#  'BABUSHKA',
#  'FLOWERS',
#  'MAGNETS',
#  'DOG',
#  'TRINKET',
#  'TUBE',
#  'BELL',
#  'BUNNY',
#  'CABINET',
#  'BAROQUE',
#  'WIRE',
#  'BASKET',
#  'ON',
#  'DOOR',
#  'BOOK',
#  'NUMBER',
#  'DROP',
#  'JACK',
#  'COFFEE',
#  'KNOB',
#  'CAT',
#  'RIBBON',
#  'REEL',
#  'DAISY',
#  'LEAF',
#  'HAND',
#  'LIGHT',
#  'I',
#  'ACRYLIC',
#  'WICKER',
#  '5',
#  'SKULLS',
#  'DINNER',
#  'T-LIGHTS',
#  'HAIR',
#  'DISH',
#  'SHELL',
#  'DOILEY',
#  'BOXES',
#  'WARMER',
#  'SKULL',
#  'RIBBONS',
#  'STICKERS',
#  'WREATH',
#  'BUNTING',
#  'DOILY',
#  'HANGER',
#  'YELLOW',
#  'TAPE',
#  'SET/6',
#  'JAM',
#  'CLASSIC',
#  'TISSUES',
#  'STYLE',
#  'FOLDING',
#  'NEW',
#  '+',
#  'TOY',
#  'TRAVEL',
#  'INCENSE',
#  'PEN',
#  'REGENCY',
#  'BAKING',
#  'FLORAL',
#  'COSY',
#  'BALL',
#  'ENGLISH',
#  'CHICK',
#  'SQUARE',
#  'DOILIES',
#  'BOTANICAL',
#  'CARDS',
#  'SHAPE',
#  'DECORATIVE',
#  'HEN',
#  'ALPHABET',
#  'JIGSAW',
#  'PARASOL',
#  'THE',
#  'MONEY',
#  'COTTAGE',
#  'SCENTED',
#  'CANDY',
#  'BATHROOM',
#  '9',
#  'BELLS',
#  'LACE',
#  'MEDIUM',
#  'SET/4',
#  'PAN',
#  'BLOSSOM',
#  'BEADED',
#  'RACK',
#  "50'S",
#  'PICTURE',
#  'CHERRY',
#  'FONT',
#  'LIGHTS',
#  'UMBRELLA',
#  'STRING',
#  'JEWELLED',
#  'APRON',
#  'HONEYCOMB',
#  'CHILDS',
#  'GREETING',
#  'FOOD',
#  'FOLKART',
#  'IMAGES',
#  'BEADS',
#  'ORBIT',
#  'EDWARDIAN',
#  'MILK',
#  'SOFT',
#  'TIDY',
#  'SLATE',
#  'PLANT',
#  'TRADITIONAL',
#  'SEWING',
#  'PICNIC',
#  'HOUSE',
#  'LAVENDER',
#  'HANDBAG',
#  'APPLES',
#  'POCKET',
#  'PEARL',
#  'WALLET',
#  'POINT',
#  'STICKER',
#  'STARS',
#  'CIRCUS',
#  'PARADE',
#  'ANT',
#  'PIECE',
#  '60',
#  'TIME',
#  'FUNKY',
#  'DOORSTOP',
#  'DINER',
#  'RUSTIC',
#  'TISSUE',
#  'CROCHET',
#  'MIRRORED',
#  '20',
#  'CAKES',
#  'TREASURE',
#  'VICTORIAN',
#  'CRAFT',
#  'COTTON',
#  'TOWEL',
#  'HAPPY',
#  'CAN',
#  'FOR',
#  'FRUIT',
#  ',',
#  'BOUDICCA',
#  'GLAZE',
#  'FLAG',
#  'CHARLOTTE',
#  'DOLL',
#  'DINOSAUR',
#  'BREAKFAST',
#  'JUG',
#  'NATURAL',
#  'YOUR',
#  'TIER',
#  'OVAL',
#  'LETTERS',
#  'TOP',
#  '10',
#  'LAMP',
#  'EMBROIDERED',
#  'TRIPLE',
#  'TALL',
#  'LUGGAGE',
#  'BISCUIT',
#  'BROWN',
#  'SOAP',
#  'PLAYING',
#  'NAPKIN',
#  'PRINT',
#  'FRYING',
#  'STRIPE',
#  'GLITTER',
#  'SET/3',
#  'BABY',
#  'CHUNKY',
#  'PENDANT',
#  'MOULD',
#  'CURTAIN',
#  'TOADSTOOL',
#  'CHAIN',
#  'LOLA',
#  'BIN',
#  'CLEAR',
#  'SAUCER',
#  'OWN',
#  'NAPKINS',
#  'KIDS',
#  'TAG',
#  'VANILLA',
#  'FILIGREE',
#  'PENCIL',
#  '3D',
#  'ORANGE',
#  'CHARMS',
#  'MULTICOLOUR',
#  'SKETCHBOOK',
#  'JEWELLERY',
#  'FEATHER',
#  'WATERING',
#  'CONTAINER',
#  'KEEP',
#  'AMBER',
#  'BIG',
#  'PASTEL',
#  'SNACK',
#  'CHARLIE',
#  'SPOTTY',
#  'COASTER',
#  'GIANT',
#  'BOARD',
#  'FRIDGE',
#  'MEASURING',
#  'TEATIME',
#  'SCANDINAVIAN',
#  'CANDLEHOLDER',
#  'SUKI',
#  'DRAWING',
#  'SCENT',
#  'HOLLY',
#  'CALENDAR',
#  'LEAVES',
#  'FIRST',
#  'FABRIC',
#  'JARDIN',
#  'OFFICE',
#  'HORSE',
#  'HERB',
#  'MARKER',
#  'MORRIS',
#  'SHOPPING',
#  'MONKEY',
#  'TUTTI',
#  'FRUTTI',
#  'LAMPSHADE',
#  'PEG',
#  'MOBILE',
#  'PAIR',
#  'HOOP',
#  'FROG',
#  'PHONE',
#  'JEWEL',
#  'DECORATIONS',
#  'ORIGAMI',
#  'MURANO',
#  'CHANDELIER',
#  'BEAKER',
#  'CALM',
#  'COAT',
#  'KNITTED',
#  'SHEET',
#  'CLIP',
#  'OWL',
#  'LOVEBIRD',
#  'FIRE',
#  'BUCKET',
#  'ORGANISER',
#  '72',
#  'TV',
#  'APPLE',
#  'FLANNEL',
#  'A',
#  'SINGLE',
#  'TURQUOISE',
#  'EMPIRE',
#  'ETCHED',
#  'SHED',
#  'PAD',
#  'MINT',
#  'UP',
#  'ROLL',
#  'SPOTS',
#  '16',
#  'SHELF',
#  'PASSPORT',
#  'PUDDING',
#  'ASSTD',
#  'AMETHYST',
#  'WASHBAG',
#  'VOTIVE',
#  'DANISH',
#  'ICE',
#  'ARTIFICIAL',
#  'CRACKED',
#  'PARLOUR',
#  '7',
#  'BLOCK',
#  'ALARM',
#  'TOWELS',
#  'BILLBOARD',
#  'CHARLIE+LOLA',
#  'CHICKEN',
#  'BANK',
#  'THERMOMETER',
#  'COLOURED',
#  'LID',
#  'CONES',
#  'CARD,',
#  'HOLIDAY',
#  'CHEST',
#  'COOKIE',
#  'ANGEL',
#  'TOTE',
#  'S/4',
#  'BEACH',
#  'KINGS',
#  'CHOICE',
#  'PLACE',
#  'STRIPES',
#  'DE',
#  'JET',
#  'BIRDHOUSE',
#  'CUT',
#  'WICK',
#  'FUN',
#  'ASS',
#  'FOREST',
#  'DEC',
#  'TEDDY',
#  '60CM',
#  'PORCELAIN',
#  '1',
#  'RECYCLED',
#  'BROOCH',
#  'FAN',
#  'MIDNIGHT',
#  'COMPACT',
#  'CHICKS',
#  'LATTICE',
#  'EGGS',
#  'COPPER',
#  'TWIST',
#  'CLUSTER',
#  'MAT',
#  'KNICK',
#  'KNACK',
#  'MAGNETIC',
#  'PARK',
#  'BICYCLE',
#  'RECIPE',
#  'PARIS',
#  'BATH',
#  'BAKELIKE',
#  'BUNNIES',
#  'AIRLINE',
#  'SHOULDER',
#  'WINE',
#  'DES',
#  'STICK',
#  'BALLOON',
#  'MEDINA',
#  'FLYING',
#  'DUCKS',
#  'DISCO',
#  'CUPS',
#  'PEGS',
#  'GREY',
#  'BALLOONS',
#  'GROW',
#  'SHAPED',
#  'MATCHES',
#  'CANDLESTICK',
#  'TRELLIS',
#  'INVITES',
#  'PENS',
#  'PLASTERS',
#  'STRAND',
#  'TASSLE',
#  'ROSES',
#  'DECOUPAGE',
#  'SOCK',
#  'BAUBLE',
#  'VILLAGE',
#  'MUSHROOM',
#  'TAGS',
#  'OVEN',
#  'COLOURING',
#  'RUBY',
#  'STATIONERY',
#  'CANVAS',
#  'SIZE',
#  'POTTING',
#  'POLYESTER',
#  'FILLER',
#  'SCARF',
#  'JOURNAL',
#  'COL',
#  'SPRING',
#  'SCALES',
#  'PATCHES',
#  'PSYCHEDELIC',
#  'SCREEN',
#  'YOU',
#  'DRAWERS',
#  'RAFFIA',
#  'HELICOPTER',
#  '8',
#  'CATS',
#  'STOCKING',
#  'JINGLE',
#  'FUSCHIA',
#  'BOXED',
#  'ELEPHANT',
#  'FOUR',
#  'ALBUM',
#  'FOB',
#  'ANIMAL',
#  'SPACE',
#  'FOLK',
#  'SUGAR',
#  'PADDED',
#  'DU',
#  'SUD',
#  'KEYRING',
#  'PAPERWEIGHT',
#  'STAMPED',
#  'SPOON',
#  'CAROUSEL',
#  'POLISHED',
#  'MOSAIC',
#  'STANDING',
#  'WHITE/PINK',
#  'ROSEBUD',
#  'WOVEN',
#  'ACAPULCO',
#  'LIST',
#  'APOTHECARY',
#  'LANDMARK',
#  'GAME',
#  'LED',
#  'NIGHT',
#  'FINISH',
#  'PLATES',
#  'TONIC',
#  'SHOPPER',
#  'CHALKBOARD',
#  'BREAD',
#  'KEEPSAKE',
#  'RAIN',
#  'SILK',
#  'PLACEMATS',
#  'COASTERS',
#  'SPONGE',
#  'ROMANTIC',
#  'CUTTERS',
#  "B'FLY",
#  'ANIMALS',
#  'GLOVE',
#  'AID',
#  'PEARS',
#  'PIZZA',
#  'TOAST',
#  'ITS',
#  '-',
#  'GLOVES',
#  'RIDGED',
#  'CHATEAU',
#  'ENCHANTED',
#  'BISCUITS',
#  'MODERN',
#  'ONE',
#  'STRAWS',
#  'COSMETIC',
#  'COLLAGE',
#  'BASE',
#  'PINK/WHITE',
#  'BRUSH',
#  'BADGES',
#  'LA',
#  'PIN',
#  'PLASTIC',
#  'TEAPOT',
#  'DAIRY',
#  'MAID',
#  'STAMP',
#  'RULER',
#  'BIRDS',
#  'COLUMBIAN',
#  'LILY',
#  'GEMSTONE',
#  'FARM',
#  'MAGNET',
#  'PILLAR',
#  'NECKLACE+BRACELET',
#  'PETIT',
#  'CHECK',
#  'CAMPHOR',
#  'SUMMER',
#  'CIRCLES',
#  'TROPICAL',
#  'MONSTER',
#  'SNOW',
#  'IRON',
#  'FORK',
#  'POP',
#  'BEAR',
#  'CHAIR',
#  'MOROCCAN',
#  '50',
#  'WINDMILL',
#  'EAU',
#  'STOOL',
#  'GOOSE',
#  'BERTIE',
#  'HUT',
#  'ST',
#  'SECRET',
#  'BUFFALO',
#  'BILL',
#  'BACKPACK',
#  'PARISIENNE',
#  'DOORKNOB',
#  'CHOPPING',
#  'TUSCAN',
#  'VILLA',
#  "POPPY'S",
#  'PLAYHOUSE',
#  'ENGLAND',
#  'SEASIDE',
#  'GIN',
#  'WILLIE',
#  'WINKIE',
#  'MAKE',
#  'CARAVAN',
#  'REINDEER',
#  'SPOONS',
#  'DELUXE',
#  'CUBE',
#  'SKITTLES',
#  'CARNIVAL',
#  'SCOTTIE',
#  'CORNICE',
#  'FAMILY',
#  'TOILET',
#  'SET/10',
#  'GIRLS',
#  'BOWLS',
#  'SWIRLY',
#  "CHILDREN'S",
#  'FACETED',
#  'BANGLE',
#  'PATTERN',
#  'SLIPPER',
#  'ADVENT',
#  'CHALK',
#  'STICKS',
#  'TO',
#  'TOADSTOOLS',
#  'BOYS',
#  'DOVE',
#  'FERN',
#  'CHRYSANTHEMUM',
#  'CHINESE',
#  'SCISSOR',
#  'SETTING',
#  'GRIP',
#  'PACK/2',
#  'EXPANDABLE',
#  'RECORD',
#  'ROCKING',
#  'SEED',
#  'PATH',
#  'WASHING',
#  'SWISS',
#  'CONFETTI',
#  'MULTI',
#  'SUCTION',
#  'PLACEMAT',
#  'WELCOME',
#  'SCHOOL',
#  'PERSON',
#  'CANDLEPOT',
#  'CURIOUS',
#  'MUSICAL',
#  'PONY',
#  'MA',
#  'CAMPAGNE',
#  'FINE',
#  'KNITTING',
#  'LADLE',
#  'CUTE',
#  'BROCANTE',
#  'ROBOT',
#  'EMBOSSED',
#  'PORTRAIT',
#  'BOY',
#  'THANK',
#  'PLANTER',
#  'POST',
#  'TWO',
#  '40',
#  'TASSEL',
#  'POSY',
#  'LILAC',
#  'CLIPS',
#  'CAFE',
#  '45CM',
#  'HOLDERS',
#  'CHOC',
#  'RUBBER',
#  'SALAD',
#  'SETTINGS',
#  'PATCH',
#  'SHOP',
#  'LONG',
#  'CAR',
#  'STITCHED',
#  'DECO',
#  'CIRCLE',
#  'ENVELOPE',
#  'SUNDAE',
#  'LAS',
#  'VEGAS',
#  'LOLLY',
#  'GNOME',
#  'SHARPENER',
#  'INCENSE/CANDLE',
#  'ROCOCO',
#  'TURQ',
#  'DIAMOND',
#  'WOBBLY',
#  'M.O.P',
#  'FRANGIPANI',
#  'DAY',
#  'KING',
#  'GEORGE',
#  'NECKLAC',
#  'DOLLCRAFT',
#  'BUNDLE',
#  'BOOKS',
#  'BON',
#  'LAUREL',
#  'TRIM',
#  'CRACKLE',
#  'BONNE',
#  'SUCKER',
#  'PRETTY',
#  'RUCKSACK',
#  'CUPID',
#  'NESTING',
#  'POLKA',
#  'PRINCESS',
#  'BUILDING',
#  'WORD',
#  'FASHION',
#  'PAINT',
#  'SAVE',
#  'PLANET',
#  'S/3',
#  'MAKING',
#  'DIET',
#  'FANCY',
#  'CALCULATOR',
#  'DRESSING',
#  'JARS',
#  'OWLS',
#  'POPCORN',
#  'STRIPEY',
#  'ROPE',
#  '24',
#  'DOUGHNUT',
#  'S/6',
#  'WRITING',
#  'LADIES',
#  'IS',
#  'OR',
#  'SANTA',
#  'PIRATE',
#  'SNOWFLAKE',
#  'JAZZ',
#  'GUMBALL',
#  'FOOTBALL',
#  'PANNETONE',
#  'RECTANGLE',
#  'ERASERS',
#  'MARBLES',
#  'BOOM',
#  'DRESS',
#  'SHOES',
#  'LITTLE',
#  'FRIENDS',
#  'HAIRBAND',
#  'GO',
#  'FAIR',
#  'CUPCAKE',
#  'SPADE',
#  'CADDY',
#  'CLASSICAL',
#  'VASE',
#  'TEALIGHT',
#  'BAUBLES',
#  'MONTANA',
#  'CIRCULAR',
#  'ENGRAVED',
#  'TOWEL,',
#  'PLATTER',
#  'TEACUP',
#  'SLICE',
#  'EIGHT',
#  'SAND',
#  'POSTCARD',
#  'CASE',
#  'LIFE',
#  'LADDER',
#  'FONTS',
#  'PEACE',
#  'COCKTAIL',
#  'ONLY',
#  'MAN',
#  'SINGING',
#  'MAGAZINE',
#  'GRAND',
#  'DAYS',
#  'CAMOUFLAGE',
#  'DRAGONFLY',
#  'SHARK',
#  'MOON',
#  'HAMMOCK',
#  'No',
#  'STACKING',
#  'CARDHOLDER',
#  'CHEESE',
#  'SHADE',
#  'CACTI',
#  'BEST',
#  'SPOTTED',
#  'LIPSTICK',
#  'FLOOR',
#  'EAR',
#  'MUFF',
#  'HEADPHONES',
#  'GARDENIA',
#  'MEMO',
#  'STENCIL',
#  'PIG',
#  'HOOKS',
#  'RAINBOW',
#  'TEA,COFFEE,SUGAR',
#  'WEDDING',
#  'SHOE',
#  'POTS',
#  'BOW',
#  'BACK',
#  'CHOPSTICKS',
#  'PUPPET',
#  'CURIO',
#  'BUTTER',
#  'OPEN',
#  'CADET',
#  'CITRONELLA',
#  'REST',
#  'GAUZE',
#  'BUTTONS',
#  '75',
#  'PALMIERA',
#  'LINERS',
#  'MOUSE',
#  'OCEAN',
#  'WAKE',
#  'COCKEREL',
#  'RIM',
#  'TROWEL',
#  'RINGS',
#  'MICROWAVE',
#  'MADRAS',
#  'STONES',
#  'ABSTRACT',
#  "70'S",
#  'ASHTRAY',
#  'QUEEN',
#  'SKIES',
#  'SUNSET',
#  'CUBIC',
#  '0',
#  '30CM',
#  'SUNGLASSES',
#  'NILE',
#  'BOTTLES',
#  'CLASS',
#  'PLAQUE',
#  'ASST',
#  'SLIDES',
#  'SCRAP',
#  'DROPLET',
#  'BEDSIDE',
#  'BEATEN',
#  'CHIC',
#  'CHALICE',
#  'ENAMEL+GLASS',
#  'COMB',
#  'DARK',
#  'CACTUS',
#  'NEST',
#  'ICON',
#  'CRYSTAL+GLASS',
#  'GLASS/SILVER',
#  'HUNT',
#  'START',
#  'POPPIES',
#  'POLE',
#  'TIE',
#  'VINT',
#  'AMELIE',
#  'GYMKHANA',
#  'LIP',
#  'GLOSS',
#  'MARIE',
#  'EXERCISE',
#  'DISPENSER',
#  'MISELTOE',
#  'KNEELING',
#  'PEONY',
#  'BLANK',
#  'REFECTORY',
#  'HAIRSLIDE',
#  'QUILTED',
#  'LINEN',
#  'HENRIETTA',
#  'MILKMAID',
#  'PANETTONE',
#  'FROSTED',
#  'DOT',
#  'BLOCKS',
#  'INFLATABLE',
#  'HEADS',
#  'TAILS',
#  'ME',
#  'TOYS',
#  'WASTEPAPER',
#  'FLORA',
#  'PERSONAL',
#  'DOORSIGN',
#  'PRINTED',
#  'PC',
#  'TOOL',
#  'BASKETS',
#  'BIRDCAGE',
#  'TALE',
#  'FIVE',
#  'SET/20',
#  'DOMINOES',
#  'CLOTHES',
#  'BOUDOIR',
#  ...]

# %%
import nltk
text=' '.join(descList).lower()
tokens = nltk.word_tokenize(text)
tags = nltk.pos_tag(tokens)
nouns = [word for word,pos in tags if (pos == 'NN' or pos == 'NNP' or pos == 'NNS' or pos == 'NNPS')]
nouns
# Out:
# ['pink',
#  'set',
#  'heart',
#  'vintage',
#  'blue',
#  'bag',
#  'christmas',
#  'glass',
#  'box',
#  'design',
#  'holder',
#  'metal',
#  'flower',
#  'decoration',
#  'wall',
#  'retrospot',
#  'candle',
#  'paper',
#  'silver',
#  'cake',
#  'art',
#  'card',
#  'polkadot',
#  'garden',
#  'mug',
#  'cover',
#  'pack',
#  'sign',
#  'bracelet',
#  'star',
#  'mini',
#  'egg',
#  'love',
#  'tea',
#  'gift',
#  'bowl',
#  'cushion',
#  'frame',
#  'home',
#  'zinc',
#  'mirror',
#  'cream',
#  'easter',
#  'ring',
#  'earrings',
#  'bird',
#  'tin',
#  'paisley',
#  'girl',
#  'party',
#  'bottle',
#  'wood',
#  'garland',
#  'gold',
#  'antique',
#  'hook',
#  'jar',
#  'spaceboy',
#  'photo',
#  'colour',
#  'cutlery',
#  'fairy',
#  'butterfly',
#  'diamante',
#  'drawer',
#  'pantry',
#  'tile',
#  'hearts',
#  'letter',
#  'charm',
#  'plate',
#  'kit',
#  'chocolate',
#  'union',
#  'water',
#  'cases',
#  'woodland',
#  'lunch',
#  'gingham',
#  'childrens',
#  'storage',
#  'strawberry',
#  'spot',
#  'pot',
#  'flock',
#  'feltcraft',
#  'london',
#  'tins',
#  'flowers',
#  'magnets',
#  'trinket',
#  'tube',
#  'bell',
#  'cabinet',
#  'baroque',
#  'wire',
#  'basket',
#  'door',
#  'book',
#  'number',
#  'drop',
#  'jack',
#  'coffee',
#  'knob',
#  'cat',
#  'ribbon',
#  'reel',
#  'daisy',
#  'hand',
#  'light',
#  'i',
#  'wicker',
#  'skulls',
#  't-lights',
#  'shell',
#  'doiley',
#  'boxes',
#  'ribbons',
#  'stickers',
#  'tape',
#  'set/6',
#  'jam',
#  'tissues',
#  'style',
#  'toy',
#  'travel',
#  'incense',
#  'regency',
#  'ball',
#  'chick',
#  'square',
#  'cards',
#  'hen',
#  'alphabet',
#  'jigsaw',
#  'money',
#  'cottage',
#  'candy',
#  'bathroom',
#  'bells',
#  'medium',
#  'set/4',
#  'pan',
#  'blossom',
#  'rack',
#  'picture',
#  'cherry',
#  'lights',
#  'umbrella',
#  'honeycomb',
#  'childs',
#  'food',
#  'folkart',
#  'beads',
#  'milk',
#  'tidy',
#  'slate',
#  'plant',
#  'house',
#  'lavender',
#  'handbag',
#  'apples',
#  'wallet',
#  'point',
#  'sticker',
#  'parade',
#  'piece',
#  'time',
#  'doorstop',
#  'diner',
#  'tissue',
#  'crochet',
#  'cakes',
#  'treasure',
#  'craft',
#  'cotton',
#  'fruit',
#  'boudicca',
#  'glaze',
#  'flag',
#  'charlotte',
#  'doll',
#  'dinosaur',
#  'breakfast',
#  'tier',
#  'letters',
#  'lamp',
#  'luggage',
#  'biscuit',
#  'soap',
#  'print',
#  'glitter',
#  'set/3',
#  'baby',
#  'chunky',
#  'pendant',
#  'mould',
#  'curtain',
#  'toadstool',
#  'chain',
#  'saucer',
#  'napkins',
#  'kids',
#  'vanilla',
#  'pencil',
#  'orange',
#  'charms',
#  'sketchbook',
#  'jewellery',
#  'container',
#  'amber',
#  'pastel',
#  'snack',
#  'charlie',
#  'coaster',
#  'giant',
#  'board',
#  'fridge',
#  'candleholder',
#  'suki',
#  'scent',
#  'leaves',
#  'jardin',
#  'office',
#  'horse',
#  'herb',
#  'marker',
#  'morris',
#  'shopping',
#  'monkey',
#  'tutti',
#  'frutti',
#  'peg',
#  'pair',
#  'hoop',
#  'frog',
#  'phone',
#  'jewel',
#  'decorations',
#  'murano',
#  'chandelier',
#  'beaker',
#  'calm',
#  'coat',
#  'sheet',
#  'clip',
#  'owl',
#  'fire',
#  'bucket',
#  'tv',
#  'apple',
#  'turquoise',
#  'empire',
#  'pad',
#  'mint',
#  'roll',
#  'spots',
#  'shelf',
#  'passport',
#  'amethyst',
#  'washbag',
#  'ice',
#  'block',
#  'alarm',
#  'towels',
#  'charlie+lola',
#  'chicken',
#  'bank',
#  'thermometer',
#  'cones',
#  'card',
#  'holiday',
#  'cookie',
#  'tote',
#  's/4',
#  'beach',
#  'kings',
#  'choice',
#  'place',
#  'jet',
#  'birdhouse',
#  'cut',
#  'fun',
#  'ass',
#  'dec',
#  'teddy',
#  'porcelain',
#  'brooch',
#  'fan',
#  'midnight',
#  'compact',
#  'chicks',
#  'lattice',
#  'eggs',
#  'twist',
#  'cluster',
#  'mat',
#  'knick',
#  'knack',
#  'park',
#  'bicycle',
#  'recipe',
#  'bath',
#  'bakelike',
#  'bunnies',
#  'airline',
#  'wine',
#  'des',
#  'balloon',
#  'medina',
#  'ducks',
#  'cups',
#  'balloons',
#  'matches',
#  'trellis',
#  'invites',
#  'plasters',
#  'roses',
#  'decoupage',
#  'sock',
#  'village',
#  'mushroom',
#  'tags',
#  'stationery',
#  'canvas',
#  'size',
#  'polyester',
#  'filler',
#  'col',
#  'spring',
#  'scales',
#  'screen',
#  'helicopter',
#  'cats',
#  'jingle',
#  'fuschia',
#  'album',
#  'fob',
#  'space',
#  'folk',
#  'sugar',
#  'sud',
#  'paperweight',
#  'carousel',
#  'white/pink',
#  'rosebud',
#  'list',
#  'landmark',
#  'game',
#  'night',
#  'finish',
#  'shopper',
#  'chalkboard',
#  'bread',
#  'rain',
#  'silk',
#  'coasters',
#  'cutters',
#  'animals',
#  'aid',
#  'pears',
#  'gloves',
#  'chateau',
#  'biscuits',
#  'straws',
#  'collage',
#  'base',
#  'pink/white',
#  'brush',
#  'plastic',
#  'teapot',
#  'dairy',
#  'maid',
#  'stamp',
#  'ruler',
#  'birds',
#  'gemstone',
#  'farm',
#  'magnet',
#  'necklace+bracelet',
#  'petit',
#  'check',
#  'camphor',
#  'summer',
#  'circles',
#  'monster',
#  'iron',
#  'fork',
#  'pop',
#  'chair',
#  'windmill',
#  'eau',
#  'stool',
#  'bertie',
#  'hut',
#  'st',
#  'buffalo',
#  'bill',
#  'backpack',
#  'parisienne',
#  'doorknob',
#  'villa',
#  'poppy',
#  'playhouse',
#  'england',
#  'seaside',
#  'gin',
#  'winkie',
#  'caravan',
#  'reindeer',
#  'spoons',
#  'cube',
#  'skittles',
#  'cornice',
#  'family',
#  'toilet',
#  'girls',
#  'children',
#  'bangle',
#  'pattern',
#  'advent',
#  'chalk',
#  'sticks',
#  'boys',
#  'scissor',
#  'grip',
#  'pack/2',
#  'record',
#  'seed',
#  'path',
#  'confetti',
#  'suction',
#  'placemat',
#  'school',
#  'person',
#  'pony',
#  'ma',
#  'campagne',
#  'cute',
#  'brocante',
#  'robot',
#  'portrait',
#  'boy',
#  'thank',
#  'planter',
#  'post',
#  'tassel',
#  'clips',
#  'holders',
#  'rubber',
#  'settings',
#  'shop',
#  'car',
#  'circle',
#  'envelope',
#  'sundae',
#  'las',
#  'vegas',
#  'sharpener',
#  'rococo',
#  'turq',
#  'diamond',
#  'day',
#  'george',
#  'necklac',
#  'dollcraft',
#  'bundle',
#  'books',
#  'laurel',
#  'crackle',
#  'bonne',
#  'sucker',
#  'polka',
#  'princess',
#  'building',
#  'word',
#  'fashion',
#  'paint',
#  'planet',
#  's/3',
#  'calculator',
#  'jars',
#  'stripey',
#  's/6',
#  'ladies',
#  'pirate',
#  'snowflake',
#  'jazz',
#  'gumball',
#  'football',
#  'pannetone',
#  'rectangle',
#  'erasers',
#  'marbles',
#  'boom',
#  'dress',
#  'shoes',
#  'friends',
#  'cupcake',
#  'spade',
#  'vase',
#  'baubles',
#  'towel',
#  'platter',
#  'teacup',
#  'slice',
#  'sand',
#  'postcard',
#  'case',
#  'life',
#  'ladder',
#  'fonts',
#  'peace',
#  'cocktail',
#  'man',
#  'magazine',
#  'days',
#  'shark',
#  'moon',
#  'hammock',
#  'cardholder',
#  'cheese',
#  'floor',
#  'muff',
#  'headphones',
#  'memo',
#  'stencil',
#  'pig',
#  'tea',
#  'coffee',
#  'sugar',
#  'wedding',
#  'shoe',
#  'pots',
#  'chopsticks',
#  'curio',
#  'butter',
#  'cadet',
#  'citronella',
#  'rest',
#  'gauze',
#  'buttons',
#  'palmiera',
#  'liners',
#  'rim',
#  'trowel',
#  'rings',
#  'stones',
#  'ashtray',
#  'skies',
#  'sunglasses',
#  'bottles',
#  'class',
#  'plaque',
#  'asst',
#  'slides',
#  'droplet',
#  'bedside',
#  'chalice',
#  'enamel+glass',
#  'comb',
#  'dark',
#  'cactus',
#  'icon',
#  'crystal+glass',
#  'glass/silver',
#  'hunt',
#  'start',
#  'poppies',
#  'vint',
#  'amelie',
#  'gymkhana',
#  'lip',
#  'gloss',
#  'marie',
#  'exercise',
#  'dispenser',
#  'miseltoe',
#  'peony',
#  'hairslide',
#  'henrietta',
#  'panettone',
#  'dot',
#  'blocks',
#  'heads',
#  'doorsign',
#  'tool',
#  'baskets',
#  'set/20',
#  'dominoes',
#  'clothes',
#  'battery',
#  'snowmen',
#  'hour',
#  'celebration',
#  'pinks',
#  'bake',
#  'harmonica',
#  'squarecushion',
#  'c/cover',
#  'speaker',
#  'sack',
#  'fawn',
#  'bulb',
#  'foil',
#  'cinammon',
#  'dinosaurs',
#  'repair',
#  'world',
#  'trees',
#  'bags',
#  'spirit',
#  'level',
#  'confectionery',
#  'swallow',
#  'please',
#  'bendy',
#  'joy',
#  'crossbones',
#  'childhood',
#  'nursery',
#  'geisha',
#  'keys',
#  'swallows',
#  'scotties',
#  'room',
#  'bomb',
#  'area',
#  'measure',
#  'stuff',
#  'moody',
#  'lanterns',
#  'army',
#  'camo',
#  'bookcover',
#  'glass+bead',
#  'juicy',
#  'creepy',
#  'wash',
#  'hairclip',
#  'hexagon',
#  'clam',
#  'garage',
#  'wrap',
#  'sky',
#  'colours',
#  'way',
#  'baths',
#  'cloche',
#  'mac',
#  'strawbery',
#  'cabin',
#  'throw',
#  'display',
#  'pack/12',
#  'field',
#  'blue/yellow',
#  'green/blue',
#  'witch',
#  'children',
#  'sailor',
#  'jasmine',
#  'bone',
#  'china',
#  'skirt',
#  'wool',
#  'bouquet',
#  'cast',
#  'lime',
#  'flask',
#  'kashmiri',
#  'silicon',
#  'seat',
#  'rocket',
#  'bitty',
#  'dogs',
#  'cap',
#  'economy',
#  'oil',
#  'burner',
#  'chrysanthemums',
#  'tumbler',
#  'travelogue',
#  'dusty',
#  'frames',
#  'sunflower',
#  'pouffe',
#  'masala',
#  'banquet',
#  'cupboard',
#  'toffee',
#  'voile',
#  'photoframe',
#  'jungle',
#  'popsicles',
#  'cd',
#  'nil',
#  'island',
#  'grass',
#  'colourful',
#  'trays',
#  'popart',
#  'rect',
#  'opium',
#  'sandlewood',
#  'goblet',
#  'slide',
#  'vip',
#  'rabbits',
#  'garld',
#  'charger',
#  'cannister',
#  'steel',
#  'stud',
#  'fly',
#  'swat',
#  'fruitbowl',
#  'stone',
#  'neckl',
#  'fluffy',
#  'band',
#  'daisies',
#  'anemone',
#  'candystuft',
#  'champagne',
#  'bar',
#  'puddings',
#  'resin',
#  'rasta',
#  'hen+chicks',
#  'petals',
#  'hamper',
#  'hydrangea',
#  'suede',
#  'posies',
#  'unit',
#  'planters',
#  'hydranga',
#  'pink/purple',
#  'radio',
#  'jade',
#  'sea',
#  'monte',
#  'carlo',
#  'pill',
#  'raspberry',
#  'riviera',
#  'jean-paul',
#  'mum',
#  'bull',
#  'kukui',
#  'coconut',
#  'tumbler',
#  'feathers',
#  'mistletoe',
#  'handle',
#  'strainer',
#  'le',
#  'gardeners',
#  'icicle',
#  'mid',
#  'spike',
#  'donkey',
#  'tail',
#  'songbird',
#  'pieces',
#  'notepad',
#  'crackers',
#  'ceature',
#  'jampot',
#  'crate',
#  'botanique',
#  'makers',
#  'stop',
#  'loves',
#  'licence',
#  'nature',
#  'baseball',
#  'boot',
#  'triobase',
#  'm.o.p',
#  'feeder',
#  'street',
#  'heart',
#  'bedroom',
#  'globe',
#  'set/2',
#  'of4',
#  'puzzles',
#  'mugs',
#  'sympathy',
#  'tomato',
#  'lounge',
#  'line',
#  'piggy',
#  'cook',
#  'beakers',
#  'ladders',
#  'lids',
#  'chilli',
#  'butterfiles',
#  'les',
#  'enfants',
#  'mice',
#  'sideboard',
#  'scotty',
#  'chasing',
#  'reds',
#  'rotator',
#  'take',
#  'baroquecandlestick',
#  'cloth',
#  'blues',
#  'cars',
#  'face',
#  'tokyo',
#  'cowboy',
#  'angels',
#  'tops',
#  'candelabra',
#  'guns',
#  'bobbles',
#  'parcel',
#  'olivia',
#  'rex',
#  'soldiers',
#  'cone',
#  'snap',
#  'drawerknob',
#  'santas',
#  'catch',
#  'birdy',
#  'namaste',
#  's/15',
#  'wc',
#  'washroom',
#  'dia',
#  'monsoon',
#  'rubbers',
#  'socks',
#  'tapes',
#  'stamps',
#  'provence',
#  'playtime',
#  'longboard',
#  'shirt',
#  'gents',
#  "'n",
#  'champion',
#  'hi',
#  'alpine',
#  'gazebo',
#  'market',
#  'tray',
#  'button',
#  'message',
#  'chives',
#  'thyme',
#  'season',
#  'squeezer',
#  'licorice',
#  'teaspoons',
#  'lizard',
#  'engine/car',
#  'flowerpower',
#  'rounders',
#  'junk',
#  'mail',
#  'finger',
#  'earth',
#  'parasols',
#  'crayons',
#  'games',
#  'women',
#  'lads',
#  'emergency',
#  'frieze',
#  'black+silver',
#  'swirlglass',
#  'pedestal',
#  'kashmir',
#  'charlie+lola',
#  'doctor',
#  'fringe',
#  'air',
#  'hostess',
#  'pen',
#  'coal',
#  'pen',
#  'pen',
#  'airmail',
#  'smiley',
#  'memory',
#  'lights',
#  'funk',
#  'choc+blue',
#  'b',
#  'newspaper',
#  'scandispot',
#  'instrument',
#  'crowns',
#  'stars',
#  'trees',
#  'medicine',
#  'smallfolkart',
#  'glass+zinc',
#  'eucalyptus',
#  'pinecone',
#  'marshmallow',
#  'indians',
#  'glass',
#  'm',
#  'v',
#  's',
#  'j',
#  'bingo',
#  'ribs',
#  'creatures',
#  'salle',
#  'bain',
#  'presents',
#  'war',
#  'gliders',
#  'bonbon',
#  'toothpaste',
#  'account',
#  'penny',
#  'hook',
#  'cakestand',
#  'vie',
#  'mod',
#  'modelling',
#  'clay',
#  'disc',
#  'lovebirds',
#  'dragon',
#  'digitalis',
#  'figures',
#  'carrot',
#  'black+white',
#  'livingroom',
#  'vine',
#  'food/drink',
#  'crawlies',
#  'cockle',
#  'front',
#  'candlestand',
#  'gaolers',
#  'bank',
#  'charges',
#  'tinsel',
#  'monsters',
#  'fanny',
#  'stopmetal',
#  'weekend',
#  'colander',
#  'blue/cream',
#  'tub',
#  'feng',
#  'shui',
#  'decoupage',
#  'novelty',
#  'toastrack',
#  'herbs',
#  'croquet',
#  'truffle',
#  'nancy',
#  'lush',
#  'greens',
#  '-paper',
#  'tools',
#  'card',
#  'pack/12',
#  'secateurs',
#  'portobello',
#  "b'draw",
#  'yellow/pink',
#  'strawberries',
#  'salt',
#  'polkadots',
#  'sound',
#  'beware',
#  'frappucino',
#  't-shirt',
#  'nurse',
#  'peacock',
#  'salts',
#  'footprints',
#  'lounge',
#  'mousey',
#  'coathanger',
#  'pearls',
#  'pennant',
#  'labels',
#  'ream',
#  'box',
#  'keyrings',
#  'memories',
#  'dream',
#  'chocolates',
#  ...]

# %% [markdown]
# ## // Description is done. //

# %%
df.to_csv('Data/uci_online_retail_cleaned.csv', index=False)
